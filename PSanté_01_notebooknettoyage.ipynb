# %% [markdown]
# Pour une lecture améliorée, ce notebook est idéalement lu avec un outil qui gère les niveaux des titres Markdown.
# Par exemple avec l'extension 'Table of Contents' du module 'Nbextensions' de Jupyter.

# %% [markdown]
# # Mise en place du notebook

# %% [markdown]
# ## Import des modules

# %%
import numpy as np
import pandas as pd
from os.path import exists

# API openfoodfacts
try:
    import openfoodfacts
except:
    # !pip install openfoodfacts
    import openfoodfacts

# %% [markdown]
# ## Gestion des paramètres d'affichage de Jupyter

# %%
# pour gérer l'affichage des dataframes pandas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 200

# pour gérer l'affichage des arrays numpy
# 230 sur ma config bureau, 165 sur ma config portable
np.set_printoptions(linewidth=165)

# pour afficher les gros fichiers sur toute la largeur de l'écran
from IPython.core.display import HTML
HTML("<style>.container { width:97% }</style>")
# Out:
# <style>.container { width:97% }</style>

# %% [markdown]
# # Prise en main de l'API openfoodfacts

# %% [markdown]
# ## Tests de l'API

# %% [markdown]
# Usage guide :
# https://github.com/openfoodfacts/openfoodfacts-python/blob/master/docs/Usage.md
#
# Les facets sont retournés sous forme de listes de dictionnaires.
#
# Les variables sont définies à :
# https://world.openfoodfacts.org/data/data-fields.txt

# %% [markdown]
# ### Requête d'une facette : retourne les modalités d'une variable

# %%
additives = openfoodfacts.facets.get_additives()
print(len(additives))
additives[0:5]
# Out:
# 564
# [{'id': 'en:e330',
#   'known': 1,
#   'name': 'E330 - Citric acid',
#   'products': 131642,
#   'sameAs': ['https://www.wikidata.org/wiki/Q159683'],
#   'url': 'https://world.openfoodfacts.org/additive/e330-citric-acid'},
#  {'id': 'en:e322',
#   'known': 1,
#   'name': 'E322 - Lecithins',
#   'products': 89093,
#   'sameAs': ['https://www.wikidata.org/wiki/Q241595'],
#   'url': 'https://world.openfoodfacts.org/additive/e322-lecithins'},
#  {'id': 'en:e322i',
#   'known': 1,
#   'name': 'E322i - Lecithin',
#   'products': 81397,
#   'sameAs': ['https://www.wikidata.org/wiki/Q241595'],
#   'url': 'https://world.openfoodfacts.org/additive/e322i-lecithin'},
#  {'id': 'en:e500',
#   'known': 1,
#   'name': 'E500 - Sodium carbonates',
#   'products': 55971,
#   'sameAs': ['https://www.wikidata.org/wiki/Q190227'],
#   'url': 'https://world.openfoodfacts.org/additive/e500-sodium-carbonates'},
#  {'id': 'en:e415',
#   'known': 1,
#   'name': 'E415 - Xanthan gum',
#   'products': 49923,
#   'sameAs': ['https://www.wikidata.org/wiki/Q410768'],
#   'url': 'https://world.openfoodfacts.org/additive/e415-xanthan-gum'}]

# %%
countries = openfoodfacts.facets.get_countries()
print(len(countries))
# Out:
# 642

# %%
# openfoodfacts.facets.get_ingredients()   # erreur de l'API

# %%
languages = openfoodfacts.facets.get_languages()
print(len(languages))
# Out:
# 138

# %%
places = openfoodfacts.facets.get_purchase_places()
print(len(places))
# Out:
# 4806

# %%
stores = openfoodfacts.facets.get_stores()
print(len(stores))
# Out:
# 6495

# %%
traces = openfoodfacts.facets.get_traces()
print(len(traces))
# Out:
# 7772

# %% [markdown]
# ### Requête de produits répondant à une seule modalité de facette

# %%
products = openfoodfacts.products.get_by_trace('egg')
print(len(products))
products[0:5]
# Out:
# 24
# [{'_id': '3579260039398',
#   '_keywords': ['charcuterie',
#    'pur',
#    'auvernou',
#    'made',
#    'stick',
#    'porcine',
#    'in',
#    'saucisson',
#    'sec',
#    'nature',
#    'viande',
#    'pork',
#    'francaise',
#    'dot',
#    'france',
#    'pure',
#    'porc',
#    'mini',
#    'green'],
#   'added_countries_tags': [],
#   'additives_debug_tags': [],
#   'additives_n': 4,
#   'additives_old_n': 3,
#   'additives_old_tags': ['en:e252', 'en:e250', 'en:e460'],
#   'additives_original_tags': ['en:e252', 'en:e250', 'en:e422', 'en:e460'],
#   'additives_prev_original_tags': ['en:e252', 'en:e250', 'en:e422', 'en:e460'],
#   'additives_tags': ['en:e250', 'en:e252', 'en:e422', 'en:e460'],
#   'additives_tags_n': None,
#   'allergens': 'en:milk',
#   'allergens_from_ingredients': 'lactose',
#   'allergens_from_user': '(en) en:milk',
#   'allergens_hierarchy': ['en:milk'],
#   'allergens_lc': 'en',
#   'allergens_tags': ['en:milk'],
#   'amino_acids_prev_tags': [],
#   'amino_acids_tags': [],
#   'brands': 'Auvernou',
#   'brands_tags': ['auvernou'],
#   'categories': 'Viandes, Charcuteries, Saucissons, Saucissons secs, Saucissons secs pur porc',
#   'categories_hierarchy': ['en:meats',
#    'en:prepared-meats',
#    'en:cured-sausages',
#    'fr:saucissons-secs',
#    'fr:saucissons-secs-pur-porc'],
#   'categories_lc': 'fr',
#   'categories_old': 'Viandes, Charcuteries, Saucissons, Saucissons secs, Saucissons secs pur porc',
#   'categories_properties': {'agribalyse_food_code:en': '30301',
#    'ciqual_food_code:en': '30301'},
#   'categories_properties_tags': ['all-products',
#    'categories-known',
#    'agribalyse-food-code-30301',
#    'agribalyse-food-code-known',
#    'agribalyse-proxy-food-code-unknown',
#    'ciqual-food-code-30301',
#    'ciqual-food-code-known',
#    'agribalyse-known',
#    'agribalyse-30301'],
#   'categories_tags': ['en:meats',
#    'en:prepared-meats',
#    'en:cured-sausages',
#    'fr:saucissons-secs',
#    'fr:saucissons-secs-pur-porc'],
#   'category_properties': {'ciqual_food_name:en': 'Dry sausage, pure pork',
#    'ciqual_food_name:fr': 'Charcuterie -aliment moyen-'},
#   'checkers_tags': [],
#   'ciqual_food_name_tags': ['dry-sausage-pure-pork'],
#   'cities_tags': ['ussel-correze-france', 'ussel-correze-france'],
#   'code': '3579260039398',
#   'codes_tags': ['code-13',
#    '3579260039xxx',
#    '357926003xxxx',
#    '35792600xxxxx',
#    '3579260xxxxxx',
#    '357926xxxxxxx',
#    '35792xxxxxxxx',
#    '3579xxxxxxxxx',
#    '357xxxxxxxxxx',
#    '35xxxxxxxxxxx',
#    '3xxxxxxxxxxxx'],
#   'compared_to_category': 'fr:saucissons-secs-pur-porc',
#   'complete': 0,
#   'completeness': 1.0875,
#   'correctors_tags': ['sebleouf',
#    'bobtseu',
#    'yuka.V0xFdkRvSXEvNllnd2RnQnpnLy8zTTFabG9hUmMzTzRGTzh6SUE9PQ',
#    'kiliweb',
#    'openfoodfacts-contributors',
#    'yuka.UzZjZ0NJWXJuTU1Va3RnQzFEam4yY0FremFUMldYbUpFdUVMSWc9PQ',
#    'beniben',
#    'yuka.R3ZzY0s0QXJtTjhxby8waS9oUFV5ODF0N3NXbmVrQ3hjTkE5SVE9PQ',
#    'aleene',
#    'roboto-app',
#    'yuka.KetAZuS1EpB-H_CP0NI7wRjiTcXQW_JgGCMOog'],
#   'countries': 'France',
#   'countries_hierarchy': ['en:france'],
#   'countries_lc': 'en',
#   'countries_tags': ['en:france'],
#   'created_t': 1363436520,
#   'creator': 'marcussacapuces91',
#   'data_quality_bugs_tags': [],
#   'data_quality_errors_tags': [],
#   'data_quality_info_tags': ['en:packaging-data-incomplete',
#    'en:ingredients-percent-analysis-ok'],
#   'data_quality_tags': ['en:packaging-data-incomplete',
#    'en:ingredients-percent-analysis-ok',
#    'en:ecoscore-production-system-no-label'],
#   'data_quality_warnings_tags': ['en:ecoscore-production-system-no-label'],
#   'data_sources': 'App - yuka, Apps',
#   'data_sources_tags': ['app-yuka', 'apps'],
#   'debug_param_sorted_langs': ['fr', 'de', 'en', 'nl'],
#   'ecoscore_data': {'adjustments': {'origins_of_ingredients': {'aggregated_origins': [{'origin': 'en:france',
#        'percent': 100}],
#      'epi_score': 93,
#      'epi_value': 4,
#      'origins_from_origins_field': ['en:france'],
#      'transportation_score_be': 85,
#      'transportation_score_ch': 69,
#      'transportation_score_de': 61,
#      'transportation_score_es': 37,
#      'transportation_score_fr': 100,
#      'transportation_score_ie': 47,
#      'transportation_score_it': 47,
#      'transportation_score_lu': 82,
#      'transportation_score_nl': 77,
#      'transportation_value_be': 13,
#      'transportation_value_ch': 10,
#      'transportation_value_de': 9,
#      'transportation_value_es': 6,
#      'transportation_value_fr': 15,
#      'transportation_value_ie': 7,
#      'transportation_value_it': 7,
#      'transportation_value_lu': 12,
#      'transportation_value_nl': 12,
#      'value_be': 17,
#      'value_ch': 14,
#      'value_de': 13,
#      'value_es': 10,
#      'value_fr': 19,
#      'value_ie': 11,
#      'value_it': 11,
#      'value_lu': 16,
#      'value_nl': 16},
#     'packaging': {'non_recyclable_and_non_biodegradable_materials': 1,
#      'packagings': [{'ecoscore_material_score': 0,
#        'ecoscore_shape_ratio': 1,
#        'material': 'en:plastic',
#        'non_recyclable_and_non_biodegradable': 'maybe',
#        'shape': 'en:bag'}],
#      'score': 0,
#      'value': -10},
#     'production_system': {'warning': 'no_label'},
#     'threatened_species': {}},
#    'agribalyse': {'agribalyse_food_code': '30301',
#     'co2_agriculture': '4.4869776',
#     'co2_consumption': '0.0047993021',
#     'co2_distribution': '0.030308663',
#     'co2_packaging': '0.10607743',
#     'co2_processing': '0.57140518',
#     'co2_total': '5.3989777',
#     'co2_transportation': '0.19915056',
#     'code': '30301',
#     'dqr': '2.53',
#     'ef_agriculture': '0.66406769',
#     'ef_consumption': '0.0024293397',
#     'ef_distribution': '0.0089437534',
#     'ef_packaging': '0.0054466238',
#     'ef_processing': '0.14484443',
#     'ef_total': 0.84106878,
#     'ef_transportation': '0.015295439999999999',
#     'is_beverage': 0,
#     'name_en': 'Dry sausage, pure pork',
#     'name_fr': 'Saucisson sec pur porc',
#     'score': 36},
#    'grade': 'd',
#    'grade_be': 'c',
#    'grade_ch': 'c',
#    'grade_de': 'd',
#    'grade_es': 'd',
#    'grade_fr': 'c',
#    'grade_ie': 'd',
#    'grade_it': 'd',
#    'grade_lu': 'c',
#    'grade_nl': 'c',
#    'missing': {'labels': 1},
#    'missing_data_warning': 1,
#    'score': 26,
#    'score_be': 43,
#    'score_ch': 40,
#    'score_de': 39,
#    'score_es': 36,
#    'score_fr': 45,
#    'score_ie': 37,
#    'score_it': 37,
#    'score_lu': 42,
#    'score_nl': 42,
#    'status': 'known'},
#   'ecoscore_grade': 'd',
#   'ecoscore_score': 26,
#   'ecoscore_tags': ['d'],
#   'editors': ['marcussacapuces91', 'teolemon'],
#   'editors_tags': ['teolemon',
#    'beniben',
#    'yuka.KetAZuS1EpB-H_CP0NI7wRjiTcXQW_JgGCMOog',
#    'sebleouf',
#    'kiliweb',
#    'aleene',
#    'yuka.R3ZzY0s0QXJtTjhxby8waS9oUFV5ODF0N3NXbmVrQ3hjTkE5SVE9PQ',
#    'yuka.V0xFdkRvSXEvNllnd2RnQnpnLy8zTTFabG9hUmMzTzRGTzh6SUE9PQ',
#    'yuka.sY2b0xO6T85zoF3NwEKvln5gYtTOgCL7F0PRuhWT492vCMDHX-9rxrXCDqs',
#    'openfoodfacts-contributors',
#    'charlesnepote',
#    'yuka.UzZjZ0NJWXJuTU1Va3RnQzFEam4yY0FremFUMldYbUpFdUVMSWc9PQ',
#    'marcussacapuces91',
#    'roboto-app',
#    'bobtseu'],
#   'emb_codes': 'FR 19.275.008 EC,EMB 19275C',
#   'emb_codes_20141016': '',
#   'emb_codes_orig': 'FR 19.275.008 CE',
#   'emb_codes_tags': ['fr-19-275-008-ec', 'emb-19275c'],
#   'entry_dates_tags': ['2013-03-16', '2013-03', '2013'],
#   'environment_impact_level': '',
#   'environment_impact_level_tags': [],
#   'expiration_date': '20/03/2018',
#   'fruits-vegetables-nuts_100g_estimate': 0,
#   'generic_name': 'Mini Sticks Nature - Saucisson Sec Pur Porc',
#   'generic_name_de': '',
#   'generic_name_en': '',
#   'generic_name_fr': 'Mini Sticks Nature - Saucisson Sec Pur Porc',
#   'generic_name_nl': '',
#   'id': '3579260039398',
#   'image_front_small_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.200.jpg',
#   'image_front_thumb_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.100.jpg',
#   'image_front_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.400.jpg',
#   'image_ingredients_small_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_en.40.200.jpg',
#   'image_ingredients_thumb_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_en.40.100.jpg',
#   'image_ingredients_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_en.40.400.jpg',
#   'image_nutrition_small_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/nutrition_fr.54.200.jpg',
#   'image_nutrition_thumb_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/nutrition_fr.54.100.jpg',
#   'image_nutrition_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/nutrition_fr.54.400.jpg',
#   'image_small_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.200.jpg',
#   'image_thumb_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.100.jpg',
#   'image_url': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.400.jpg',
#   'images': {'1': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 3264, 'w': 2448}},
#     'uploaded_t': 1363436521,
#     'uploader': 'marcussacapuces91'},
#    '10': {'sizes': {'100': {'h': 31, 'w': 100},
#      '400': {'h': 123, 'w': 400},
#      'full': {'h': 737, 'w': 2392}},
#     'uploaded_t': '1518025371',
#     'uploader': 'kiliweb'},
#    '11': {'sizes': {'100': {'h': 100, 'w': 38},
#      '400': {'h': 400, 'w': 151},
#      'full': {'h': 1200, 'w': 454}},
#     'uploaded_t': '1522343960',
#     'uploader': 'kiliweb'},
#    '12': {'sizes': {'100': {'h': 100, 'w': 91},
#      '400': {'h': 400, 'w': 362},
#      'full': {'h': 3050, 'w': 2763}},
#     'uploaded_t': 1573559268,
#     'uploader': 'openfoodfacts-contributors'},
#    '13': {'sizes': {'100': {'h': 100, 'w': 56},
#      '400': {'h': 400, 'w': 225},
#      'full': {'h': 1200, 'w': 675}},
#     'uploaded_t': 1591970817,
#     'uploader': 'kiliweb'},
#    '14': {'sizes': {'100': {'h': 72, 'w': 100},
#      '400': {'h': 288, 'w': 400},
#      'full': {'h': 1138, 'w': 1582}},
#     'uploaded_t': 1591970817,
#     'uploader': 'kiliweb'},
#    '15': {'sizes': {'100': {'h': 100, 'w': 56},
#      '400': {'h': 400, 'w': 225},
#      'full': {'h': 1200, 'w': 675}},
#     'uploaded_t': 1615551814,
#     'uploader': 'kiliweb'},
#    '16': {'sizes': {'100': {'h': 72, 'w': 100},
#      '400': {'h': 288, 'w': 400},
#      'full': {'h': 1138, 'w': 1582}},
#     'uploaded_t': 1615551816,
#     'uploader': 'kiliweb'},
#    '2': {'sizes': {'100': {'h': 75, 'w': 100},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 2448, 'w': 3264}},
#     'uploaded_t': 1363436591,
#     'uploader': 'marcussacapuces91'},
#    '3': {'sizes': {'100': {'h': 75, 'w': 100},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 2448, 'w': 3264}},
#     'uploaded_t': 1363436644,
#     'uploader': 'marcussacapuces91'},
#    '4': {'sizes': {'100': {'h': 100, 'w': 74},
#      '400': {'h': 400, 'w': 296},
#      'full': {'h': 2701, 'w': 2000}},
#     'uploaded_t': '1496413510',
#     'uploader': 'sebleouf'},
#    '5': {'sizes': {'100': {'h': 100, 'w': 74},
#      '400': {'h': 400, 'w': 296},
#      'full': {'h': 2701, 'w': 2000}},
#     'uploaded_t': '1496413513',
#     'uploader': 'sebleouf'},
#    '6': {'sizes': {'100': {'h': 100, 'w': 74},
#      '400': {'h': 400, 'w': 296},
#      'full': {'h': 2701, 'w': 2000}},
#     'uploaded_t': '1496413526',
#     'uploader': 'sebleouf'},
#    '7': {'sizes': {'100': {'h': 100, 'w': 74},
#      '400': {'h': 400, 'w': 296},
#      'full': {'h': 2701, 'w': 2000}},
#     'uploaded_t': '1496413533',
#     'uploader': 'sebleouf'},
#    '8': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 3264, 'w': 2448}},
#     'uploaded_t': '1502818696',
#     'uploader': 'openfoodfacts-contributors'},
#    '9': {'sizes': {'100': {'h': 76, 'w': 100},
#      '400': {'h': 304, 'w': 400},
#      'full': {'h': 1360, 'w': 1788}},
#     'uploaded_t': '1518025366',
#     'uploader': 'kiliweb'},
#    'front': {'geometry': '0x0-0-0',
#     'imgid': '1',
#     'normalize': 'false',
#     'rev': '5',
#     'sizes': {'100': {'h': 100, 'w': 75},
#      '200': {'h': 200, 'w': 150},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 3264, 'w': 2448}},
#     'white_magic': 'false'},
#    'front_fr': {'angle': 0,
#     'coordinates_image_size': 'full',
#     'geometry': '0x0--1--1',
#     'imgid': '15',
#     'normalize': None,
#     'rev': '52',
#     'sizes': {'100': {'h': 100, 'w': 56},
#      '200': {'h': 200, 'w': 113},
#      '400': {'h': 400, 'w': 225},
#      'full': {'h': 1200, 'w': 675}},
#     'white_magic': None,
#     'x1': '-1',
#     'x2': '-1',
#     'y1': '-1',
#     'y2': '-1'},
#    'ingredients': {'geometry': '2627x522-365-488',
#     'imgid': '2',
#     'normalize': 'true',
#     'rev': '7',
#     'sizes': {'100': {'h': 20, 'w': 100},
#      '200': {'h': 40, 'w': 200},
#      '400': {'h': 79, 'w': 400},
#      'full': {'h': 522, 'w': 2627}},
#     'white_magic': 'false'},
#    'ingredients_de': {'angle': '0',
#     'geometry': '3085x424-134-1483',
#     'imgid': '2',
#     'normalize': 'false',
#     'ocr': 1,
#     'orientation': '0',
#     'rev': '39',
#     'sizes': {'100': {'h': 14, 'w': 100},
#      '200': {'h': 27, 'w': 200},
#      '400': {'h': 55, 'w': 400},
#      'full': {'h': 424, 'w': 3085}},
#     'white_magic': 'false',
#     'x1': '16.5',
#     'x2': '394.5',
#     'y1': '181.8125',
#     'y2': '233.8125'},
#    'ingredients_en': {'angle': '0',
#     'geometry': '628x480-1415-1578',
#     'imgid': '4',
#     'normalize': 'false',
#     'ocr': 1,
#     'orientation': '0',
#     'rev': '40',
#     'sizes': {'100': {'h': 82, 'w': 100},
#      '200': {'h': 164, 'w': 200},
#      '400': {'h': 328, 'w': 400},
#      'full': {'h': 480, 'w': 585}},
#     'white_magic': 'false',
#     'x1': '209.5',
#     'x2': '302.5',
#     'y1': '233.8125',
#     'y2': '304.8125'},
#    'ingredients_fr': {'angle': '0',
#     'geometry': '0x0-0-0',
#     'imgid': '10',
#     'normalize': 'false',
#     'ocr': 1,
#     'orientation': '0',
#     'rev': '33',
#     'sizes': {'100': {'h': 31, 'w': 100},
#      '200': {'h': 62, 'w': 200},
#      '400': {'h': 123, 'w': 400},
#      'full': {'h': 737, 'w': 2392}},
#     'white_magic': 'false',
#     'x1': '0',
#     'x2': '0',
#     'y1': '0',
#     'y2': '0'},
#    'ingredients_nl': {'angle': '0',
#     'geometry': '1236x479-395-201',
#     'imgid': '5',
#     'normalize': 'false',
#     'ocr': 1,
#     'orientation': '0',
#     'rev': '38',
#     'sizes': {'100': {'h': 39, 'w': 100},
#      '200': {'h': 78, 'w': 200},
#      '400': {'h': 155, 'w': 400},
#      'full': {'h': 479, 'w': 1236}},
#     'white_magic': 'false',
#     'x1': '58.5',
#     'x2': '241.5',
#     'y1': '29.8125',
#     'y2': '100.8125'},
#    'nutrition': {'geometry': '2978x245-220-1238',
#     'imgid': '2',
#     'normalize': 'true',
#     'rev': '8',
#     'sizes': {'100': {'h': 8, 'w': 100},
#      '200': {'h': 16, 'w': 200},
#      '400': {'h': 33, 'w': 400},
#      'full': {'h': 245, 'w': 2978}},
#     'white_magic': 'false'},
#    'nutrition_fr': {'angle': 0,
#     'coordinates_image_size': 'full',
#     'geometry': '0x0--1--1',
#     'imgid': '16',
#     'normalize': None,
#     'rev': '54',
#     'sizes': {'100': {'h': 72, 'w': 100},
#      '200': {'h': 144, 'w': 200},
#      '400': {'h': 288, 'w': 400},
#      'full': {'h': 1138, 'w': 1582}},
#     'white_magic': None,
#     'x1': '-1',
#     'x2': '-1',
#     'y1': '-1',
#     'y2': '-1'}},
#   'informers_tags': ['marcussacapuces91',
#    'teolemon',
#    'kiliweb',
#    'sebleouf',
#    'yuka.V0xFdkRvSXEvNllnd2RnQnpnLy8zTTFabG9hUmMzTzRGTzh6SUE9PQ',
#    'yuka.UzZjZ0NJWXJuTU1Va3RnQzFEam4yY0FremFUMldYbUpFdUVMSWc9PQ',
#    'beniben',
#    'aleene',
#    'openfoodfacts-contributors'],
#   'ingredients': [{'id': 'en:pork-meat',
#     'percent_estimate': 53.5714285714286,
#     'percent_max': 100,
#     'percent_min': 7.14285714285714,
#     'text': 'Viande de porc',
#     'vegan': 'no',
#     'vegetarian': 'no'},
#    {'id': 'en:lactose',
#     'percent_estimate': 23.2142857142857,
#     'percent_max': 50,
#     'percent_min': 0,
#     'text': '_lactose_',
#     'vegan': 'no',
#     'vegetarian': 'yes'},
#    {'id': 'en:salt',
#     'percent_estimate': 11.6071428571429,
#     'percent_max': 33.3333333333333,
#     'percent_min': 0,
#     'text': 'sel',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:pepper',
#     'percent_estimate': 5.80357142857143,
#     'percent_max': 25,
#     'percent_min': 0,
#     'text': 'poivres',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:sugar',
#     'percent_estimate': 2.90178571428572,
#     'percent_max': 20,
#     'percent_min': 0,
#     'text': 'sucre',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:dextrose',
#     'percent_estimate': 1.45089285714286,
#     'percent_max': 16.6666666666667,
#     'percent_min': 0,
#     'text': 'dextrose',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:garlic',
#     'percent_estimate': 0.725446428571431,
#     'percent_max': 14.2857142857143,
#     'percent_min': 0,
#     'text': 'ail',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:mace',
#     'percent_estimate': 0.362723214285715,
#     'percent_max': 12.5,
#     'percent_min': 0,
#     'text': 'macis',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:preservative',
#     'ingredients': [{'id': 'en:e252',
#       'percent_estimate': 0.0906808035714306,
#       'percent_max': 11.1111111111111,
#       'percent_min': 0,
#       'text': 'nitrate de potassium',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'id': 'en:e250',
#       'percent_estimate': 0.0906808035714306,
#       'percent_max': 5.55555555555556,
#       'percent_min': 0,
#       'text': 'nitrite de sodium',
#       'vegan': 'yes',
#       'vegetarian': 'yes'}],
#     'percent_estimate': 0.181361607142861,
#     'percent_max': 11.1111111111111,
#     'percent_min': 0,
#     'text': 'conservateurs'},
#    {'id': 'en:clove',
#     'percent_estimate': 0.0906808035714306,
#     'percent_max': 10,
#     'percent_min': 0,
#     'text': 'girofle',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:ferment',
#     'percent_estimate': 0.0453404017857153,
#     'percent_max': 9.09090909090909,
#     'percent_min': 0,
#     'text': 'ferments',
#     'vegan': 'maybe',
#     'vegetarian': 'maybe'},
#    {'id': 'en:casing',
#     'ingredients': [{'id': 'fr:boyau-collagenique',
#       'percent_estimate': 0.0113351004464306,
#       'percent_max': 8.33333333333333,
#       'percent_min': 0,
#       'text': 'boyau collagénique',
#       'vegan': 'no',
#       'vegetarian': 'no'},
#      {'id': 'en:collagen',
#       'percent_estimate': 0.0113351004464306,
#       'percent_max': 4.16666666666667,
#       'percent_min': 0,
#       'text': 'collagène',
#       'vegan': 'no',
#       'vegetarian': 'no'}],
#     'percent_estimate': 0.0226702008928612,
#     'percent_max': 8.33333333333333,
#     'percent_min': 0,
#     'text': 'Enveloppe'},
#    {'id': 'en:e422',
#     'percent_estimate': 0.0113351004464306,
#     'percent_max': 7.69230769230769,
#     'percent_min': 0,
#     'text': 'glycérine',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:e460',
#     'percent_estimate': 0.0113351004464306,
#     'percent_max': 7.14285714285714,
#     'percent_min': 0,
#     'text': 'cellulose',
#     'vegan': 'yes',
#     'vegetarian': 'yes'}],
#   'ingredients_analysis_tags': ['en:palm-oil-free',
#    'en:non-vegan',
#    'en:non-vegetarian'],
#   'ingredients_debug': ['Viande de porc',
#    ',',
#    None,
#    None,
#    None,
#    ' _lactose_',
#    ',',
#    None,
#    None,
#    None,
#    ' sel',
#    ',',
#    None,
#    None,
#    None,
#    ' poivres',
#    ',',
#    None,
#    None,
#    None,
#    ' sucre',
#    ',',
#    None,
#    None,
#    None,
#    ' dextrose',
#    ',',
#    None,
#    None,
#    None,
#    ' ail',
#    ',',
#    None,
#    None,
#    None,
#    ' macis',
#    ',',
#    None,
#    None,
#    None,
#    ' conservateurs ',
#    ':',
#    ':',
#    None,
#    None,
#    '  nitrate de potassium et nitrite de sodium',
#    ',',
#    None,
#    None,
#    None,
#    ' girofle',
#    ',',
#    None,
#    None,
#    None,
#    ' ferments',
#    '. ',
#    None,
#    None,
#    None,
#    'Enveloppe ',
#    ':',
#    ':',
#    None,
#    None,
#    ' boyau collagénique ',
#    '(',
#    '(',
#    None,
#    None,
#    'collagène',
#    ',',
#    None,
#    None,
#    None,
#    ' glycérine',
#    ',',
#    None,
#    None,
#    None,
#    ' cellulose).'],
#   'ingredients_from_or_that_may_be_from_palm_oil_n': 0,
#   'ingredients_from_palm_oil_n': 0,
#   'ingredients_from_palm_oil_tags': [],
#   'ingredients_hierarchy': ['en:pork-meat',
#    'en:animal',
#    'en:meat',
#    'en:pork',
#    'en:lactose',
#    'en:salt',
#    'en:pepper',
#    'en:seed',
#    'en:sugar',
#    'en:dextrose',
#    'en:glucose',
#    'en:garlic',
#    'en:vegetable',
#    'en:root-vegetable',
#    'en:mace',
#    'en:spice',
#    'en:preservative',
#    'en:clove',
#    'en:ferment',
#    'en:casing',
#    'en:e422',
#    'en:e460',
#    'en:e252',
#    'en:e250',
#    'fr:boyau-collagenique',
#    'en:collagen'],
#   'ingredients_ids_debug': ['viande-de-porc',
#    'lactose',
#    'sel',
#    'poivres',
#    'sucre',
#    'dextrose',
#    'ail',
#    'macis',
#    'conservateurs',
#    'nitrate-de-potassium',
#    'nitrite-de-sodium',
#    'girofle',
#    'ferments',
#    'enveloppe',
#    'boyau-collagenique',
#    'collagene',
#    'glycerine',
#    'cellulose'],
#   'ingredients_n': 18,
#   'ingredients_n_tags': ['18', '11-20'],
#   'ingredients_original_tags': ['en:pork-meat',
#    'en:lactose',
#    'en:salt',
#    'en:pepper',
#    'en:sugar',
#    'en:dextrose',
#    'en:garlic',
#    'en:mace',
#    'en:preservative',
#    'en:clove',
#    'en:ferment',
#    'en:casing',
#    'en:e422',
#    'en:e460',
#    'en:e252',
#    'en:e250',
#    'fr:boyau-collagenique',
#    'en:collagen'],
#   'ingredients_tags': ['en:pork-meat',
#    'en:animal',
#    'en:meat',
#    'en:pork',
#    'en:lactose',
#    'en:salt',
#    'en:pepper',
#    'en:seed',
#    'en:sugar',
#    'en:dextrose',
#    'en:glucose',
#    'en:garlic',
#    'en:vegetable',
#    'en:root-vegetable',
#    'en:mace',
#    'en:spice',
#    'en:preservative',
#    'en:clove',
#    'en:ferment',
#    'en:casing',
#    'en:e422',
#    'en:e460',
#    'en:e252',
#    'en:e250',
#    'fr:boyau-collagenique',
#    'en:collagen'],
#   'ingredients_text': 'Viande de porc, _lactose_, sel, poivres, sucre, dextrose, ail, macis, conservateurs : nitrate de potassium et nitrite de sodium, girofle, ferments. Enveloppe : boyau collagénique (collagène, glycérine, cellulose).',
#   'ingredients_text_de': 'ocknete Salami aus reinem Schweinefleisch Zutaten Sceinefleisch, Laktose, Salz, Knoblauchfleisch (Wasser, Knoblauch, Salz, Säuerungsmittel: Zitronensaure) Pienerucker, Weizendextrose. Muskatblüte, Konservierungsstoff: Kaliumnitrat, Neke Fermente. Essbare, Hülle (Kollagen, Glyzerin, Zellulose). 100g Salami werden aus 168g Schweinefleisch hergestellt.kann on Schalenfrüchten enthalten',
#   'ingredients_text_debug': 'Viande de porc, _lactose_, sel, poivres, sucre, dextrose, ail, macis, conservateurs :  nitrate de potassium et nitrite de sodium, girofle, ferments. Enveloppe : boyau collagénique (collagène, glycérine, cellulose).',
#   'ingredients_text_en': 'collagen',
#   'ingredients_text_fr': 'Viande de porc, _lactose_, sel, poivres, sucre, dextrose, ail, macis, conservateurs : nitrate de potassium et nitrite de sodium, girofle, ferments. Enveloppe : boyau collagénique (collagène, glycérine, cellulose).',
#   'ingredients_text_nl': 'collageendarm (collageen)',
#   'ingredients_text_with_allergens': 'Viande de porc, <span class="allergen">lactose</span>, sel, poivres, sucre, dextrose, ail, macis, conservateurs : nitrate de potassium et nitrite de sodium, girofle, ferments. Enveloppe : boyau collagénique (collagène, glycérine, cellulose).',
#   'ingredients_text_with_allergens_de': 'ocknete Salami aus reinem Schweinefleisch Zutaten Sceinefleisch, <span class="allergen">Laktose</span>, Salz, Knoblauchfleisch (Wasser, Knoblauch, Salz, Säuerungsmittel: Zitronensaure) Pienerucker, Weizendextrose. Muskatblüte, Konservierungsstoff: Kaliumnitrat, Neke Fermente. Essbare, Hülle (Kollagen, Glyzerin, Zellulose). 100g Salami werden aus 168g Schweinefleisch hergestellt.kann on Schalenfrüchten enthalten',
#   'ingredients_text_with_allergens_en': 'collagen',
#   'ingredients_text_with_allergens_fr': 'Viande de porc, <span class="allergen">lactose</span>, sel, poivres, sucre, dextrose, ail, macis, conservateurs : nitrate de potassium et nitrite de sodium, girofle, ferments. Enveloppe : boyau collagénique (collagène, glycérine, cellulose).',
#   'ingredients_text_with_allergens_nl': 'collageendarm (collageen)',
#   'ingredients_that_may_be_from_palm_oil_n': 0,
#   'ingredients_that_may_be_from_palm_oil_tags': [],
#   'interface_version_created': '20120622',
#   'interface_version_modified': '20150316.jqm2',
#   'known_ingredients_n': 26,
#   'labels': 'fr:Viande Française,Green Dot,Made in France,Pure pork,fr:Viande Porcine Française',
#   'labels_hierarchy': ['fr:viande-francaise',
#    'en:green-dot',
#    'en:made-in-france',
#    'en:pure-pork',
#    'fr:viande-porcine-francaise'],
#   'labels_lc': 'en',
#   'labels_tags': ['fr:viande-francaise',
#    'en:green-dot',
#    'en:made-in-france',
#    'en:pure-pork',
#    'fr:viande-porcine-francaise'],
#   'lang': 'fr',
#   'languages': {'en:dutch': 2,
#    'en:english': 2,
#    'en:french': 6,
#    'en:german': 2},
#   'languages_codes': {'de': 2, 'en': 2, 'fr': 6, 'nl': 2},
#   'languages_hierarchy': ['en:english', 'en:german', 'en:dutch', 'en:french'],
#   'languages_tags': ['en:english',
#    'en:german',
#    'en:dutch',
#    'en:french',
#    'en:4',
#    'en:multilingual'],
#   'last_edit_dates_tags': ['2021-05-31', '2021-05', '2021'],
#   'last_editor': 'charlesnepote',
#   'last_image_dates_tags': ['2021-03-12', '2021-03', '2021'],
#   'last_image_t': 1615551816,
#   'last_modified_by': 'charlesnepote',
#   'last_modified_t': 1622453812,
#   'lc': 'fr',
#   'link': '',
#   'main_countries_tags': [],
#   'manufacturing_places': 'France',
#   'manufacturing_places_tags': ['france'],
#   'max_imgid': '16',
#   'minerals_prev_tags': [],
#   'minerals_tags': [],
#   'misc_tags': ['en:nutrition-fruits-vegetables-nuts-estimate-from-ingredients',
#    'en:nutrition-all-nutriscore-values-known',
#    'en:nutriscore-computed',
#    'en:ecoscore-missing-data-warning',
#    'en:ecoscore-computed'],
#   'no_nutrition_data': '',
#   'nova_group': 4,
#   'nova_group_debug': ' -- additives/en:e250 : 3 -- additives/en:e422 : 4',
#   'nova_groups': '4',
#   'nova_groups_tags': ['en:4-ultra-processed-food-and-drink-products'],
#   'nucleotides_prev_tags': [],
#   'nucleotides_tags': [],
#   'nutrient_levels': {'fat': 'high',
#    'salt': 'high',
#    'saturated-fat': 'high',
#    'sugars': 'low'},
#   'nutrient_levels_tags': ['en:fat-in-high-quantity',
#    'en:saturated-fat-in-high-quantity',
#    'en:sugars-in-low-quantity',
#    'en:salt-in-high-quantity'],
#   'nutriments': {'carbohydrates': 2.4,
#    'carbohydrates_100g': 2.4,
#    'carbohydrates_unit': 'g',
#    'carbohydrates_value': 2.4,
#    'energy': 2205,
#    'energy-kcal': 527,
#    'energy-kcal_100g': 527,
#    'energy-kcal_unit': 'kcal',
#    'energy-kcal_value': 527,
#    'energy_100g': 2205,
#    'energy_unit': 'kcal',
#    'energy_value': 527,
#    'fat': 45,
#    'fat_100g': 45,
#    'fat_unit': 'g',
#    'fat_value': 45,
#    'fiber': 0,
#    'fiber_100g': 0,
#    'fiber_unit': 'g',
#    'fiber_value': 0,
#    'fruits-vegetables-nuts-estimate-from-ingredients_100g': 0,
#    'nova-group': 4,
#    'nova-group_100g': 4,
#    'nova-group_serving': 4,
#    'nutrition-score-fr': 26,
#    'nutrition-score-fr_100g': 26,
#    'proteins': 28,
#    'proteins_100g': 28,
#    'proteins_unit': 'g',
#    'proteins_value': 28,
#    'salt': 4.6,
#    'salt_100g': 4.6,
#    'salt_unit': 'g',
#    'salt_value': 4.6,
#    'saturated-fat': 16,
#    'saturated-fat_100g': 16,
#    'saturated-fat_unit': 'g',
#    'saturated-fat_value': 16,
#    'sodium': 1.84,
#    'sodium_100g': 1.84,
#    'sodium_unit': 'g',
#    'sodium_value': 1.84,
#    'sugars': 2.2,
#    'sugars_100g': 2.2,
#    'sugars_unit': 'g',
#    'sugars_value': 2.2},
#   'nutriscore_data': {'energy': 2205,
#    'energy_points': 6,
#    'energy_value': 2205,
#    'fiber': 0,
#    'fiber_points': 0,
#    'fiber_value': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 0,
#    'grade': 'e',
#    'is_beverage': 0,
#    'is_cheese': 0,
#    'is_fat': 0,
#    'is_water': 0,
#    'negative_points': 26,
#    'positive_points': 0,
#    'proteins': 28,
#    'proteins_points': 5,
#    'proteins_value': 28,
#    'saturated_fat': 16,
#    'saturated_fat_points': 10,
#    'saturated_fat_ratio': 35.5555555555556,
#    'saturated_fat_ratio_points': 5,
#    'saturated_fat_ratio_value': 35.6,
#    'saturated_fat_value': 16,
#    'score': 26,
#    'sodium': 1840,
#    'sodium_points': 10,
#    'sodium_value': 1840,
#    'sugars': 2.2,
#    'sugars_points': 0,
#    'sugars_value': 2.2},
#   'nutriscore_grade': 'e',
#   'nutriscore_score': 26,
#   'nutriscore_score_opposite': -26,
#   'nutrition_data': 'on',
#   'nutrition_data_per': '100g',
#   'nutrition_data_prepared': '',
#   'nutrition_data_prepared_per': '100g',
#   'nutrition_grade_fr': 'e',
#   'nutrition_grades': 'e',
#   'nutrition_grades_tags': ['e'],
#   'nutrition_score_beverage': 0,
#   'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients': 1,
#   'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value': 0,
#   'obsolete': '',
#   'obsolete_since_date': '',
#   'origins': 'France',
#   'origins_hierarchy': ['en:france'],
#   'origins_lc': 'fr',
#   'origins_old': 'France',
#   'origins_tags': ['en:france'],
#   'other_nutritional_substances_tags': [],
#   'packaging': 'Sachet,Plastique',
#   'packaging_tags': ['sachet', 'plastique'],
#   'packagings': [{'material': 'en:plastic', 'shape': 'en:bag'}],
#   'photographers_tags': ['marcussacapuces91',
#    'sebleouf',
#    'openfoodfacts-contributors',
#    'kiliweb'],
#   'pnns_groups_1': 'Fish Meat Eggs',
#   'pnns_groups_1_tags': ['fish-meat-eggs', 'known'],
#   'pnns_groups_2': 'Processed meat',
#   'pnns_groups_2_tags': ['processed-meat', 'known'],
#   'popularity_key': 19950000032,
#   'popularity_tags': ['top-50000-scans-2019',
#    'top-100000-scans-2019',
#    'at-least-5-scans-2019',
#    'at-least-10-scans-2019',
#    'top-75-percent-scans-2019',
#    'top-80-percent-scans-2019',
#    'top-85-percent-scans-2019',
#    'top-90-percent-scans-2019',
#    'top-50000-fr-scans-2019',
#    'top-100000-fr-scans-2019',
#    'top-country-fr-scans-2019',
#    'at-least-5-fr-scans-2019',
#    'at-least-10-fr-scans-2019',
#    'top-50-hk-scans-2019',
#    'top-100-hk-scans-2019',
#    'top-500-hk-scans-2019',
#    'top-1000-hk-scans-2019',
#    'top-5000-hk-scans-2019',
#    'top-10000-hk-scans-2019',
#    'top-50000-hk-scans-2019',
#    'top-100000-hk-scans-2019',
#    'top-50000-scans-2020',
#    'top-100000-scans-2020',
#    'at-least-5-scans-2020',
#    'at-least-10-scans-2020',
#    'top-75-percent-scans-2020',
#    'top-80-percent-scans-2020',
#    'top-85-percent-scans-2020',
#    'top-90-percent-scans-2020',
#    'top-50000-fr-scans-2020',
#    'top-100000-fr-scans-2020',
#    'top-country-fr-scans-2020',
#    'at-least-5-fr-scans-2020',
#    'at-least-10-fr-scans-2020',
#    'top-100-mc-scans-2020',
#    'top-500-mc-scans-2020',
#    'top-1000-mc-scans-2020',
#    'top-5000-mc-scans-2020',
#    'top-10000-mc-scans-2020',
#    'top-50000-mc-scans-2020',
#    'top-100000-mc-scans-2020',
#    'top-5000-ie-scans-2020',
#    'top-10000-ie-scans-2020',
#    'top-50000-ie-scans-2020',
#    'top-100000-ie-scans-2020',
#    'top-500-sg-scans-2020',
#    'top-1000-sg-scans-2020',
#    'top-5000-sg-scans-2020',
#    'top-10000-sg-scans-2020',
#    'top-50000-sg-scans-2020',
#    'top-100000-sg-scans-2020'],
#   'product_name': 'Mini sticks nature auvernou',
#   'product_name_de': '',
#   'product_name_en': '',
#   'product_name_fr': 'Mini sticks nature auvernou',
#   'product_name_nl': '',
#   'product_quantity': 100,
#   'purchase_places': 'France',
#   'purchase_places_tags': ['france'],
#   'quantity': '100 g',
#   'removed_countries_tags': [],
#   'rev': 55,
#   'scans_n': 32,
#   'selected_images': {'front': {'display': {'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.400.jpg'},
#     'small': {'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.200.jpg'},
#     'thumb': {'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/front_fr.52.100.jpg'}},
#    'ingredients': {'display': {'de': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_de.39.400.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_en.40.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_fr.33.400.jpg',
#      'nl': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_nl.38.400.jpg'},
#     'small': {'de': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_de.39.200.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_en.40.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_fr.33.200.jpg',
#      'nl': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_nl.38.200.jpg'},
#     'thumb': {'de': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_de.39.100.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_en.40.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_fr.33.100.jpg',
#      'nl': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/ingredients_nl.38.100.jpg'}},
#    'nutrition': {'display': {'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/nutrition_fr.54.400.jpg'},
#     'small': {'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/nutrition_fr.54.200.jpg'},
#     'thumb': {'fr': 'https://static.openfoodfacts.org/images/products/357/926/003/9398/nutrition_fr.54.100.jpg'}}},
#   'sortkey': 1591970818,
#   'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-completed, en:packaging-code-completed, en:characteristics-completed, en:origins-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#   'states_hierarchy': ['en:to-be-completed',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-completed',
#    'en:characteristics-completed',
#    'en:origins-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-to-be-validated',
#    'en:packaging-photo-to-be-selected',
#    'en:nutrition-photo-selected',
#    'en:ingredients-photo-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'states_tags': ['en:to-be-completed',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-completed',
#    'en:characteristics-completed',
#    'en:origins-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-to-be-validated',
#    'en:packaging-photo-to-be-selected',
#    'en:nutrition-photo-selected',
#    'en:ingredients-photo-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'stores': '',
#   'stores_tags': [],
#   'teams': 'stakano,chocolatine',
#   'teams_tags': ['stakano', 'chocolatine'],
#   'traces': 'en:celery,en:eggs,en:gluten,en:nuts,en:soybeans',
#   'traces_from_ingredients': '',
#   'traces_from_user': '(en) en:celery,en:eggs,en:gluten,en:nuts,en:soybeans',
#   'traces_hierarchy': ['en:celery',
#    'en:eggs',
#    'en:gluten',
#    'en:nuts',
#    'en:soybeans'],
#   'traces_lc': 'en',
#   'traces_tags': ['en:celery',
#    'en:eggs',
#    'en:gluten',
#    'en:nuts',
#    'en:soybeans'],
#   'unique_scans_n': 22,
#   'unknown_ingredients_n': 0,
#   'unknown_nutrients_tags': [],
#   'update_key': 'main-countries',
#   'url': 'https://world.openfoodfacts.org/product/3579260039398/mini-sticks-nature-auvernou',
#   'vitamins_prev_tags': [],
#   'vitamins_tags': []},
#  {'_id': '00726511300821001676',
#   '_keywords': ['punto',
#    'comida',
#    'verde',
#    'de',
#    'bonarea',
#    'crema',
#    'espinaca',
#    'preparada',
#    'origen',
#    'la',
#    'vegetal'],
#   'added_countries_tags': [],
#   'additives_n': 0,
#   'additives_old_n': 0,
#   'additives_old_tags': [],
#   'additives_original_tags': [],
#   'additives_tags': [],
#   'allergens': 'en:milk,en:nuts,es:Nata',
#   'allergens_from_ingredients': 'nata, leche, piñones',
#   'allergens_from_user': '(es) Leche,Frutos de cáscara,Nata',
#   'allergens_hierarchy': ['en:milk', 'en:nuts', 'es:Nata', 'es:nata'],
#   'allergens_lc': 'es',
#   'allergens_tags': ['en:milk', 'en:nuts', 'es:nata', 'es:nata'],
#   'amino_acids_tags': [],
#   'brands': 'Bonarea',
#   'brands_tags': ['bonarea'],
#   'categories': 'Comidas preparadas de origen vegetal',
#   'categories_hierarchy': ['en:plant-based-foods-and-beverages',
#    'en:plant-based-foods',
#    'en:meals',
#    'en:plant-based-meals'],
#   'categories_lc': 'es',
#   'categories_properties': {},
#   'categories_properties_tags': ['all-products',
#    'categories-known',
#    'agribalyse-food-code-unknown',
#    'agribalyse-proxy-food-code-unknown',
#    'ciqual-food-code-unknown',
#    'agribalyse-unknown'],
#   'categories_tags': ['en:plant-based-foods-and-beverages',
#    'en:plant-based-foods',
#    'en:meals',
#    'en:plant-based-meals'],
#   'checkers_tags': [],
#   'cities_tags': [],
#   'code': '00726511300821001676',
#   'codes_tags': ['code-20',
#    '00726511300821001xxx',
#    '0072651130082100xxxx',
#    '007265113008210xxxxx',
#    '00726511300821xxxxxx',
#    '0072651130082xxxxxxx',
#    '007265113008xxxxxxxx',
#    '00726511300xxxxxxxxx',
#    '0072651130xxxxxxxxxx',
#    '007265113xxxxxxxxxxx',
#    '00726511xxxxxxxxxxxx',
#    '0072651xxxxxxxxxxxxx',
#    '007265xxxxxxxxxxxxxx',
#    '00726xxxxxxxxxxxxxxx',
#    '0072xxxxxxxxxxxxxxxx',
#    '007xxxxxxxxxxxxxxxxx',
#    '00xxxxxxxxxxxxxxxxxx',
#    '0xxxxxxxxxxxxxxxxxxx'],
#   'compared_to_category': 'en:plant-based-meals',
#   'complete': 0,
#   'completeness': 0.8875,
#   'correctors_tags': ['alia', 'thaialagata'],
#   'countries': 'España',
#   'countries_hierarchy': ['en:spain'],
#   'countries_lc': 'es',
#   'countries_tags': ['en:spain'],
#   'created_t': 1620077789,
#   'creator': 'kiliweb',
#   'data_quality_bugs_tags': [],
#   'data_quality_errors_tags': [],
#   'data_quality_info_tags': ['en:packaging-data-incomplete',
#    'en:ingredients-percent-analysis-ok'],
#   'data_quality_tags': ['en:packaging-data-incomplete',
#    'en:ingredients-percent-analysis-ok',
#    'en:nutrition-value-very-high-for-category-saturated-fat',
#    'en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#    'en:ecoscore-packaging-packaging-data-missing',
#    'en:ecoscore-production-system-no-label'],
#   'data_quality_warnings_tags': ['en:nutrition-value-very-high-for-category-saturated-fat',
#    'en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#    'en:ecoscore-packaging-packaging-data-missing',
#    'en:ecoscore-production-system-no-label'],
#   'data_sources': 'App - yuka, Apps',
#   'data_sources_tags': ['app-yuka', 'apps'],
#   'debug_param_sorted_langs': ['es'],
#   'ecoscore_data': {'adjustments': {'origins_of_ingredients': {'aggregated_origins': [{'origin': 'en:unknown',
#        'percent': 100}],
#      'epi_score': 0,
#      'epi_value': -5,
#      'origins_from_origins_field': ['en:unknown'],
#      'transportation_score_be': 0,
#      'transportation_score_ch': 0,
#      'transportation_score_de': 0,
#      'transportation_score_es': 0,
#      'transportation_score_fr': 0,
#      'transportation_score_ie': 0,
#      'transportation_score_it': 0,
#      'transportation_score_lu': 0,
#      'transportation_score_nl': 0,
#      'transportation_value_be': 0,
#      'transportation_value_ch': 0,
#      'transportation_value_de': 0,
#      'transportation_value_es': 0,
#      'transportation_value_fr': 0,
#      'transportation_value_ie': 0,
#      'transportation_value_it': 0,
#      'transportation_value_lu': 0,
#      'transportation_value_nl': 0,
#      'value_be': -5,
#      'value_ch': -5,
#      'value_de': -5,
#      'value_es': -5,
#      'value_fr': -5,
#      'value_ie': -5,
#      'value_it': -5,
#      'value_lu': -5,
#      'value_nl': -5,
#      'warning': 'origins_are_100_percent_unknown'},
#     'packaging': {'non_recyclable_and_non_biodegradable_materials': 1,
#      'packagings': [{'ecoscore_material_score': 0,
#        'ecoscore_shape_ratio': 1,
#        'material': 'en:unknown',
#        'non_recyclable_and_non_biodegradable': 'maybe',
#        'shape': 'en:unknown'}],
#      'score': 0,
#      'value': -10,
#      'warning': 'packaging_data_missing'},
#     'production_system': {'warning': 'no_label'},
#     'threatened_species': {}},
#    'agribalyse': {'warning': 'missing_agribalyse_match'},
#    'missing': {'agb_category': 1, 'labels': 1, 'origins': 1, 'packagings': 1},
#    'missing_agribalyse_match_warning': 1,
#    'status': 'unknown'},
#   'ecoscore_grade': 'unknown',
#   'ecoscore_tags': ['unknown'],
#   'editors_tags': ['alia',
#    'yuka.sY2b0xO6T85zoF3NwEKvlkwZdsb8oCj4DUP6ohW69s3RNbb6QOhq_5DCGKo',
#    'thaialagata',
#    'roboto-app',
#    'kiliweb'],
#   'emb_codes': '',
#   'emb_codes_tags': [],
#   'entry_dates_tags': ['2021-05-03', '2021-05', '2021'],
#   'expiration_date': '23/05/2021',
#   'generic_name': 'Espinacas a la crema',
#   'generic_name_es': 'Espinacas a la crema',
#   'id': '00726511300821001676',
#   'image_front_small_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.200.jpg',
#   'image_front_thumb_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.100.jpg',
#   'image_front_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.400.jpg',
#   'image_ingredients_small_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.200.jpg',
#   'image_ingredients_thumb_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.100.jpg',
#   'image_ingredients_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.400.jpg',
#   'image_nutrition_small_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.200.jpg',
#   'image_nutrition_thumb_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.100.jpg',
#   'image_nutrition_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.400.jpg',
#   'image_small_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.200.jpg',
#   'image_thumb_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.100.jpg',
#   'image_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.400.jpg',
#   'images': {'1': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 1200, 'w': 900}},
#     'uploaded_t': 1620077789,
#     'uploader': 'kiliweb'},
#    '2': {'sizes': {'100': {'h': 100, 'w': 88},
#      '400': {'h': 400, 'w': 351},
#      'full': {'h': 1200, 'w': 1053}},
#     'uploaded_t': 1620077790,
#     'uploader': 'kiliweb'},
#    'front_es': {'angle': '0',
#     'coordinates_image_size': 'full',
#     'geometry': '0x0-0-0',
#     'imgid': '1',
#     'normalize': 'true',
#     'rev': '8',
#     'sizes': {'100': {'h': 100, 'w': 75},
#      '200': {'h': 200, 'w': 150},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 1200, 'w': 900}},
#     'white_magic': 'false',
#     'x1': '0',
#     'x2': '0',
#     'y1': '0',
#     'y2': '0'},
#    'ingredients_es': {'angle': '0',
#     'coordinates_image_size': 'full',
#     'geometry': '925x227-33-908',
#     'imgid': '2',
#     'normalize': 'true',
#     'rev': '9',
#     'sizes': {'100': {'h': 25, 'w': 100},
#      '200': {'h': 49, 'w': 200},
#      '400': {'h': 98, 'w': 400},
#      'full': {'h': 227, 'w': 925}},
#     'white_magic': 'false',
#     'x1': '33.03594771241827',
#     'x2': '958.5261437908497',
#     'y1': '908.148153467116',
#     'y2': '1135.5991338592728'},
#    'nutrition_es': {'angle': '0',
#     'coordinates_image_size': 'full',
#     'geometry': '541x272-77-439',
#     'imgid': '2',
#     'normalize': 'true',
#     'rev': '10',
#     'sizes': {'100': {'h': 50, 'w': 100},
#      '200': {'h': 101, 'w': 200},
#      '400': {'h': 201, 'w': 400},
#      'full': {'h': 272, 'w': 541}},
#     'white_magic': 'false',
#     'x1': '77.48039215686272',
#     'x2': '618.656862745098',
#     'y1': '439.8257186989379',
#     'y2': '711.7211435355392'}},
#   'informers_tags': ['yuka.sY2b0xO6T85zoF3NwEKvlkwZdsb8oCj4DUP6ohW69s3RNbb6QOhq_5DCGKo',
#    'kiliweb',
#    'roboto-app',
#    'alia'],
#   'ingredients': [{'id': 'en:spinach',
#     'ingredients': [{'id': 'en:spinach',
#       'percent_estimate': 32.5,
#       'percent_max': 52,
#       'percent_min': 13,
#       'text': 'espinacas',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'from_palm_oil': 'no',
#       'id': 'en:sunflower-oil',
#       'percent_estimate': 9.75,
#       'percent_max': 26,
#       'percent_min': 0,
#       'text': 'aceite de girasol',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'id': 'en:garlic',
#       'percent_estimate': 4.875,
#       'percent_max': 17.3333333333333,
#       'percent_min': 0,
#       'text': 'ajo',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'id': 'en:salt',
#       'percent_estimate': 4.875,
#       'percent_max': 13,
#       'percent_min': 0,
#       'text': 'sal',
#       'vegan': 'yes',
#       'vegetarian': 'yes'}],
#     'percent': 52,
#     'percent_estimate': 52,
#     'percent_max': 52,
#     'percent_min': 52,
#     'text': 'Espinacas',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:cream',
#     'ingredients': [{'id': 'en:pasteurized-cream',
#       'percent_estimate': 23.4285714285714,
#       'percent_max': 41,
#       'percent_min': 5.85714285714286,
#       'text': '_nata_ pasteurizada',
#       'vegan': 'no',
#       'vegetarian': 'yes'},
#      {'id': 'en:water',
#       'percent_estimate': 8.78571428571429,
#       'percent_max': 20.5,
#       'percent_min': 0,
#       'text': 'agua',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'id': 'en:rice-flour',
#       'percent_estimate': 4.39285714285714,
#       'percent_max': 13.6666666666667,
#       'percent_min': 0,
#       'text': 'harina de arroz',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'id': 'en:starch',
#       'percent_estimate': 2.19642857142857,
#       'percent_max': 10.25,
#       'percent_min': 0,
#       'text': 'almidón',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'id': 'en:salt',
#       'percent_estimate': 1.09821428571428,
#       'percent_max': 8.2,
#       'percent_min': 0,
#       'text': 'sal',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'id': 'en:flavouring',
#       'ingredients': [{'id': 'en:milk',
#         'percent_estimate': 0.549107142857142,
#         'percent_max': 6.83333333333333,
#         'percent_min': 0,
#         'text': '_leche_',
#         'vegan': 'no',
#         'vegetarian': 'yes'}],
#       'percent_estimate': 0.549107142857142,
#       'percent_max': 6.83333333333333,
#       'percent_min': 0,
#       'text': 'aromas',
#       'vegan': 'maybe',
#       'vegetarian': 'maybe'},
#      {'id': 'en:nutmeg',
#       'percent_estimate': 0.549107142857139,
#       'percent_max': 5.85714285714286,
#       'percent_min': 0,
#       'text': 'nuez moscada',
#       'vegan': 'yes',
#       'vegetarian': 'yes'}],
#     'percent': 41,
#     'percent_estimate': 41,
#     'percent_max': 41,
#     'percent_min': 41,
#     'text': 'crema',
#     'vegan': 'no',
#     'vegetarian': 'yes'},
#    {'id': 'en:raisin',
#     'percent_estimate': 4.375,
#     'percent_max': 7,
#     'percent_min': 1.75,
#     'text': 'pasas',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:pine-nuts',
#     'percent_estimate': 1.3125,
#     'percent_max': 3.5,
#     'percent_min': 0,
#     'text': 'piñones',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:starch',
#     'percent_estimate': 0.65625,
#     'percent_max': 2.33333333333333,
#     'percent_min': 0,
#     'text': 'almidón',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:salt',
# ...
#    'ingredients': {'display': {'fr': 'https://static.openfoodfacts.org/images/products/330/274/859/9028/ingredients_fr.55.400.jpg'},
#     'small': {'fr': 'https://static.openfoodfacts.org/images/products/330/274/859/9028/ingredients_fr.55.200.jpg'},
#     'thumb': {'fr': 'https://static.openfoodfacts.org/images/products/330/274/859/9028/ingredients_fr.55.100.jpg'}},
#    'nutrition': {'display': {'fr': 'https://static.openfoodfacts.org/images/products/330/274/859/9028/nutrition_fr.56.400.jpg'},
#     'small': {'fr': 'https://static.openfoodfacts.org/images/products/330/274/859/9028/nutrition_fr.56.200.jpg'},
#     'thumb': {'fr': 'https://static.openfoodfacts.org/images/products/330/274/859/9028/nutrition_fr.56.100.jpg'}}},
#   'serving_quantity': 280,
#   'serving_size': '280g',
#   'sortkey': 1603897303,
#   'sources': [{'fields': ['product_name_fr'],
#     'id': 'fleurymichon',
#     'images': ['3', '4', '5', '6'],
#     'import_t': 1504555510,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': ['product_name_fr', 'ingredients_text_fr'],
#     'id': 'fleurymichon',
#     'images': ['11', '12', '13'],
#     'import_t': 1528116436,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': ['product_name_fr', 'quantity', 'ingredients_text_fr'],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1550337673,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1561181806,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': ['ingredients_text_fr'],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1598508218,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': ['ingredients_text_fr'],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1599200505,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1601963723,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1613113171,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': ['product_name_fr'],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1617344152,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': ['ingredients_text_fr'],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1617428836,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1617516395,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1617602079,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1617689242,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1617774448,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1617862437,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1617947186,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618033674,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618121561,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618210075,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618292839,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618381201,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618469220,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618552013,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618638707,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618727083,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618815110,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618901352,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1618984446,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619074588,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619157002,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619243557,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619331408,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619418815,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619506267,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619588903,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619677599,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619765266,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619848065,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1619936415,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620023662,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620107190,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620196086,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620283242,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620369701,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620452800,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620540830,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620629048,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620711961,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620801531,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620886439,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1620971233,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621057720,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621145226,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621232487,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621321590,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621411618,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621490073,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621578962,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621662851,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621750294,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621838141,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1621923927,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1622007996,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1622097575,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1622181013,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1622267281,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1622354992,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'},
#    {'fields': [],
#     'id': 'fleurymichon',
#     'images': [],
#     'import_t': 1622443174,
#     'manufacturer': 1,
#     'name': 'Fleury Michon',
#     'url': 'https://www.fleurymichon.fr'}],
#   'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-completed, en:packaging-code-completed, en:characteristics-completed, en:origins-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#   'states_hierarchy': ['en:to-be-completed',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-completed',
#    'en:characteristics-completed',
#    'en:origins-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-to-be-validated',
#    'en:packaging-photo-to-be-selected',
#    'en:nutrition-photo-selected',
#    'en:ingredients-photo-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'states_tags': ['en:to-be-completed',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-completed',
#    'en:characteristics-completed',
#    'en:origins-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-to-be-validated',
#    'en:packaging-photo-to-be-selected',
#    'en:nutrition-photo-selected',
#    'en:ingredients-photo-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'stores': 'Leclerc,Magasins U,Carrefour',
#   'stores_tags': ['leclerc', 'magasins-u', 'carrefour'],
#   'teams': 'chocolatine,la-robe-est-bleue',
#   'teams_tags': ['chocolatine', 'la-robe-est-bleue'],
#   'traces': 'en:eggs,fr:Aretes',
#   'traces_from_ingredients': '',
#   'traces_from_user': '(en) en:eggs,fr:Aretes',
#   'traces_hierarchy': ['en:eggs', 'fr:Aretes'],
#   'traces_lc': 'en',
#   'traces_tags': ['en:eggs', 'fr:aretes'],
#   'unique_scans_n': 16,
#   'unknown_ingredients_n': 1,
#   'unknown_nutrients_tags': [],
#   'update_key': 'main-countries',
#   'url': 'https://world.openfoodfacts.org/product/3302748599028/filet-de-saumon-pates-au-basilic-sauce-citron-fleury-michon',
#   'vitamins_prev_tags': [],
#   'vitamins_tags': []}]

# %%
products = openfoodfacts.products.get_by_country('France')
print(len(products))
products[0:5]
# Out:
# 24
# [{'_id': '5470188071102',
#   '_keywords': ['alvalle', 'gaspacho'],
#   'added_countries_tags': [],
#   'allergens': '',
#   'allergens_from_ingredients': '',
#   'allergens_from_user': '(fr) ',
#   'allergens_hierarchy': [],
#   'allergens_tags': [],
#   'brands': 'Alvalle',
#   'brands_tags': ['alvalle'],
#   'categories_properties': {},
#   'categories_properties_tags': ['all-products',
#    'categories-unknown',
#    'agribalyse-food-code-unknown',
#    'agribalyse-proxy-food-code-unknown',
#    'ciqual-food-code-unknown',
#    'agribalyse-unknown'],
#   'checkers_tags': [],
#   'code': '5470188071102',
#   'codes_tags': ['code-13',
#    '5470188071xxx',
#    '547018807xxxx',
#    '54701880xxxxx',
#    '5470188xxxxxx',
#    '547018xxxxxxx',
#    '54701xxxxxxxx',
#    '5470xxxxxxxxx',
#    '547xxxxxxxxxx',
#    '54xxxxxxxxxxx',
#    '5xxxxxxxxxxxx'],
#   'complete': 0,
#   'completeness': 0.2,
#   'correctors_tags': [],
#   'countries': 'en:france',
#   'countries_hierarchy': ['en:france'],
#   'countries_tags': ['en:france'],
#   'created_t': 1622454217,
#   'creator': 'nutrinet-sante',
#   'data_quality_bugs_tags': [],
#   'data_quality_errors_tags': [],
#   'data_quality_info_tags': ['en:packaging-data-incomplete'],
#   'data_quality_tags': ['en:packaging-data-incomplete',
#    'en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#    'en:ecoscore-packaging-packaging-data-missing',
#    'en:ecoscore-production-system-no-label',
#    'en:ecoscore-threatened-species-ingredients-missing'],
#   'data_quality_warnings_tags': ['en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#    'en:ecoscore-packaging-packaging-data-missing',
#    'en:ecoscore-production-system-no-label',
#    'en:ecoscore-threatened-species-ingredients-missing'],
#   'ecoscore_data': {'adjustments': {'origins_of_ingredients': {'aggregated_origins': [{'origin': 'en:unknown',
#        'percent': 100}],
#      'epi_score': 0,
#      'epi_value': -5,
#      'origins_from_origins_field': ['en:unknown'],
#      'transportation_score_be': 0,
#      'transportation_score_ch': 0,
#      'transportation_score_de': 0,
#      'transportation_score_es': 0,
#      'transportation_score_fr': 0,
#      'transportation_score_ie': 0,
#      'transportation_score_it': 0,
#      'transportation_score_lu': 0,
#      'transportation_score_nl': 0,
#      'transportation_value_be': 0,
#      'transportation_value_ch': 0,
#      'transportation_value_de': 0,
#      'transportation_value_es': 0,
#      'transportation_value_fr': 0,
#      'transportation_value_ie': 0,
#      'transportation_value_it': 0,
#      'transportation_value_lu': 0,
#      'transportation_value_nl': 0,
#      'value_be': -5,
#      'value_ch': -5,
#      'value_de': -5,
#      'value_es': -5,
#      'value_fr': -5,
#      'value_ie': -5,
#      'value_it': -5,
#      'value_lu': -5,
#      'value_nl': -5,
#      'warning': 'origins_are_100_percent_unknown'},
#     'packaging': {'non_recyclable_and_non_biodegradable_materials': 1,
#      'packagings': [{'ecoscore_material_score': 0,
#        'ecoscore_shape_ratio': 1,
#        'material': 'en:unknown',
#        'non_recyclable_and_non_biodegradable': 'maybe',
#        'shape': 'en:unknown'}],
#      'score': 0,
#      'value': -10,
#      'warning': 'packaging_data_missing'},
#     'production_system': {'warning': 'no_label'},
#     'threatened_species': {'warning': 'ingredients_missing'}},
#    'agribalyse': {'warning': 'missing_agribalyse_match'},
#    'missing': {'categories': 1,
#     'ingredients': 1,
#     'labels': 1,
#     'origins': 1,
#     'packagings': 1},
#    'missing_agribalyse_match_warning': 1,
#    'status': 'unknown'},
#   'ecoscore_grade': 'unknown',
#   'ecoscore_tags': ['unknown'],
#   'editors_tags': ['nutrinet-sante'],
#   'entry_dates_tags': ['2021-05-31', '2021-05', '2021'],
#   'id': '5470188071102',
#   'informers_tags': ['nutrinet-sante'],
#   'interface_version_created': '20150316.jqm2',
#   'interface_version_modified': '20150316.jqm2',
#   'lang': 'fr',
#   'languages': {'en:french': 1},
#   'languages_codes': {'fr': 1},
#   'languages_hierarchy': ['en:french'],
#   'languages_tags': ['en:french', 'en:1'],
#   'last_edit_dates_tags': ['2021-05-31', '2021-05', '2021'],
#   'last_editor': 'nutrinet-sante',
#   'last_modified_by': 'nutrinet-sante',
#   'last_modified_t': 1622454217,
#   'lc': 'fr',
#   'main_countries_tags': [],
#   'misc_tags': ['en:nutriscore-not-computed',
#    'en:nutriscore-missing-category',
#    'en:ecoscore-not-computed',
#    'en:main-countries-new-product'],
#   'nova_group_debug': 'no nova group when the product does not have ingredients',
#   'nova_group_tags': ['not-applicable'],
#   'nutrient_levels': {},
#   'nutrient_levels_tags': [],
#   'nutriments': {},
#   'nutrition_data_per': '100g',
#   'nutrition_data_prepared_per': '100g',
#   'nutrition_grades_tags': ['unknown'],
#   'nutrition_score_debug': 'no score when the product does not have a category',
#   'packagings': [{'material': 'en:unknown', 'shape': 'en:unknown'}],
#   'photographers_tags': [],
#   'pnns_groups_1': 'unknown',
#   'pnns_groups_1_tags': ['unknown', 'missing-category'],
#   'pnns_groups_2': 'unknown',
#   'pnns_groups_2_tags': ['unknown', 'missing-category'],
#   'popularity_key': 0,
#   'product_name': 'Gaspacho',
#   'product_name_fr': 'Gaspacho',
#   'removed_countries_tags': [],
#   'rev': 1,
#   'states': 'en:to-be-completed, en:nutrition-facts-to-be-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:origins-to-be-completed, en:categories-to-be-completed, en:brands-completed, en:packaging-to-be-completed, en:quantity-to-be-completed, en:product-name-completed, en:photos-to-be-uploaded',
#   'states_hierarchy': ['en:to-be-completed',
#    'en:nutrition-facts-to-be-completed',
#    'en:ingredients-to-be-completed',
#    'en:expiration-date-to-be-completed',
#    'en:packaging-code-to-be-completed',
#    'en:characteristics-to-be-completed',
#    'en:origins-to-be-completed',
#    'en:categories-to-be-completed',
#    'en:brands-completed',
#    'en:packaging-to-be-completed',
#    'en:quantity-to-be-completed',
#    'en:product-name-completed',
#    'en:photos-to-be-uploaded'],
#   'states_tags': ['en:to-be-completed',
#    'en:nutrition-facts-to-be-completed',
#    'en:ingredients-to-be-completed',
#    'en:expiration-date-to-be-completed',
#    'en:packaging-code-to-be-completed',
#    'en:characteristics-to-be-completed',
#    'en:origins-to-be-completed',
#    'en:categories-to-be-completed',
#    'en:brands-completed',
#    'en:packaging-to-be-completed',
#    'en:quantity-to-be-completed',
#    'en:product-name-completed',
#    'en:photos-to-be-uploaded'],
#   'traces': '',
#   'traces_from_ingredients': '',
#   'traces_from_user': '(fr) ',
#   'traces_hierarchy': [],
#   'traces_tags': [],
#   'unknown_nutrients_tags': [],
#   'url': 'https://world.openfoodfacts.org/product/5470188071102/gaspacho-alvalle'},
#  {'_id': '8414100244059',
#   '_keywords': ['tonica',
#    'no',
#    'soda',
#    'bebida',
#    'green-dot',
#    'alcoholica',
#    'carbonatada',
#    'schweppe',
#    'azucarada'],
#   'added_countries_tags': [],
#   'additives_debug_tags': [],
#   'additives_old_tags': [],
#   'additives_original_tags': [],
#   'additives_prev_original_tags': [],
#   'additives_tags': [],
#   'allergens': '',
#   'allergens_debug_tags': [],
#   'allergens_from_ingredients': '',
#   'allergens_from_user': '(fr) ',
#   'allergens_hierarchy': [],
#   'allergens_lc': 'fr',
#   'allergens_tags': [],
#   'amino_acids_prev_tags': [],
#   'amino_acids_tags': [],
#   'brands': 'Schweppes',
#   'brands_tags': ['schweppes'],
#   'categories': 'Bebidas, Bebidas carbonatadas, Sodas, Bebidas no alcohólicas, Tónica, Bebidas azucaradas',
#   'categories_hierarchy': ['en:beverages',
#    'en:carbonated-drinks',
#    'en:sodas',
#    'en:non-alcoholic-beverages',
#    'en:tonic-water',
#    'en:sweetened-beverages'],
#   'categories_lc': 'es',
#   'categories_old': 'Bebidas, Bebidas carbonatadas, Sodas, Bebidas no alcohólicas, en:Tonic water, Bebidas azucaradas',
#   'categories_properties': {'agribalyse_proxy_food_code:en': '18344',
#    'ciqual_food_code:en': '18029'},
#   'categories_properties_tags': ['all-products',
#    'categories-known',
#    'agribalyse-food-code-unknown',
#    'agribalyse-proxy-food-code-18344',
#    'agribalyse-proxy-food-code-known',
#    'ciqual-food-code-18029',
#    'ciqual-food-code-known',
#    'agribalyse-known',
#    'agribalyse-18344'],
#   'categories_tags': ['en:beverages',
#    'en:carbonated-drinks',
#    'en:sodas',
#    'en:non-alcoholic-beverages',
#    'en:tonic-water',
#    'en:sweetened-beverages'],
#   'category_properties': {'ciqual_food_name:en': 'Non-alcoholic beverage -average-',
#    'ciqual_food_name:fr': 'Boisson rafraîchissante sans alcool -aliment moyen-'},
#   'checkers_tags': [],
#   'ciqual_food_name_tags': ['non-alcoholic-beverage-average'],
#   'cities_tags': [],
#   'code': '8414100244059',
#   'codes_tags': ['code-13',
#    '8414100244xxx',
#    '841410024xxxx',
#    '84141002xxxxx',
#    '8414100xxxxxx',
#    '841410xxxxxxx',
#    '84141xxxxxxxx',
#    '8414xxxxxxxxx',
#    '841xxxxxxxxxx',
#    '84xxxxxxxxxxx',
#    '8xxxxxxxxxxxx'],
#   'compared_to_category': 'en:sweetened-beverages',
#   'complete': 0,
#   'completeness': 0.5875,
#   'correctors_tags': ['openfoodfacts-contributors',
#    'elpatriarca34',
#    'autorotate-bot',
#    'scanbot',
#    'alia'],
#   'countries': 'Francia, en:spain',
#   'countries_beforescanbot': 'Francia',
#   'countries_hierarchy': ['en:france', 'en:spain'],
#   'countries_lc': 'es',
#   'countries_tags': ['en:france', 'en:spain'],
#   'created_t': 1528575105,
#   'creator': 'kiliweb',
#   'data_quality_bugs_tags': [],
#   'data_quality_errors_tags': [],
#   'data_quality_info_tags': ['en:no-packaging-data',
#    'en:ingredients-percent-analysis-ok'],
#   'data_quality_tags': ['en:no-packaging-data',
#    'en:ingredients-percent-analysis-ok',
#    'en:nutrition-value-under-0-1-g-salt'],
#   'data_quality_warnings_tags': ['en:nutrition-value-under-0-1-g-salt'],
#   'data_sources': 'App - yuka, Apps',
#   'data_sources_tags': ['app-yuka', 'apps'],
#   'debug_param_sorted_langs': ['fr'],
#   'ecoscore_data': {'adjustments': {},
#    'ecoscore_not_applicable_for_category': 'en:sodas',
#    'status': 'unknown'},
#   'ecoscore_grade': 'not-applicable',
#   'ecoscore_tags': ['not-applicable'],
#   'editors_tags': ['openfoodfacts-contributors',
#    'alia',
#    'laramba',
#    'scanbot',
#    'cyn',
#    'autorotate-bot',
#    'yuka.ZW9VWkxwNFFxT0k0djhJaC9DTE40TUFyemE2MlpWTzZPdU5QSVE9PQ',
#    'elpatriarca34',
#    'kiliweb'],
#   'emb_codes': '',
#   'emb_codes_orig': '',
#   'emb_codes_tags': [],
#   'entry_dates_tags': ['2018-06-09', '2018-06', '2018'],
#   'expiration_date': '',
#   'expiration_date_debug_tags': [],
#   'generic_name': '',
#   'generic_name_fr': '',
#   'generic_name_fr_debug_tags': [],
#   'id': '8414100244059',
#   'image_front_small_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.200.jpg',
#   'image_front_thumb_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.100.jpg',
#   'image_front_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.400.jpg',
#   'image_ingredients_small_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_es.26.200.jpg',
#   'image_ingredients_thumb_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_es.26.100.jpg',
#   'image_ingredients_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_es.26.400.jpg',
#   'image_nutrition_small_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_es.27.200.jpg',
#   'image_nutrition_thumb_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_es.27.100.jpg',
#   'image_nutrition_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_es.27.400.jpg',
#   'image_small_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.200.jpg',
#   'image_thumb_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.100.jpg',
#   'image_url': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.400.jpg',
#   'images': {'1': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 1200, 'w': 901}},
#     'uploaded_t': '1528575107',
#     'uploader': 'kiliweb'},
#    '2': {'sizes': {'100': {'h': 70, 'w': 100},
#      '400': {'h': 282, 'w': 400},
#      'full': {'h': 1200, 'w': 1703}},
#     'uploaded_t': '1528575115',
#     'uploader': 'kiliweb'},
#    '3': {'sizes': {'100': {'h': 100, 'w': 93},
#      '400': {'h': 400, 'w': 371},
#      'full': {'h': 1453, 'w': 1346}},
#     'uploaded_t': 1553091587,
#     'uploader': 'elpatriarca34'},
#    '4': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 4000, 'w': 3000}},
#     'uploaded_t': 1586954338,
#     'uploader': 'openfoodfacts-contributors'},
#    '5': {'sizes': {'100': {'h': 100, 'w': 28},
#      '400': {'h': 400, 'w': 114},
#      'full': {'h': 4613, 'w': 1314}},
#     'uploaded_t': 1620149820,
#     'uploader': 'laramba'},
#    '6': {'sizes': {'100': {'h': 100, 'w': 57},
#      '400': {'h': 400, 'w': 229},
#      'full': {'h': 2177, 'w': 1249}},
#     'uploaded_t': 1620149859,
#     'uploader': 'laramba'},
#    '7': {'sizes': {'100': {'h': 100, 'w': 82},
#      '400': {'h': 400, 'w': 329},
#      'full': {'h': 1761, 'w': 1450}},
#     'uploaded_t': 1620149879,
#     'uploader': 'laramba'},
#    '8': {'sizes': {'100': {'h': 100, 'w': 74},
#      '400': {'h': 400, 'w': 298},
#      'full': {'h': 1650, 'w': 1229}},
#     'uploaded_t': 1620149904,
#     'uploader': 'laramba'},
#    'front_es': {'angle': '0',
#     'coordinates_image_size': 'full',
#     'geometry': '0x0-0-0',
#     'imgid': '5',
#     'normalize': 'true',
#     'rev': '24',
#     'sizes': {'100': {'h': 100, 'w': 28},
#      '200': {'h': 200, 'w': 57},
#      '400': {'h': 400, 'w': 114},
#      'full': {'h': 4613, 'w': 1314}},
#     'white_magic': 'false',
#     'x1': '0',
#     'x2': '0',
#     'y1': '0',
#     'y2': '0'},
#    'front_fr': {'angle': None,
#     'geometry': '0x0-0-0',
#     'imgid': '1',
#     'normalize': '0',
#     'rev': '4',
#     'sizes': {'100': {'h': 100, 'w': 75},
#      '200': {'h': 200, 'w': 150},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 1200, 'w': 901}},
#     'white_magic': '0',
#     'x1': None,
#     'x2': None,
#     'y1': None,
#     'y2': None},
#    'front_pt': {'angle': 0,
#     'coordinates_image_size': 'full',
#     'geometry': '0x0--1--1',
#     'imgid': '5',
#     'normalize': None,
#     'rev': '19',
#     'sizes': {'100': {'h': 100, 'w': 28},
#      '200': {'h': 200, 'w': 57},
#      '400': {'h': 400, 'w': 114},
#      'full': {'h': 4613, 'w': 1314}},
#     'white_magic': None,
#     'x1': '-1',
#     'x2': '-1',
#     'y1': '-1',
#     'y2': '-1'},
#    'ingredients_es': {'angle': '0',
#     'coordinates_image_size': 'full',
#     'geometry': '894x330-204-463',
#     'imgid': '7',
#     'normalize': 'true',
#     'rev': '26',
#     'sizes': {'100': {'h': 37, 'w': 100},
#      '200': {'h': 74, 'w': 200},
#      '400': {'h': 148, 'w': 400},
#      'full': {'h': 330, 'w': 894}},
#     'white_magic': 'false',
#     'x1': '204.18137254901958',
#     'x2': '1098.109477124183',
#     'y1': '463.33353558708643',
#     'y2': '793.2812480053872'},
#    'ingredients_fr': {'angle': -270,
#     'geometry': '0x0--4--4',
#     'imgid': '2',
#     'normalize': None,
#     'rev': '14',
#     'sizes': {'100': {'h': 100, 'w': 70},
#      '200': {'h': 200, 'w': 141},
#      '400': {'h': 400, 'w': 282},
#      'full': {'h': 1703, 'w': 1200}},
#     'white_magic': None,
#     'x1': '-1',
#     'x2': '-1',
#     'y1': '-1',
#     'y2': '-1'},
#    'nutrition_es': {'angle': 0,
#     'coordinates_image_size': 'full',
#     'geometry': '977x1043-9-240',
#     'imgid': '6',
#     'normalize': 'true',
#     'rev': 27,
#     'sizes': {'100': {'h': 100, 'w': 94},
#      '200': {'h': 200, 'w': 187},
#      '400': {'h': 400, 'w': 375},
#      'full': {'h': 1043, 'w': 977}},
#     'white_magic': 'false',
#     'x1': 9.10620915032682,
#     'x2': 986.147603485839,
#     'y1': 240.149808796403,
#     'y2': 1283.59207459161},
#    'nutrition_fr': {'angle': None,
#     'geometry': '0x0-0-0',
#     'imgid': '3',
#     'normalize': None,
#     'ocr': 1,
#     'orientation': '0',
#     'rev': '11',
#     'sizes': {'100': {'h': 100, 'w': 93},
#      '200': {'h': 200, 'w': 185},
#      '400': {'h': 400, 'w': 371},
#      'full': {'h': 1453, 'w': 1346}},
#     'white_magic': None,
#     'x1': None,
#     'x2': None,
#     'y1': None,
#     'y2': None}},
#   'informers_tags': ['yuka.ZW9VWkxwNFFxT0k0djhJaC9DTE40TUFyemE2MlpWTzZPdU5QSVE9PQ',
#    'kiliweb',
#    'cyn',
#    'elpatriarca34',
#    'autorotate-bot',
#    'openfoodfacts-contributors',
#    'laramba',
#    'alia'],
#   'ingredients': [],
#   'ingredients_debug': [],
#   'ingredients_from_palm_oil_tags': [],
#   'ingredients_hierarchy': [],
#   'ingredients_ids_debug': [],
#   'ingredients_original_tags': [],
#   'ingredients_tags': [],
#   'ingredients_text': '',
#   'ingredients_text_debug': '',
#   'ingredients_text_es': '',
#   'ingredients_text_fr': '',
#   'ingredients_text_with_allergens': '',
#   'ingredients_text_with_allergens_es': '',
#   'ingredients_text_with_allergens_fr': '',
#   'ingredients_that_may_be_from_palm_oil_tags': [],
#   'interface_version_created': '20150316.jqm2',
#   'interface_version_modified': '20150316.jqm2',
#   'labels': 'en:green-dot',
#   'labels_hierarchy': ['en:green-dot'],
#   'labels_lc': 'en',
#   'labels_tags': ['en:green-dot'],
#   'lang': 'es',
#   'languages': {'en:french': 4, 'en:portuguese': 1, 'en:spanish': 3},
#   'languages_codes': {'es': 3, 'fr': 4, 'pt': 1},
#   'languages_hierarchy': ['en:spanish', 'en:french', 'en:portuguese'],
#   'languages_tags': ['en:spanish',
#    'en:french',
#    'en:portuguese',
#    'en:3',
#    'en:multilingual'],
#   'last_edit_dates_tags': ['2021-05-31', '2021-05', '2021'],
#   'last_editor': 'alia',
#   'last_image_dates_tags': ['2021-05-04', '2021-05', '2021'],
#   'last_image_t': 1620149904,
#   'last_modified_by': 'alia',
#   'last_modified_t': 1622454180,
#   'lc': 'es',
#   'link': '',
#   'main_countries_tags': [],
#   'manufacturing_places': '',
#   'manufacturing_places_tags': [],
#   'max_imgid': '8',
#   'minerals_prev_tags': [],
#   'minerals_tags': [],
#   'misc_tags': ['en:nutrition-no-fruits-vegetables-nuts',
#    'en:nutrition-no-fiber-or-fruits-vegetables-nuts',
#    'en:nutriscore-computed',
#    'en:ecoscore-not-applicable',
#    'en:ecoscore-not-computed',
#    'en:main-countries-fr-unexpectedly-low-scans',
#    'en:main-countries-fr-unexpectedly-low-scans-0-10-percent-of-expected',
#    'en:main-countries-fr-unexpectedly-low-scans-and-only-1-field-in-country-language',
#    'en:main-countries-fr-ingredients-not-in-country-language',
#    'en:main-countries-fr-only-1-field-in-country-language',
#    'en:main-countries-es-product-name-not-in-country-language',
#    'en:main-countries-es-ingredients-not-in-country-language',
#    'en:main-countries-es-no-data-in-country-language'],
#   'no_nutrition_data': '',
#   'nova_group_debug': 'no nova group when the product does not have ingredients',
#   'nova_group_tags': ['not-applicable'],
#   'nucleotides_prev_tags': [],
#   'nucleotides_tags': [],
#   'nutrient_levels': {'fat': 'low',
#    'salt': 'low',
#    'saturated-fat': 'low',
#    'sugars': 'high'},
#   'nutrient_levels_tags': ['en:fat-in-low-quantity',
#    'en:saturated-fat-in-low-quantity',
#    'en:sugars-in-high-quantity',
#    'en:salt-in-low-quantity'],
#   'nutriments': {'carbohydrates': 8.5,
#    'carbohydrates_100g': 8.5,
#    'carbohydrates_serving': 8.5,
#    'carbohydrates_unit': 'g',
#    'carbohydrates_value': 8.5,
#    'energy': 151,
#    'energy-kcal': 36,
#    'energy-kcal_100g': 36,
#    'energy-kcal_serving': 36,
#    'energy-kcal_unit': 'kcal',
#    'energy-kcal_value': 36,
#    'energy_100g': 151,
#    'energy_serving': 151,
#    'energy_unit': 'kcal',
#    'energy_value': 36,
#    'fat': 0,
#    'fat_100g': 0,
#    'fat_serving': 0,
#    'fat_unit': 'g',
#    'fat_value': 0,
#    'nutrition-score-fr': 12,
#    'nutrition-score-fr_100g': 12,
#    'proteins': 0,
#    'proteins_100g': 0,
#    'proteins_serving': 0,
#    'proteins_unit': 'g',
#    'proteins_value': 0,
#    'salt': 0.03,
#    'salt_100g': 0.03,
#    'salt_serving': 0.03,
#    'salt_unit': 'g',
#    'salt_value': 0.03,
#    'saturated-fat': 0,
#    'saturated-fat_100g': 0,
#    'saturated-fat_serving': 0,
#    'saturated-fat_unit': 'g',
#    'saturated-fat_value': 0,
#    'sodium': 0.012,
#    'sodium_100g': 0.012,
#    'sodium_serving': 0.012,
#    'sodium_unit': 'g',
#    'sodium_value': 0.012,
#    'sugars': 8.4,
#    'sugars_100g': 8.4,
#    'sugars_serving': 8.4,
#    'sugars_unit': 'g',
#    'sugars_value': 8.4},
#   'nutriscore_data': {'energy': 151,
#    'energy_points': 6,
#    'energy_value': 151,
#    'fiber': 0,
#    'fiber_points': 0,
#    'fiber_value': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 0,
#    'grade': 'e',
#    'is_beverage': 1,
#    'is_cheese': 0,
#    'is_fat': 0,
#    'is_water': 0,
#    'negative_points': 12,
#    'positive_points': 0,
#    'proteins': 0,
#    'proteins_points': 0,
#    'proteins_value': 0,
#    'saturated_fat': 0,
#    'saturated_fat_points': 0,
#    'saturated_fat_ratio': 0,
#    'saturated_fat_ratio_points': 0,
#    'saturated_fat_ratio_value': 0,
#    'saturated_fat_value': 0,
#    'score': 12,
#    'sodium': 12,
#    'sodium_points': 0,
#    'sodium_value': 12,
#    'sugars': 8.4,
#    'sugars_points': 6,
#    'sugars_value': 8.4},
#   'nutriscore_grade': 'e',
#   'nutriscore_score': 12,
#   'nutriscore_score_opposite': -12,
#   'nutrition_data': 'on',
#   'nutrition_data_per': '100g',
#   'nutrition_data_prepared': '',
#   'nutrition_data_prepared_per': '100g',
#   'nutrition_data_prepared_per_debug_tags': [],
#   'nutrition_grade_fr': 'e',
#   'nutrition_grades': 'e',
#   'nutrition_grades_tags': ['e'],
#   'nutrition_score_beverage': 1,
#   'nutrition_score_warning_no_fruits_vegetables_nuts': 1,
#   'origins': '',
#   'origins_hierarchy': [],
#   'origins_lc': 'es',
#   'origins_old': '',
#   'origins_tags': [],
#   'other_nutritional_substances_tags': [],
#   'packaging': 'Botella de Cristal',
#   'packaging_tags': ['botella-de-cristal'],
#   'packagings': [],
#   'photographers_tags': ['kiliweb',
#    'elpatriarca34',
#    'openfoodfacts-contributors',
#    'laramba'],
#   'pnns_groups_1': 'Beverages',
#   'pnns_groups_1_tags': ['beverages', 'known'],
#   'pnns_groups_2': 'Sweetened beverages',
#   'pnns_groups_2_tags': ['sweetened-beverages', 'known'],
#   'popularity_key': 19900000022,
#   'popularity_tags': ['top-50000-scans-2019',
#    'top-100000-scans-2019',
#    'at-least-5-scans-2019',
#    'at-least-10-scans-2019',
#    'top-75-percent-scans-2019',
#    'top-80-percent-scans-2019',
#    'top-85-percent-scans-2019',
#    'top-90-percent-scans-2019',
#    'top-5000-es-scans-2019',
#    'top-10000-es-scans-2019',
#    'top-50000-es-scans-2019',
#    'top-100000-es-scans-2019',
#    'top-country-es-scans-2019',
#    'at-least-5-es-scans-2019',
#    'at-least-10-es-scans-2019',
#    'top-5000-pt-scans-2019',
#    'top-10000-pt-scans-2019',
#    'top-50000-pt-scans-2019',
#    'top-100000-pt-scans-2019',
#    'top-50000-it-scans-2019',
#    'top-100000-it-scans-2019',
#    'top-100000-scans-2020',
#    'at-least-5-scans-2020',
#    'at-least-10-scans-2020',
#    'top-75-percent-scans-2020',
#    'top-80-percent-scans-2020',
#    'top-85-percent-scans-2020',
#    'top-90-percent-scans-2020',
#    'top-5000-es-scans-2020',
#    'top-10000-es-scans-2020',
#    'top-50000-es-scans-2020',
#    'top-100000-es-scans-2020',
#    'top-country-es-scans-2020',
#    'at-least-5-es-scans-2020',
#    'top-5000-pt-scans-2020',
#    'top-10000-pt-scans-2020',
#    'top-50000-pt-scans-2020',
#    'top-100000-pt-scans-2020'],
#   'product_name': '',
#   'product_name_debug_tags': [],
#   'product_name_es': '',
#   'product_name_fr': 'Tónica',
#   'product_quantity': '250',
#   'purchase_places': '',
#   'purchase_places_tags': [],
#   'quantity': '25 CL',
#   'removed_countries_tags': [],
#   'rev': 27,
#   'scans_n': 17,
#   'selected_images': {'front': {'display': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_fr.4.400.jpg',
#      'pt': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_pt.19.400.jpg'},
#     'small': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_fr.4.200.jpg',
#      'pt': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_pt.19.200.jpg'},
#     'thumb': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_es.24.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_fr.4.100.jpg',
#      'pt': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/front_pt.19.100.jpg'}},
#    'ingredients': {'display': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_es.26.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_fr.14.400.jpg'},
#     'small': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_es.26.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_fr.14.200.jpg'},
#     'thumb': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_es.26.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/ingredients_fr.14.100.jpg'}},
#    'nutrition': {'display': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_es.27.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_fr.11.400.jpg'},
#     'small': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_es.27.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_fr.11.200.jpg'},
#     'thumb': {'es': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_es.27.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/841/410/024/4059/nutrition_fr.11.100.jpg'}}},
#   'serving_quantity': '100',
#   'serving_size': '100g',
#   'sortkey': 1586954341,
#   'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:origins-to-be-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-to-be-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#   'states_hierarchy': ['en:to-be-completed',
#    'en:nutrition-facts-completed',
#    'en:ingredients-to-be-completed',
#    'en:expiration-date-to-be-completed',
#    'en:packaging-code-to-be-completed',
#    'en:characteristics-to-be-completed',
#    'en:origins-to-be-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-to-be-completed',
#    'en:photos-to-be-validated',
#    'en:packaging-photo-to-be-selected',
#    'en:nutrition-photo-selected',
#    'en:ingredients-photo-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'states_tags': ['en:to-be-completed',
#    'en:nutrition-facts-completed',
#    'en:ingredients-to-be-completed',
#    'en:expiration-date-to-be-completed',
#    'en:packaging-code-to-be-completed',
#    'en:characteristics-to-be-completed',
#    'en:origins-to-be-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-to-be-completed',
#    'en:photos-to-be-validated',
#    'en:packaging-photo-to-be-selected',
#    'en:nutrition-photo-selected',
#    'en:ingredients-photo-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'stores': '',
#   'stores_tags': [],
#   'traces': '',
#   'traces_from_ingredients': '',
#   'traces_from_user': '(es) ',
#   'traces_hierarchy': [],
#   'traces_lc': 'es',
#   'traces_tags': [],
#   'unique_scans_n': 10,
#   'unknown_nutrients_tags': [],
#   'update_key': 'main-countries',
#   'url': 'https://world.openfoodfacts.org/product/8414100244059/schweppes',
#   'vitamins_prev_tags': [],
#   'vitamins_tags': []},
#  {'_id': '8431876230222',
#   '_keywords': ['loncha',
#    'product',
#    'spanish',
#    'carrefour',
#    'serrano',
#    'jamon',
#    'de',
#    'pai',
#    'producto',
#    'base',
#    'jamone',
#    'meat',
#    'seco',
#    'carne',
#    'embutido',
#    'curado'],
#   'added_countries_tags': [],
#   'additives_debug_tags': [],
#   'additives_n': 3,
#   'additives_old_n': 0,
#   'additives_old_tags': [],
#   'additives_original_tags': ['en:e301', 'en:e250', 'en:e252'],
#   'additives_prev_original_tags': [],
#   'additives_tags': ['en:e250', 'en:e252', 'en:e301'],
#   'allergens': 'es:Ausencia',
#   'allergens_from_ingredients': '',
#   'allergens_from_user': '(es) Ausencia',
#   'allergens_hierarchy': ['es:Ausencia'],
#   'allergens_imported': 'Ausencia',
#   'allergens_lc': 'es',
#   'allergens_tags': ['es:ausencia'],
#   'amino_acids_prev_tags': [],
#   'amino_acids_tags': [],
#   'brands': 'Carrefour',
#   'brands_imported': 'Carrefour',
#   'brands_tags': ['carrefour'],
#   'categories': 'Carnes,Embutidos,Productos a base de carne,Jamón,Jamón de país,Jamones secos,en:Spanish meat products,Jamón Serrano',
#   'categories_hierarchy': ['en:meats',
#    'en:prepared-meats',
#    'en:meat-based-products',
#    'en:hams',
#    'en:cured-ham',
#    'en:dried-hams',
#    'en:spanish-meat-products',
#    'en:serrano-ham'],
#   'categories_imported': 'Jamón ibérico',
#   'categories_lc': 'es',
#   'categories_old': 'Carnes, Embutidos, Productos a base de carne, Jamón, en:raw-cured-ham, Jamones secos, en:Spanish meat products, Jamón Serrano, Jamón ibérico',
#   'categories_properties': {'agribalyse_food_code:en': '28845',
#    'ciqual_food_code:en': '28845'},
#   'categories_properties_tags': ['all-products',
#    'categories-known',
#    'agribalyse-food-code-28845',
#    'agribalyse-food-code-known',
#    'agribalyse-proxy-food-code-unknown',
#    'ciqual-food-code-28845',
#    'ciqual-food-code-known',
#    'agribalyse-known',
#    'agribalyse-28845'],
#   'categories_tags': ['en:meats',
#    'en:prepared-meats',
#    'en:meat-based-products',
#    'en:hams',
#    'en:cured-ham',
#    'en:dried-hams',
#    'en:spanish-meat-products',
#    'en:serrano-ham'],
#   'category_properties': {'ciqual_food_name:en': 'Serrano dry-cured ham',
#    'ciqual_food_name:fr': 'Jambon sec Serrano'},
#   'checkers_tags': [],
#   'ciqual_food_name_tags': ['serrano-dry-cured-ham'],
#   'cities_tags': [],
#   'code': '8431876230222',
#   'codes_tags': ['code-13',
#    '8431876230xxx',
#    '843187623xxxx',
#    '84318762xxxxx',
#    '8431876xxxxxx',
#    '843187xxxxxxx',
#    '84318xxxxxxxx',
#    '8431xxxxxxxxx',
#    '843xxxxxxxxxx',
#    '84xxxxxxxxxxx',
#    '8xxxxxxxxxxxx'],
#   'compared_to_category': 'en:serrano-ham',
#   'complete': 0,
#   'completeness': 0.5875,
#   'correctors_tags': ['yuka.V0xBak5ZUWVoLzhHZzlnVC9Dano1SXBFNHBXblJqeStlOFVQSWc9PQ',
#    'yukafix',
#    'elcoco',
#    'raphael0202',
#    'org-carrefour-espana',
#    'thaialagata'],
#   'countries': 'Francia,España',
#   'countries_hierarchy': ['en:france', 'en:spain'],
#   'countries_imported': 'España',
#   'countries_lc': 'es',
#   'countries_tags': ['en:france', 'en:spain'],
#   'created_t': 1493670094,
#   'creator': 'openfoodfacts-contributors',
#   'data_quality_bugs_tags': [],
#   'data_quality_errors_tags': [],
#   'data_quality_info_tags': ['en:packaging-data-incomplete',
#    'en:ingredients-percent-analysis-ok'],
#   'data_quality_tags': ['en:packaging-data-incomplete',
#    'en:ingredients-percent-analysis-ok',
#    'en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#    'en:ecoscore-packaging-packaging-data-missing',
#    'en:ecoscore-production-system-no-label'],
#   'data_quality_warnings_tags': ['en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#    'en:ecoscore-packaging-packaging-data-missing',
#    'en:ecoscore-production-system-no-label'],
#   'data_sources': 'App - elcoco, App - yuka, Apps, Producers, Producer - carrefour-espana',
#   'data_sources_imported': 'Producers, Producer - carrefour-espana',
#   'data_sources_tags': ['app-elcoco',
#    'app-yuka',
#    'apps',
#    'producers',
#    'producer-carrefour-espana'],
#   'debug_param_sorted_langs': ['es', 'fr'],
#   'ecoscore_data': {'adjustments': {'origins_of_ingredients': {'aggregated_origins': [{'origin': 'en:unknown',
#        'percent': 100}],
#      'epi_score': 0,
#      'epi_value': -5,
#      'origins_from_origins_field': ['en:unknown'],
#      'transportation_score_be': 0,
#      'transportation_score_ch': 0,
#      'transportation_score_de': 0,
#      'transportation_score_es': 0,
#      'transportation_score_fr': 0,
#      'transportation_score_ie': 0,
#      'transportation_score_it': 0,
#      'transportation_score_lu': 0,
#      'transportation_score_nl': 0,
#      'transportation_value_be': 0,
#      'transportation_value_ch': 0,
#      'transportation_value_de': 0,
#      'transportation_value_es': 0,
#      'transportation_value_fr': 0,
#      'transportation_value_ie': 0,
#      'transportation_value_it': 0,
#      'transportation_value_lu': 0,
#      'transportation_value_nl': 0,
#      'value_be': -5,
#      'value_ch': -5,
#      'value_de': -5,
#      'value_es': -5,
#      'value_fr': -5,
#      'value_ie': -5,
#      'value_it': -5,
#      'value_lu': -5,
#      'value_nl': -5,
#      'warning': 'origins_are_100_percent_unknown'},
#     'packaging': {'non_recyclable_and_non_biodegradable_materials': 1,
#      'packagings': [{'ecoscore_material_score': 0,
#        'ecoscore_shape_ratio': 1,
#        'material': 'en:unknown',
#        'non_recyclable_and_non_biodegradable': 'maybe',
#        'shape': 'en:unknown'}],
#      'score': 0,
#      'value': -10,
#      'warning': 'packaging_data_missing'},
#     'production_system': {'warning': 'no_label'},
#     'threatened_species': {}},
#    'agribalyse': {'agribalyse_food_code': '28845',
#     'co2_agriculture': '13.227038',
#     'co2_consumption': '0.10556394',
#     'co2_distribution': '0.037885829',
#     'co2_packaging': '0.13381699',
#     'co2_processing': '2.1311004',
#     'co2_total': '15.909519',
#     'co2_transportation': '0.27297814',
#     'code': '28845',
#     'dqr': '2.51',
#     'ef_agriculture': '1.9571782',
#     'ef_consumption': '0.0072555916',
#     'ef_distribution': '0.011179692',
#     'ef_packaging': '0.0071220994',
#     'ef_processing': '0.40096057',
#     'ef_total': 2.4050366,
#     'ef_transportation': '0.021137823',
#     'is_beverage': 0,
#     'name_en': 'Serrano dry-cured ham',
#     'name_fr': 'Jambon sec Serrano',
#     'score': 7},
#    'grade': 'e',
#    'grade_be': 'e',
#    'grade_ch': 'e',
#    'grade_de': 'e',
#    'grade_es': 'e',
#    'grade_fr': 'e',
#    'grade_ie': 'e',
#    'grade_it': 'e',
#    'grade_lu': 'e',
#    'grade_nl': 'e',
#    'missing': {'labels': 1, 'origins': 1, 'packagings': 1},
#    'missing_data_warning': 1,
#    'score': -3,
#    'score_be': -8,
#    'score_ch': -8,
#    'score_de': -8,
#    'score_es': -8,
#    'score_fr': -8,
#    'score_ie': -8,
#    'score_it': -8,
#    'score_lu': -8,
#    'score_nl': -8,
#    'status': 'known'},
#   'ecoscore_grade': 'e',
#   'ecoscore_score': -3,
#   'ecoscore_tags': ['e'],
#   'editors_tags': ['elcoco',
#    'kiliweb',
#    'thaialagata',
#    'raphael0202',
#    'teolemon',
#    'yuka.UjU4dVRLa2t2TVpUeC9jUTBoSHV4b2tyK0lhV1pFYWJLdll5SVE9PQ',
#    'openfoodfacts-contributors',
#    'org-carrefour-espana',
#    'yukafix',
#    'yuka.V0xBak5ZUWVoLzhHZzlnVC9Dano1SXBFNHBXblJqeStlOFVQSWc9PQ'],
#   'emb_codes': '',
#   'emb_codes_tags': [],
#   'entry_dates_tags': ['2017-05-01', '2017-05', '2017'],
#   'expiration_date': '',
#   'generic_name': '',
#   'generic_name_es': '',
#   'generic_name_fr': '',
#   'id': '8431876230222',
#   'image_front_small_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/front_es.20.200.jpg',
#   'image_front_thumb_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/front_es.20.100.jpg',
#   'image_front_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/front_es.20.400.jpg',
#   'image_ingredients_small_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/ingredients_es.8.200.jpg',
#   'image_ingredients_thumb_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/ingredients_es.8.100.jpg',
#   'image_ingredients_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/ingredients_es.8.400.jpg',
#   'image_nutrition_small_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/nutrition_es.16.200.jpg',
#   'image_nutrition_thumb_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/nutrition_es.16.100.jpg',
#   'image_nutrition_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/nutrition_es.16.400.jpg',
#   'image_small_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/front_es.20.200.jpg',
#   'image_thumb_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/front_es.20.100.jpg',
#   'image_url': 'https://static.openfoodfacts.org/images/products/843/187/623/0222/front_es.20.400.jpg',
#   'images': {'1': {'sizes': {'100': {'h': 74, 'w': 100},
#      '400': {'h': 296, 'w': 400},
#      'full': {'h': 1482, 'w': 2000}},
#     'uploaded_t': '1493670094',
#     'uploader': 'openfoodfacts-contributors'},
#    '2': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 1200, 'w': 900}},
#     'uploaded_t': '1525779220',
#     'uploader': 'kiliweb'},
#    '3': {'sizes': {'100': {'h': 75, 'w': 100},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 1200, 'w': 1600}},
#     'uploaded_t': '1525779223',
#     'uploader': 'kiliweb'},
#    '4': {'sizes': {'100': {'h': 100, 'w': 84},
#      '400': {'h': 400, 'w': 336},
#      'full': {'h': 1200, 'w': 1007}},
#     'uploaded_t': 1568808333,
#     'uploader': 'kiliweb'},
#    '5': {'sizes': {'100': {'h': 100, 'w': 100},
#      '400': {'h': 350, 'w': 350},
#      'full': {'h': 350, 'w': 350}},
#     'uploaded_t': 1589382951,
#     'uploader': 'org-carrefour-espana'},
#    'front_es': {'angle': 0,
#     'geometry': '0x0--1--1',
#     'imgid': '5',
#     'normalize': 'false',
#     'rev': '20',
#     'sizes': {'100': {'h': 100, 'w': 100},
#      '200': {'h': 200, 'w': 200},
#      '400': {'h': 350, 'w': 350},
#      'full': {'h': 350, 'w': 350}},
#     'white_magic': 'false',
#     'x1': '-1',
#     'x2': '-1',
#     'y1': '-1',
#     'y2': '-1'},
#    'front_fr': {'angle': None,
#     'geometry': '0x0-0-0',
#     'imgid': '2',
#     'normalize': '0',
#     'rev': '6',
#     'sizes': {'100': {'h': 100, 'w': 75},
#      '200': {'h': 200, 'w': 150},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 1200, 'w': 900}},
#     'white_magic': '0',
#     'x1': None,
#     'x2': None,
#     'y1': None,
#     'y2': None},
#    'ingredients_es': {'angle': 0,
#     'geometry': '0x0--4--4',
#     'imgid': '3',
#     'normalize': None,
#     'ocr': 1,
#     'orientation': None,
#     'rev': '8',
#     'sizes': {'100': {'h': 75, 'w': 100},
#      '200': {'h': 150, 'w': 200},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 1200, 'w': 1600}},
#     'white_magic': None,
#     'x1': -1,
#     'x2': -1,
#     'y1': -1,
#     'y2': -1},
#    'ingredients_fr': {'angle': None,
#     'geometry': '0x0-0-0',
#     'imgid': '3',
#     'normalize': '0',
#     'ocr': 1,
#     'orientation': None,
#     'rev': '9',
#     'sizes': {'100': {'h': 75, 'w': 100},
#      '200': {'h': 150, 'w': 200},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 1200, 'w': 1600}},
#     'white_magic': '0',
#     'x1': None,
#     'x2': None,
#     'y1': None,
#     'y2': None},
#    'nutrition_es': {'angle': 0,
#     'geometry': '0x0--2--3',
#     'imgid': '4',
#     'normalize': None,
#     'rev': '16',
#     'sizes': {'100': {'h': 100, 'w': 84},
#      '200': {'h': 200, 'w': 168},
#      '400': {'h': 400, 'w': 336},
#      'full': {'h': 1200, 'w': 1007}},
#     'white_magic': None,
#     'x1': '-1',
#     'x2': '-1',
#     'y1': '-1',
#     'y2': '-1'}},
#   'informers_tags': ['openfoodfacts-contributors',
#    'yuka.V0xBak5ZUWVoLzhHZzlnVC9Dano1SXBFNHBXblJqeStlOFVQSWc9PQ',
#    'kiliweb',
#    'elcoco',
#    'teolemon',
#    'org-carrefour-espana'],
#   'ingredients': [{'id': 'en:ham',
#     'ingredients': [{'id': 'es:jamón provienen de 143g de carne de cerdo',
#       'percent': '100',
#       'percent_estimate': 100,
#       'percent_max': 100,
#       'percent_min': 100,
#       'text': 'jamón provienen de 143g de carne de cerdo'}],
#     'percent_estimate': 100,
#     'percent_max': 100,
#     'percent_min': 100,
#     'text': 'Jamón de cerdo',
#     'vegan': 'no',
#     'vegetarian': 'no'},
#    {'id': 'en:salt',
#     'percent_estimate': 0,
#     'percent_max': 0,
#     'percent_min': 0,
#     'text': 'sal',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:dextrose',
#     'percent_estimate': 0,
#     'percent_max': 0,
#     'percent_min': 0,
#     'text': 'dextrosa',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:antioxidant',
#     'ingredients': [{'id': 'en:e301',
#       'percent_estimate': 0,
#       'percent_max': 0,
#       'percent_min': 0,
#       'text': 'ascorbato sódico',
#       'vegan': 'yes',
#       'vegetarian': 'yes'}],
#     'percent_estimate': 0,
#     'percent_max': 0,
#     'percent_min': 0,
#     'text': 'antioxidante'},
#    {'id': 'en:preservative',
#     'ingredients': [{'id': 'en:e250',
#       'percent_estimate': 0,
#       'percent_max': 0,
#       'percent_min': 0,
#       'text': 'nitrito sódico',
#       'vegan': 'yes',
#       'vegetarian': 'yes'},
#      {'id': 'en:e252',
#       'percent_estimate': 0,
#       'percent_max': 0,
#       'percent_min': 0,
#       'text': 'nitrato potásico',
#       'vegan': 'yes',
#       'vegetarian': 'yes'}],
#     'percent_estimate': 0,
#     'percent_max': 0,
#     'percent_min': 0,
#     'text': 'conservadores'}],
#   'ingredients_analysis_tags': ['en:palm-oil-content-unknown',
#    'en:non-vegan',
#    'en:non-vegetarian'],
#   'ingredients_debug': [],
#   'ingredients_from_or_that_may_be_from_palm_oil_n': 0,
#   'ingredients_from_palm_oil_n': 0,
#   'ingredients_from_palm_oil_tags': [],
#   'ingredients_hierarchy': ['en:ham',
#    'en:animal',
#    'en:meat',
#    'en:pork',
#    'en:pork-meat',
#    'en:salt',
#    'en:dextrose',
#    'en:glucose',
#    'en:antioxidant',
#    'en:preservative',
#    'es:jamón provienen de 143g de carne de cerdo',
#    'en:e301',
#    'en:e250',
#    'en:e252'],
#   'ingredients_ids_debug': [],
#   'ingredients_n': 9,
#   'ingredients_n_tags': ['9', '1-10'],
#   'ingredients_original_tags': ['en:ham',
#    'en:salt',
#    'en:dextrose',
#    'en:antioxidant',
#    'en:preservative',
#    'es:jamón provienen de 143g de carne de cerdo',
#    'en:e301',
#    'en:e250',
#    'en:e252'],
#   'ingredients_tags': ['en:ham',
#    'en:animal',
#    'en:meat',
#    'en:pork',
#    'en:pork-meat',
#    'en:salt',
#    'en:dextrose',
#    'en:glucose',
#    'en:antioxidant',
#    'en:preservative',
#    'es:jamon-provienen-de-143g-de-carne-de-cerdo',
#    'en:e301',
#    'en:e250',
#    'en:e252'],
#   'ingredients_text': 'Jamón de cerdo (100g de jamón provienen de 143g de carne de cerdo), sal, dextrosa, antioxidante (ascorbato sódico), conservadores (nitrito sódico, nitrato potásico).',
#   'ingredients_text_debug': None,
#   'ingredients_text_es': 'Jamón de cerdo (100g de jamón provienen de 143g de carne de cerdo), sal, dextrosa, antioxidante (ascorbato sódico), conservadores (nitrito sódico, nitrato potásico).',
#   'ingredients_text_es_imported': 'Jamón de cerdo (100g de jamón provienen de 143g de carne de cerdo), sal, dextrosa, antioxidante (ascorbato sódico), conservadores (nitrito sódico, nitrato potásico).',
#   'ingredients_text_fr': '',
#   'ingredients_text_with_allergens': 'Jamón de cerdo (100g de jamón provienen de 143g de carne de cerdo), sal, dextrosa, antioxidante (ascorbato sódico), conservadores (nitrito sódico, nitrato potásico).',
#   'ingredients_text_with_allergens_es': 'Jamón de cerdo (100g de jamón provienen de 143g de carne de cerdo), sal, dextrosa, antioxidante (ascorbato sódico), conservadores (nitrito sódico, nitrato potásico).',
#   'ingredients_text_with_allergens_fr': '',
#   'ingredients_that_may_be_from_palm_oil_n': 0,
#   'ingredients_that_may_be_from_palm_oil_tags': [],
#   'interface_version_created': '20120622',
#   'interface_version_modified': '20190830',
#   'known_ingredients_n': 13,
#   'labels': '',
#   'labels_hierarchy': [],
#   'labels_lc': 'es',
#   'labels_tags': [],
#   'lang': 'es',
#   'lang_imported': 'es',
#   'languages': {'en:french': 2, 'en:spanish': 5},
#   'languages_codes': {'es': 5, 'fr': 2},
#   'languages_hierarchy': ['en:french', 'en:spanish'],
#   'languages_tags': ['en:french', 'en:spanish', 'en:2', 'en:multilingual'],
#   'last_edit_dates_tags': ['2021-05-31', '2021-05', '2021'],
#   'last_editor': 'thaialagata',
#   'last_image_dates_tags': ['2020-05-13', '2020-05', '2020'],
#   'last_image_t': 1589382951,
#   'last_modified_by': 'thaialagata',
#   'last_modified_t': 1622454178,
#   'lc': 'es',
#   'lc_imported': 'es',
#   'link': '',
#   'main_countries_tags': [],
#   'manufacturing_places': '',
#   'manufacturing_places_tags': [],
#   'max_imgid': '5',
#   'minerals_prev_tags': [],
#   'minerals_tags': [],
#   'misc_tags': ['en:nutrition-fruits-vegetables-nuts',
#    'en:nutrition-all-nutriscore-values-known',
#    'en:nutriscore-computed',
#    'en:ecoscore-missing-data-warning',
#    'en:ecoscore-computed',
#    'en:main-countries-fr-product-name-not-in-country-language',
#    'en:main-countries-fr-ingredients-not-in-country-language',
#    'en:main-countries-fr-no-data-in-country-language',
#    'en:main-countries-old-product-without-scans-in-2020'],
#   'no_nutrition_data': '',
#   'nova_group': 4,
#   'nova_group_debug': ' -- additives/en:e250 : 3 -- ingredients/en:dextrose : 4',
#   'nova_group_tags': ['not-applicable'],
#   'nova_groups': '4',
#   'nova_groups_tags': ['en:4-ultra-processed-food-and-drink-products'],
#   'nucleotides_prev_tags': [],
#   'nucleotides_tags': [],
#   'nutrient_levels': {'fat': 'moderate',
#    'salt': 'high',
#    'saturated-fat': 'moderate',
#    'sugars': 'low'},
#   'nutrient_levels_tags': ['en:fat-in-moderate-quantity',
#    'en:saturated-fat-in-moderate-quantity',
#    'en:sugars-in-low-quantity',
#    'en:salt-in-high-quantity'],
#   'nutriments': {'carbohydrates': 0,
#    'carbohydrates_100g': 0,
#    'carbohydrates_unit': 'g',
#    'carbohydrates_value': 0,
#    'energy': 884,
#    'energy-kcal': 211,
#    'energy-kcal_100g': 211,
#    'energy-kcal_unit': 'kcal',
#    'energy-kcal_value': 211,
#    'energy-kj': 884,
#    'energy-kj_100g': 884,
#    'energy-kj_unit': 'kJ',
#    'energy-kj_value': 884,
#    'energy_100g': 884,
#    'energy_unit': 'kJ',
#    'energy_value': 884,
#    'fat': 10,
#    'fat_100g': 10,
#    'fat_unit': 'g',
#    'fat_value': 10,
#    'fiber': 0,
#    'fiber_100g': 0,
#    'fiber_unit': 'g',
#    'fiber_value': 0,
#    'fruits-vegetables-nuts': 0,
#    'fruits-vegetables-nuts-estimate-from-ingredients_100g': 0,
#    'fruits-vegetables-nuts_100g': 0,
#    'fruits-vegetables-nuts_serving': 0,
#    'fruits-vegetables-nuts_unit': 'g',
#    'fruits-vegetables-nuts_value': 0,
#    'nova-group': 4,
#    'nova-group_100g': 4,
#    'nova-group_serving': 4,
#    'nutrition-score-fr': 15,
#    'nutrition-score-fr_100g': 15,
#    'proteins': 30,
#    'proteins_100g': 30,
#    'proteins_unit': 'g',
#    'proteins_value': 30,
#    'salt': 3.2,
#    'salt_100g': 3.2,
#    'salt_unit': 'g',
#    'salt_value': 3.2,
#    'saturated-fat': 3.6,
#    'saturated-fat_100g': 3.6,
#    'saturated-fat_unit': 'g',
#    'saturated-fat_value': 3.6,
#    'sodium': 1.28,
#    'sodium_100g': 1.28,
#    'sodium_unit': 'g',
#    'sodium_value': 1.28,
#    'sugars': 0,
#    'sugars_100g': 0,
#    'sugars_unit': 'g',
#    'sugars_value': 0},
#   'nutriscore_data': {'energy': 884,
#    'energy_points': 2,
#    'energy_value': 884,
#    'fiber': 0,
#    'fiber_points': 0,
#    'fiber_value': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 0,
#    'grade': 'd',
#    'is_beverage': 0,
#    'is_cheese': 0,
#    'is_fat': 0,
#    'is_water': 0,
#    'negative_points': 15,
#    'positive_points': 0,
#    'proteins': 30,
#    'proteins_points': 5,
#    'proteins_value': 30,
#    'saturated_fat': 3.6,
#    'saturated_fat_points': 3,
#    'saturated_fat_ratio': 36,
#    'saturated_fat_ratio_points': 5,
#    'saturated_fat_ratio_value': 36,
#    'saturated_fat_value': 3.6,
#    'score': 15,
# ...
#    'en:danish',
#    'en:german',
#    'en:russian',
#    'en:italian',
#    'en:dutch',
#    'en:english',
#    'en:french',
#    'en:finnish',
#    'en:swedish',
#    'en:portuguese',
#    'en:12',
#    'en:multilingual'],
#   'last_edit_dates_tags': ['2021-05-31', '2021-05', '2021'],
#   'last_editor': 'torredibabele',
#   'last_image_dates_tags': ['2021-05-28', '2021-05', '2021'],
#   'last_image_t': 1622217349,
#   'last_modified_by': 'torredibabele',
#   'last_modified_t': 1622454148,
#   'lc': 'it',
#   'link': '',
#   'main_countries_tags': [],
#   'manufacturing_places': 'Italy',
#   'manufacturing_places_tags': ['italy'],
#   'max_imgid': '6',
#   'minerals_prev_tags': [],
#   'minerals_tags': [],
#   'misc_tags': ['en:nutrition-fruits-vegetables-nuts-estimate-from-ingredients',
#    'en:nutrition-all-nutriscore-values-known',
#    'en:nutriscore-computed',
#    'en:ecoscore-missing-data-warning',
#    'en:ecoscore-computed',
#    'en:main-countries-es-ingredients-not-in-country-language',
#    'en:main-countries-es-only-1-field-in-country-language'],
#   'no_nutrition_data': '',
#   'nova_group': 1,
#   'nova_group_debug': '',
#   'nova_group_tags': ['not-applicable'],
#   'nova_groups': '1',
#   'nova_groups_tags': ['en:1-unprocessed-or-minimally-processed-foods'],
#   'nucleotides_prev_tags': [],
#   'nucleotides_tags': [],
#   'nutrient_levels': {'fat': 'low',
#    'salt': 'low',
#    'saturated-fat': 'low',
#    'sugars': 'low'},
#   'nutrient_levels_tags': ['en:fat-in-low-quantity',
#    'en:saturated-fat-in-low-quantity',
#    'en:sugars-in-low-quantity',
#    'en:salt-in-low-quantity'],
#   'nutriments': {'carbohydrates': 65.8,
#    'carbohydrates_100g': 65.8,
#    'carbohydrates_unit': 'g',
#    'carbohydrates_value': 65.8,
#    'energy': 1476,
#    'energy-kcal': 348,
#    'energy-kcal_100g': 348,
#    'energy-kcal_unit': 'kcal',
#    'energy-kcal_value': 348,
#    'energy-kj': 1476,
#    'energy-kj_100g': 1476,
#    'energy-kj_unit': 'kJ',
#    'energy-kj_value': 1476,
#    'energy_100g': 1476,
#    'energy_unit': 'kJ',
#    'energy_value': 1476,
#    'fat': 1.9,
#    'fat_100g': 1.9,
#    'fat_unit': 'g',
#    'fat_value': 1.9,
#    'fiber': 6.2,
#    'fiber_100g': 6.2,
#    'fiber_unit': 'g',
#    'fiber_value': 6.2,
#    'fruits-vegetables-nuts-estimate-from-ingredients_100g': 0,
#    'nova-group': 1,
#    'nova-group_100g': 1,
#    'nova-group_serving': 1,
#    'nutrition-score-fr': -6,
#    'nutrition-score-fr_100g': -6,
#    'proteins': 14,
#    'proteins_100g': 14,
#    'proteins_unit': 'g',
#    'proteins_value': 14,
#    'salt': 0.01,
#    'salt_100g': 0.01,
#    'salt_unit': 'g',
#    'salt_value': 0.01,
#    'saturated-fat': 0.4,
#    'saturated-fat_100g': 0.4,
#    'saturated-fat_unit': 'g',
#    'saturated-fat_value': 0.4,
#    'sodium': 0.004,
#    'sodium_100g': 0.004,
#    'sodium_unit': 'g',
#    'sodium_value': 0.004,
#    'sugars': 2.8,
#    'sugars_100g': 2.8,
#    'sugars_unit': 'g',
#    'sugars_value': 2.8},
#   'nutriscore_data': {'energy': 1476,
#    'energy_points': 4,
#    'energy_value': 1476,
#    'fiber': 6.2,
#    'fiber_points': 5,
#    'fiber_value': 6.2,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 0,
#    'grade': 'a',
#    'is_beverage': 0,
#    'is_cheese': 0,
#    'is_fat': 0,
#    'is_water': 0,
#    'negative_points': 4,
#    'positive_points': 10,
#    'proteins': 14,
#    'proteins_points': 5,
#    'proteins_value': 14,
#    'saturated_fat': 0.4,
#    'saturated_fat_points': 0,
#    'saturated_fat_ratio': 21.0526315789474,
#    'saturated_fat_ratio_points': 2,
#    'saturated_fat_ratio_value': 21.1,
#    'saturated_fat_value': 0.4,
#    'score': -6,
#    'sodium': 4,
#    'sodium_points': 0,
#    'sodium_value': 4,
#    'sugars': 2.8,
#    'sugars_points': 0,
#    'sugars_value': 2.8},
#   'nutriscore_grade': 'a',
#   'nutriscore_score': -6,
#   'nutriscore_score_opposite': 6,
#   'nutrition_data': 'on',
#   'nutrition_data_per': '100g',
#   'nutrition_data_prepared': '',
#   'nutrition_data_prepared_per': '100g',
#   'nutrition_grade_fr': 'a',
#   'nutrition_grades': 'a',
#   'nutrition_grades_tags': ['a'],
#   'nutrition_score_beverage': 0,
#   'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients': 1,
#   'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value': 0,
#   'origins': 'Italy',
#   'origins_hierarchy': ['en:italy'],
#   'origins_lc': 'en',
#   'origins_old': '',
#   'origins_tags': ['en:italy'],
#   'other_nutritional_substances_tags': [],
#   'packaging': 'Sacchetto carta,81-CPAP',
#   'packaging_tags': ['sacchetto-carta', '81-cpap'],
#   'packaging_text': '1 sacchetto 81-C/PAP buttare',
#   'packaging_text_ar': '',
#   'packaging_text_da': '',
#   'packaging_text_de': '',
#   'packaging_text_en': '',
#   'packaging_text_es': '',
#   'packaging_text_fi': '',
#   'packaging_text_fr': '',
#   'packaging_text_it': '1 sacchetto 81-C/PAP buttare',
#   'packaging_text_nl': '',
#   'packaging_text_pt': '',
#   'packaging_text_ru': '',
#   'packaging_text_sv': '',
#   'packagings': [{'shape': 'en:unknown'}],
#   'photographers_tags': ['kiliweb', 'torredibabele'],
#   'pnns_groups_1': 'Cereals and potatoes',
#   'pnns_groups_1_tags': ['cereals-and-potatoes', 'known'],
#   'pnns_groups_2': 'Cereals',
#   'pnns_groups_2_tags': ['cereals', 'known'],
#   'popularity_key': 15,
#   'popularity_tags': ['bottom-25-percent-scans-2019',
#    'bottom-20-percent-scans-2019',
#    'bottom-15-percent-scans-2019',
#    'top-90-percent-scans-2019',
#    'top-50000-it-scans-2019',
#    'top-100000-it-scans-2019',
#    'top-country-it-scans-2019',
#    'top-75-percent-scans-2020',
#    'top-80-percent-scans-2020',
#    'top-85-percent-scans-2020',
#    'top-90-percent-scans-2020',
#    'top-5000-it-scans-2020',
#    'top-10000-it-scans-2020',
#    'top-50000-it-scans-2020',
#    'top-100000-it-scans-2020',
#    'top-country-it-scans-2020',
#    'top-100-al-scans-2020',
#    'top-500-al-scans-2020',
#    'top-1000-al-scans-2020',
#    'top-5000-al-scans-2020',
#    'top-10000-al-scans-2020',
#    'top-50000-al-scans-2020',
#    'top-100000-al-scans-2020'],
#   'product_name': 'Bio Integrale Farfalle n° 85',
#   'product_name_ar': 'Bio Integrale Farfalle n° 85',
#   'product_name_da': 'Bio Integrale Farfalle n° 85',
#   'product_name_de': 'Bio Integrale Farfalle n° 85',
#   'product_name_debug_tags': [],
#   'product_name_en': 'Bio Integrale Farfalle n° 85',
#   'product_name_es': 'Bio Integrale Farfalle n° 85',
#   'product_name_fi': 'Bio Integrale Farfalle n° 85',
#   'product_name_fr': 'Bio Integrale Farfalle n° 85',
#   'product_name_it': 'Bio Integrale Farfalle n° 85',
#   'product_name_nl': 'Bio Integrale Farfalle n° 85',
#   'product_name_pt': 'Bio Integrale Farfalle n° 85',
#   'product_name_ru': 'Bio Integrale Farfalle n° 85',
#   'product_name_sv': 'Bio Integrale Farfalle n° 85',
#   'product_quantity': '500',
#   'purchase_places': 'Italy',
#   'purchase_places_tags': ['italy'],
#   'quantity': '500 g',
#   'removed_countries_tags': [],
#   'rev': 53,
#   'scans_n': 6,
#   'selected_images': {'front': {'display': {'ar': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_ar.41.400.jpg',
#      'da': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_da.37.400.jpg',
#      'de': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_de.33.400.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_en.32.400.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_es.34.400.jpg',
#      'fi': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_fi.39.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_fr.18.400.jpg',
#      'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_it.25.400.jpg',
#      'nl': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_nl.35.400.jpg',
#      'pt': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_pt.36.400.jpg',
#      'ru': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_ru.40.400.jpg',
#      'sv': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_sv.38.400.jpg'},
#     'small': {'ar': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_ar.41.200.jpg',
#      'da': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_da.37.200.jpg',
#      'de': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_de.33.200.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_en.32.200.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_es.34.200.jpg',
#      'fi': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_fi.39.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_fr.18.200.jpg',
#      'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_it.25.200.jpg',
#      'nl': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_nl.35.200.jpg',
#      'pt': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_pt.36.200.jpg',
#      'ru': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_ru.40.200.jpg',
#      'sv': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_sv.38.200.jpg'},
#     'thumb': {'ar': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_ar.41.100.jpg',
#      'da': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_da.37.100.jpg',
#      'de': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_de.33.100.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_en.32.100.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_es.34.100.jpg',
#      'fi': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_fi.39.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_fr.18.100.jpg',
#      'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_it.25.100.jpg',
#      'nl': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_nl.35.100.jpg',
#      'pt': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_pt.36.100.jpg',
#      'ru': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_ru.40.100.jpg',
#      'sv': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/front_sv.38.100.jpg'}},
#    'ingredients': {'display': {'ar': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_ar.43.400.jpg',
#      'da': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_da.44.400.jpg',
#      'de': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_de.45.400.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_en.46.400.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_es.52.400.jpg',
#      'fi': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_fi.53.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_fr.50.400.jpg',
#      'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_it.28.400.jpg'},
#     'small': {'ar': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_ar.43.200.jpg',
#      'da': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_da.44.200.jpg',
#      'de': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_de.45.200.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_en.46.200.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_es.52.200.jpg',
#      'fi': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_fi.53.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_fr.50.200.jpg',
#      'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_it.28.200.jpg'},
#     'thumb': {'ar': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_ar.43.100.jpg',
#      'da': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_da.44.100.jpg',
#      'de': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_de.45.100.jpg',
#      'en': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_en.46.100.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_es.52.100.jpg',
#      'fi': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_fi.53.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_fr.50.100.jpg',
#      'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/ingredients_it.28.100.jpg'}},
#    'nutrition': {'display': {'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/nutrition_it.29.400.jpg'},
#     'small': {'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/nutrition_it.29.200.jpg'},
#     'thumb': {'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/nutrition_it.29.100.jpg'}},
#    'packaging': {'display': {'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/packaging_it.30.400.jpg'},
#     'small': {'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/packaging_it.30.200.jpg'},
#     'thumb': {'it': 'https://static.openfoodfacts.org/images/products/800/834/370/0856/packaging_it.30.100.jpg'}}},
#   'sortkey': 1596643462,
#   'states': 'en:to-be-checked, en:complete, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-completed, en:packaging-code-to-be-completed, en:characteristics-completed, en:origins-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-validated, en:packaging-photo-selected, en:nutrition-photo-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#   'states_hierarchy': ['en:to-be-checked',
#    'en:complete',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-to-be-completed',
#    'en:characteristics-completed',
#    'en:origins-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-validated',
#    'en:packaging-photo-selected',
#    'en:nutrition-photo-selected',
#    'en:ingredients-photo-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'states_tags': ['en:to-be-checked',
#    'en:complete',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-to-be-completed',
#    'en:characteristics-completed',
#    'en:origins-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-validated',
#    'en:packaging-photo-selected',
#    'en:nutrition-photo-selected',
#    'en:ingredients-photo-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'stores': '',
#   'stores_tags': [],
#   'traces': 'en:soybeans',
#   'traces_from_ingredients': '',
#   'traces_from_user': '(en) Soybeans',
#   'traces_hierarchy': ['en:soybeans'],
#   'traces_lc': 'en',
#   'traces_tags': ['en:soybeans'],
#   'unique_scans_n': 3,
#   'unknown_ingredients_n': 0,
#   'unknown_nutrients_tags': [],
#   'update_key': 'main-countries',
#   'url': 'https://world.openfoodfacts.org/product/8008343700856/bio-integrale-farfalle-n-85-rummo',
#   'vitamins_prev_tags': [],
#   'vitamins_tags': []}]

# %%
ingredient = 'phosphate de calcium'
products_ingredient = openfoodfacts.products.get_by_ingredient(ingredient)
for product in products_ingredient:
    print (product['product_name'])
# Out:
# nature's bounty women's multivitamin
# Velveeta
# Mini Fruits
# A  Toddler Tout-petits
# Almond Dream Almond Milk

# %% [markdown]
# ### Requête de produits répondant à plusieurs modalités

# %% [markdown]
# get_by_facets() : résultat très décevant. La requête ne retourne que 24 produits.

# %%
# liste des produits contenant des traces d'oeuf, et country=France
products = openfoodfacts.products.get_by_facets(
#     {'trace': 'egg', 'country': 'france'})
    {'trace': 'egg'})
print(len(products))
#products   # products est une liste de dictionnaires
# Out:
# 24

# %%
products[1]
# Out:
# {'_id': '00726511300821001676',
#  '_keywords': ['punto',
#   'comida',
#   'verde',
#   'de',
#   'bonarea',
#   'crema',
#   'espinaca',
#   'preparada',
#   'origen',
#   'la',
#   'vegetal'],
#  'added_countries_tags': [],
#  'additives_n': 0,
#  'additives_old_n': 0,
#  'additives_old_tags': [],
#  'additives_original_tags': [],
#  'additives_tags': [],
#  'allergens': 'en:milk,en:nuts,es:Nata',
#  'allergens_from_ingredients': 'nata, leche, piñones',
#  'allergens_from_user': '(es) Leche,Frutos de cáscara,Nata',
#  'allergens_hierarchy': ['en:milk', 'en:nuts', 'es:Nata', 'es:nata'],
#  'allergens_lc': 'es',
#  'allergens_tags': ['en:milk', 'en:nuts', 'es:nata', 'es:nata'],
#  'amino_acids_tags': [],
#  'brands': 'Bonarea',
#  'brands_tags': ['bonarea'],
#  'categories': 'Comidas preparadas de origen vegetal',
#  'categories_hierarchy': ['en:plant-based-foods-and-beverages',
#   'en:plant-based-foods',
#   'en:meals',
#   'en:plant-based-meals'],
#  'categories_lc': 'es',
#  'categories_properties': {},
#  'categories_properties_tags': ['all-products',
#   'categories-known',
#   'agribalyse-food-code-unknown',
#   'agribalyse-proxy-food-code-unknown',
#   'ciqual-food-code-unknown',
#   'agribalyse-unknown'],
#  'categories_tags': ['en:plant-based-foods-and-beverages',
#   'en:plant-based-foods',
#   'en:meals',
#   'en:plant-based-meals'],
#  'checkers_tags': [],
#  'cities_tags': [],
#  'code': '00726511300821001676',
#  'codes_tags': ['code-20',
#   '00726511300821001xxx',
#   '0072651130082100xxxx',
#   '007265113008210xxxxx',
#   '00726511300821xxxxxx',
#   '0072651130082xxxxxxx',
#   '007265113008xxxxxxxx',
#   '00726511300xxxxxxxxx',
#   '0072651130xxxxxxxxxx',
#   '007265113xxxxxxxxxxx',
#   '00726511xxxxxxxxxxxx',
#   '0072651xxxxxxxxxxxxx',
#   '007265xxxxxxxxxxxxxx',
#   '00726xxxxxxxxxxxxxxx',
#   '0072xxxxxxxxxxxxxxxx',
#   '007xxxxxxxxxxxxxxxxx',
#   '00xxxxxxxxxxxxxxxxxx',
#   '0xxxxxxxxxxxxxxxxxxx'],
#  'compared_to_category': 'en:plant-based-meals',
#  'complete': 0,
#  'completeness': 0.8875,
#  'correctors_tags': ['alia', 'thaialagata'],
#  'countries': 'España',
#  'countries_hierarchy': ['en:spain'],
#  'countries_lc': 'es',
#  'countries_tags': ['en:spain'],
#  'created_t': 1620077789,
#  'creator': 'kiliweb',
#  'data_quality_bugs_tags': [],
#  'data_quality_errors_tags': [],
#  'data_quality_info_tags': ['en:packaging-data-incomplete',
#   'en:ingredients-percent-analysis-ok'],
#  'data_quality_tags': ['en:packaging-data-incomplete',
#   'en:ingredients-percent-analysis-ok',
#   'en:nutrition-value-very-high-for-category-saturated-fat',
#   'en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#   'en:ecoscore-packaging-packaging-data-missing',
#   'en:ecoscore-production-system-no-label'],
#  'data_quality_warnings_tags': ['en:nutrition-value-very-high-for-category-saturated-fat',
#   'en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#   'en:ecoscore-packaging-packaging-data-missing',
#   'en:ecoscore-production-system-no-label'],
#  'data_sources': 'App - yuka, Apps',
#  'data_sources_tags': ['app-yuka', 'apps'],
#  'debug_param_sorted_langs': ['es'],
#  'ecoscore_data': {'adjustments': {'origins_of_ingredients': {'aggregated_origins': [{'origin': 'en:unknown',
#       'percent': 100}],
#     'epi_score': 0,
#     'epi_value': -5,
#     'origins_from_origins_field': ['en:unknown'],
#     'transportation_score_be': 0,
#     'transportation_score_ch': 0,
#     'transportation_score_de': 0,
#     'transportation_score_es': 0,
#     'transportation_score_fr': 0,
#     'transportation_score_ie': 0,
#     'transportation_score_it': 0,
#     'transportation_score_lu': 0,
#     'transportation_score_nl': 0,
#     'transportation_value_be': 0,
#     'transportation_value_ch': 0,
#     'transportation_value_de': 0,
#     'transportation_value_es': 0,
#     'transportation_value_fr': 0,
#     'transportation_value_ie': 0,
#     'transportation_value_it': 0,
#     'transportation_value_lu': 0,
#     'transportation_value_nl': 0,
#     'value_be': -5,
#     'value_ch': -5,
#     'value_de': -5,
#     'value_es': -5,
#     'value_fr': -5,
#     'value_ie': -5,
#     'value_it': -5,
#     'value_lu': -5,
#     'value_nl': -5,
#     'warning': 'origins_are_100_percent_unknown'},
#    'packaging': {'non_recyclable_and_non_biodegradable_materials': 1,
#     'packagings': [{'ecoscore_material_score': 0,
#       'ecoscore_shape_ratio': 1,
#       'material': 'en:unknown',
#       'non_recyclable_and_non_biodegradable': 'maybe',
#       'shape': 'en:unknown'}],
#     'score': 0,
#     'value': -10,
#     'warning': 'packaging_data_missing'},
#    'production_system': {'warning': 'no_label'},
#    'threatened_species': {}},
#   'agribalyse': {'warning': 'missing_agribalyse_match'},
#   'missing': {'agb_category': 1, 'labels': 1, 'origins': 1, 'packagings': 1},
#   'missing_agribalyse_match_warning': 1,
#   'status': 'unknown'},
#  'ecoscore_grade': 'unknown',
#  'ecoscore_tags': ['unknown'],
#  'editors_tags': ['alia',
#   'yuka.sY2b0xO6T85zoF3NwEKvlkwZdsb8oCj4DUP6ohW69s3RNbb6QOhq_5DCGKo',
#   'thaialagata',
#   'roboto-app',
#   'kiliweb'],
#  'emb_codes': '',
#  'emb_codes_tags': [],
#  'entry_dates_tags': ['2021-05-03', '2021-05', '2021'],
#  'expiration_date': '23/05/2021',
#  'generic_name': 'Espinacas a la crema',
#  'generic_name_es': 'Espinacas a la crema',
#  'id': '00726511300821001676',
#  'image_front_small_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.200.jpg',
#  'image_front_thumb_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.100.jpg',
#  'image_front_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.400.jpg',
#  'image_ingredients_small_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.200.jpg',
#  'image_ingredients_thumb_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.100.jpg',
#  'image_ingredients_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.400.jpg',
#  'image_nutrition_small_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.200.jpg',
#  'image_nutrition_thumb_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.100.jpg',
#  'image_nutrition_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.400.jpg',
#  'image_small_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.200.jpg',
#  'image_thumb_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.100.jpg',
#  'image_url': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.400.jpg',
#  'images': {'1': {'sizes': {'100': {'h': 100, 'w': 75},
#     '400': {'h': 400, 'w': 300},
#     'full': {'h': 1200, 'w': 900}},
#    'uploaded_t': 1620077789,
#    'uploader': 'kiliweb'},
#   '2': {'sizes': {'100': {'h': 100, 'w': 88},
#     '400': {'h': 400, 'w': 351},
#     'full': {'h': 1200, 'w': 1053}},
#    'uploaded_t': 1620077790,
#    'uploader': 'kiliweb'},
#   'front_es': {'angle': '0',
#    'coordinates_image_size': 'full',
#    'geometry': '0x0-0-0',
#    'imgid': '1',
#    'normalize': 'true',
#    'rev': '8',
#    'sizes': {'100': {'h': 100, 'w': 75},
#     '200': {'h': 200, 'w': 150},
#     '400': {'h': 400, 'w': 300},
#     'full': {'h': 1200, 'w': 900}},
#    'white_magic': 'false',
#    'x1': '0',
#    'x2': '0',
#    'y1': '0',
#    'y2': '0'},
#   'ingredients_es': {'angle': '0',
#    'coordinates_image_size': 'full',
#    'geometry': '925x227-33-908',
#    'imgid': '2',
#    'normalize': 'true',
#    'rev': '9',
#    'sizes': {'100': {'h': 25, 'w': 100},
#     '200': {'h': 49, 'w': 200},
#     '400': {'h': 98, 'w': 400},
#     'full': {'h': 227, 'w': 925}},
#    'white_magic': 'false',
#    'x1': '33.03594771241827',
#    'x2': '958.5261437908497',
#    'y1': '908.148153467116',
#    'y2': '1135.5991338592728'},
#   'nutrition_es': {'angle': '0',
#    'coordinates_image_size': 'full',
#    'geometry': '541x272-77-439',
#    'imgid': '2',
#    'normalize': 'true',
#    'rev': '10',
#    'sizes': {'100': {'h': 50, 'w': 100},
#     '200': {'h': 101, 'w': 200},
#     '400': {'h': 201, 'w': 400},
#     'full': {'h': 272, 'w': 541}},
#    'white_magic': 'false',
#    'x1': '77.48039215686272',
#    'x2': '618.656862745098',
#    'y1': '439.8257186989379',
#    'y2': '711.7211435355392'}},
#  'informers_tags': ['yuka.sY2b0xO6T85zoF3NwEKvlkwZdsb8oCj4DUP6ohW69s3RNbb6QOhq_5DCGKo',
#   'kiliweb',
#   'roboto-app',
#   'alia'],
#  'ingredients': [{'id': 'en:spinach',
#    'ingredients': [{'id': 'en:spinach',
#      'percent_estimate': 32.5,
#      'percent_max': 52,
#      'percent_min': 13,
#      'text': 'espinacas',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'from_palm_oil': 'no',
#      'id': 'en:sunflower-oil',
#      'percent_estimate': 9.75,
#      'percent_max': 26,
#      'percent_min': 0,
#      'text': 'aceite de girasol',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'id': 'en:garlic',
#      'percent_estimate': 4.875,
#      'percent_max': 17.3333333333333,
#      'percent_min': 0,
#      'text': 'ajo',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'id': 'en:salt',
#      'percent_estimate': 4.875,
#      'percent_max': 13,
#      'percent_min': 0,
#      'text': 'sal',
#      'vegan': 'yes',
#      'vegetarian': 'yes'}],
#    'percent': 52,
#    'percent_estimate': 52,
#    'percent_max': 52,
#    'percent_min': 52,
#    'text': 'Espinacas',
#    'vegan': 'yes',
#    'vegetarian': 'yes'},
#   {'id': 'en:cream',
#    'ingredients': [{'id': 'en:pasteurized-cream',
#      'percent_estimate': 23.4285714285714,
#      'percent_max': 41,
#      'percent_min': 5.85714285714286,
#      'text': '_nata_ pasteurizada',
#      'vegan': 'no',
#      'vegetarian': 'yes'},
#     {'id': 'en:water',
#      'percent_estimate': 8.78571428571429,
#      'percent_max': 20.5,
#      'percent_min': 0,
#      'text': 'agua',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'id': 'en:rice-flour',
#      'percent_estimate': 4.39285714285714,
#      'percent_max': 13.6666666666667,
#      'percent_min': 0,
#      'text': 'harina de arroz',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'id': 'en:starch',
#      'percent_estimate': 2.19642857142857,
#      'percent_max': 10.25,
#      'percent_min': 0,
#      'text': 'almidón',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'id': 'en:salt',
#      'percent_estimate': 1.09821428571428,
#      'percent_max': 8.2,
#      'percent_min': 0,
#      'text': 'sal',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'id': 'en:flavouring',
#      'ingredients': [{'id': 'en:milk',
#        'percent_estimate': 0.549107142857142,
#        'percent_max': 6.83333333333333,
#        'percent_min': 0,
#        'text': '_leche_',
#        'vegan': 'no',
#        'vegetarian': 'yes'}],
#      'percent_estimate': 0.549107142857142,
#      'percent_max': 6.83333333333333,
#      'percent_min': 0,
#      'text': 'aromas',
#      'vegan': 'maybe',
#      'vegetarian': 'maybe'},
#     {'id': 'en:nutmeg',
#      'percent_estimate': 0.549107142857139,
#      'percent_max': 5.85714285714286,
#      'percent_min': 0,
#      'text': 'nuez moscada',
#      'vegan': 'yes',
#      'vegetarian': 'yes'}],
#    'percent': 41,
#    'percent_estimate': 41,
#    'percent_max': 41,
#    'percent_min': 41,
#    'text': 'crema',
#    'vegan': 'no',
#    'vegetarian': 'yes'},
#   {'id': 'en:raisin',
#    'percent_estimate': 4.375,
#    'percent_max': 7,
#    'percent_min': 1.75,
#    'text': 'pasas',
#    'vegan': 'yes',
#    'vegetarian': 'yes'},
#   {'id': 'en:pine-nuts',
#    'percent_estimate': 1.3125,
#    'percent_max': 3.5,
#    'percent_min': 0,
#    'text': 'piñones',
#    'vegan': 'yes',
#    'vegetarian': 'yes'},
#   {'id': 'en:starch',
#    'percent_estimate': 0.65625,
#    'percent_max': 2.33333333333333,
#    'percent_min': 0,
#    'text': 'almidón',
#    'vegan': 'yes',
#    'vegetarian': 'yes'},
#   {'id': 'en:salt',
#    'percent_estimate': 0.65625,
#    'percent_max': 1.75,
#    'percent_min': 0,
#    'text': 'sal',
#    'vegan': 'yes',
#    'vegetarian': 'yes'}],
#  'ingredients_analysis_tags': ['en:palm-oil-free',
#   'en:non-vegan',
#   'en:maybe-vegetarian'],
#  'ingredients_from_or_that_may_be_from_palm_oil_n': 0,
#  'ingredients_from_palm_oil_n': 0,
#  'ingredients_from_palm_oil_tags': [],
#  'ingredients_hierarchy': ['en:spinach',
#   'en:vegetable',
#   'en:cream',
#   'en:dairy',
#   'en:raisin',
#   'en:fruit',
#   'en:grape',
#   'en:pine-nuts',
#   'en:seed',
#   'en:starch',
#   'en:salt',
#   'en:sunflower-oil',
#   'en:oil-and-fat',
#   'en:vegetable-oil-and-fat',
#   'en:vegetable-oil',
#   'en:garlic',
#   'en:root-vegetable',
#   'en:pasteurized-cream',
#   'en:water',
#   'en:rice-flour',
#   'en:flour',
#   'en:rice',
#   'en:flavouring',
#   'en:nutmeg',
#   'en:spice',
#   'en:milk'],
#  'ingredients_n': 18,
#  'ingredients_n_tags': ['18', '11-20'],
#  'ingredients_original_tags': ['en:spinach',
#   'en:cream',
#   'en:raisin',
#   'en:pine-nuts',
#   'en:starch',
#   'en:salt',
#   'en:spinach',
#   'en:sunflower-oil',
#   'en:garlic',
#   'en:salt',
#   'en:pasteurized-cream',
#   'en:water',
#   'en:rice-flour',
#   'en:starch',
#   'en:salt',
#   'en:flavouring',
#   'en:nutmeg',
#   'en:milk'],
#  'ingredients_tags': ['en:spinach',
#   'en:vegetable',
#   'en:cream',
#   'en:dairy',
#   'en:raisin',
#   'en:fruit',
#   'en:grape',
#   'en:pine-nuts',
#   'en:seed',
#   'en:starch',
#   'en:salt',
#   'en:sunflower-oil',
#   'en:oil-and-fat',
#   'en:vegetable-oil-and-fat',
#   'en:vegetable-oil',
#   'en:garlic',
#   'en:root-vegetable',
#   'en:pasteurized-cream',
#   'en:water',
#   'en:rice-flour',
#   'en:flour',
#   'en:rice',
#   'en:flavouring',
#   'en:nutmeg',
#   'en:spice',
#   'en:milk'],
#  'ingredients_text': 'Espinacas 52% (espinacas, aceite de girasol, ajo, sal), crema 41% (_nata_ pasteurizada, agua, harina de arroz, almidón, sal, aromas (_leche_), nuez moscada), pasas, piñones. almidón, sal.',
#  'ingredients_text_es': 'Espinacas 52% (espinacas, aceite de girasol, ajo, sal), crema 41% (_nata_ pasteurizada, agua, harina de arroz, almidón, sal, aromas (_leche_), nuez moscada), pasas, piñones. almidón, sal.',
#  'ingredients_text_with_allergens': 'Espinacas 52% (espinacas, aceite de girasol, ajo, sal), crema 41% (<span class="allergen">nata</span> pasteurizada, agua, harina de arroz, almidón, sal, aromas (<span class="allergen">leche</span>), nuez moscada), pasas, <span class="allergen">piñones</span>. almidón, sal.',
#  'ingredients_text_with_allergens_es': 'Espinacas 52% (espinacas, aceite de girasol, ajo, sal), crema 41% (<span class="allergen">nata</span> pasteurizada, agua, harina de arroz, almidón, sal, aromas (<span class="allergen">leche</span>), nuez moscada), pasas, <span class="allergen">piñones</span>. almidón, sal.',
#  'ingredients_that_may_be_from_palm_oil_n': 0,
#  'ingredients_that_may_be_from_palm_oil_tags': [],
#  'interface_version_created': '20150316.jqm2',
#  'interface_version_modified': '20190830',
#  'known_ingredients_n': 26,
#  'labels': 'Punto Verde',
#  'labels_hierarchy': ['en:green-dot'],
#  'labels_lc': 'es',
#  'labels_tags': ['en:green-dot'],
#  'lang': 'es',
#  'languages': {'en:spanish': 6},
#  'languages_codes': {'es': 6},
#  'languages_hierarchy': ['en:spanish'],
#  'languages_tags': ['en:spanish', 'en:1'],
#  'last_edit_dates_tags': ['2021-05-31', '2021-05', '2021'],
#  'last_editor': 'thaialagata',
#  'last_image_dates_tags': ['2021-05-03', '2021-05', '2021'],
#  'last_image_t': 1620077790,
#  'last_modified_by': 'thaialagata',
#  'last_modified_t': 1622450618,
#  'lc': 'es',
#  'link': '',
#  'main_countries_tags': [],
#  'manufacturing_places': '',
#  'manufacturing_places_tags': [],
#  'max_imgid': '2',
#  'minerals_tags': [],
#  'misc_tags': ['en:nutrition-no-fiber',
#   'en:nutrition-fruits-vegetables-nuts-estimate-from-ingredients',
#   'en:nutrition-no-fiber-or-fruits-vegetables-nuts',
#   'en:nutriscore-computed',
#   'en:ecoscore-not-computed',
#   'en:main-countries-new-product'],
#  'no_nutrition_data': '',
#  'nova_group': 4,
#  'nova_group_debug': ' -- categories/en:meals : 3 -- ingredients/en:flavouring : 4',
#  'nova_group_tags': ['not-applicable'],
#  'nova_groups': '4',
#  'nova_groups_tags': ['en:4-ultra-processed-food-and-drink-products'],
#  'nucleotides_tags': [],
#  'nutrient_levels': {'fat': 'moderate',
#   'salt': 'high',
#   'saturated-fat': 'high',
#   'sugars': 'low'},
#  'nutrient_levels_tags': ['en:fat-in-moderate-quantity',
#   'en:saturated-fat-in-high-quantity',
#   'en:sugars-in-low-quantity',
#   'en:salt-in-high-quantity'],
#  'nutriments': {'carbohydrates': 9,
#   'carbohydrates_100g': 9,
#   'carbohydrates_unit': 'g',
#   'carbohydrates_value': 9,
#   'energy': 509,
#   'energy-kcal': 122,
#   'energy-kcal_100g': 122,
#   'energy-kcal_unit': 'kcal',
#   'energy-kcal_value': 122,
#   'energy-kj': 509,
#   'energy-kj_100g': 509,
#   'energy-kj_unit': 'kJ',
#   'energy-kj_value': 509,
#   'energy_100g': 509,
#   'energy_unit': 'kJ',
#   'energy_value': 509,
#   'fat': 8,
#   'fat_100g': 8,
#   'fat_unit': 'g',
#   'fat_value': 8,
#   'fruits-vegetables-nuts-estimate-from-ingredients_100g': 53.75,
#   'nova-group': 4,
#   'nova-group_100g': 4,
#   'nova-group_serving': 4,
#   'nutrition-score-fr': 12,
#   'nutrition-score-fr_100g': 12,
#   'proteins': 3.5,
#   'proteins_100g': 3.5,
#   'proteins_unit': 'g',
#   'proteins_value': 3.5,
#   'salt': 1.73,
#   'salt_100g': 1.73,
#   'salt_unit': 'g',
#   'salt_value': 1.73,
#   'saturated-fat': 5.2,
#   'saturated-fat_100g': 5.2,
#   'saturated-fat_unit': 'g',
#   'saturated-fat_value': 5.2,
#   'sodium': 0.692,
#   'sodium_100g': 0.692,
#   'sodium_unit': 'g',
#   'sodium_value': 0.692,
#   'sugars': 3,
#   'sugars_100g': 3,
#   'sugars_unit': 'g',
#   'sugars_value': 3},
#  'nutriscore_data': {'energy': 509,
#   'energy_points': 1,
#   'energy_value': 509,
#   'fiber': 0,
#   'fiber_points': 0,
#   'fiber_value': 0,
#   'fruits_vegetables_nuts_colza_walnut_olive_oils': 53.75,
#   'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 1,
#   'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 53.8,
#   'grade': 'd',
#   'is_beverage': 0,
#   'is_cheese': 0,
#   'is_fat': 0,
#   'is_water': 0,
#   'negative_points': 13,
#   'positive_points': 1,
#   'proteins': 3.5,
#   'proteins_points': 2,
#   'proteins_value': 3.5,
#   'saturated_fat': 5.2,
#   'saturated_fat_points': 5,
#   'saturated_fat_ratio': 65,
#   'saturated_fat_ratio_points': 10,
#   'saturated_fat_ratio_value': 65,
#   'saturated_fat_value': 5.2,
#   'score': 12,
#   'sodium': 692,
#   'sodium_points': 7,
#   'sodium_value': 692,
#   'sugars': 3,
#   'sugars_points': 0,
#   'sugars_value': 3},
#  'nutriscore_grade': 'd',
#  'nutriscore_score': 12,
#  'nutriscore_score_opposite': -12,
#  'nutrition_data': 'on',
#  'nutrition_data_per': '100g',
#  'nutrition_data_prepared': '',
#  'nutrition_data_prepared_per': '100g',
#  'nutrition_grade_fr': 'd',
#  'nutrition_grades': 'd',
#  'nutrition_grades_tags': ['d'],
#  'nutrition_score_beverage': 0,
#  'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients': 1,
#  'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value': 53.75,
#  'nutrition_score_warning_no_fiber': 1,
#  'origins': '',
#  'origins_hierarchy': [],
#  'origins_lc': 'es',
#  'origins_tags': [],
#  'other_nutritional_substances_tags': [],
#  'packaging': 'Green dot',
#  'packaging_tags': ['green-dot'],
#  'packaging_text': '',
#  'packaging_text_es': '',
#  'packagings': [{'material': 'en:unknown', 'shape': 'en:unknown'}],
#  'photographers_tags': ['kiliweb'],
#  'pnns_groups_1': 'Composite foods',
#  'pnns_groups_1_tags': ['composite-foods', 'known'],
#  'pnns_groups_2': 'One-dish meals',
#  'pnns_groups_2_tags': ['one-dish-meals', 'known'],
#  'popularity_key': 12,
#  'product_name': 'Espinacas a la crema',
#  'product_name_es': 'Espinacas a la crema',
#  'product_quantity': 300,
#  'purchase_places': '',
#  'purchase_places_tags': [],
#  'quantity': '300g',
#  'removed_countries_tags': [],
#  'rev': 13,
#  'selected_images': {'front': {'display': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.400.jpg'},
#    'small': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.200.jpg'},
#    'thumb': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/front_es.8.100.jpg'}},
#   'ingredients': {'display': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.400.jpg'},
#    'small': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.200.jpg'},
#    'thumb': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/ingredients_es.9.100.jpg'}},
#   'nutrition': {'display': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.400.jpg'},
#    'small': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.200.jpg'},
#    'thumb': {'es': 'https://static.openfoodfacts.org/images/products/007/265/113/00821001676/nutrition_es.10.100.jpg'}}},
#  'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:origins-to-be-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#  'states_hierarchy': ['en:to-be-completed',
#   'en:nutrition-facts-completed',
#   'en:ingredients-completed',
#   'en:expiration-date-completed',
#   'en:packaging-code-to-be-completed',
#   'en:characteristics-to-be-completed',
#   'en:origins-to-be-completed',
#   'en:categories-completed',
#   'en:brands-completed',
#   'en:packaging-completed',
#   'en:quantity-completed',
#   'en:product-name-completed',
#   'en:photos-to-be-validated',
#   'en:packaging-photo-to-be-selected',
#   'en:nutrition-photo-selected',
#   'en:ingredients-photo-selected',
#   'en:front-photo-selected',
#   'en:photos-uploaded'],
#  'states_tags': ['en:to-be-completed',
#   'en:nutrition-facts-completed',
#   'en:ingredients-completed',
#   'en:expiration-date-completed',
#   'en:packaging-code-to-be-completed',
#   'en:characteristics-to-be-completed',
#   'en:origins-to-be-completed',
#   'en:categories-completed',
#   'en:brands-completed',
#   'en:packaging-completed',
#   'en:quantity-completed',
#   'en:product-name-completed',
#   'en:photos-to-be-validated',
#   'en:packaging-photo-to-be-selected',
#   'en:nutrition-photo-selected',
#   'en:ingredients-photo-selected',
#   'en:front-photo-selected',
#   'en:photos-uploaded'],
#  'stores': '',
#  'stores_tags': [],
#  'traces': 'en:crustaceans,en:eggs,en:fish,en:gluten,en:mustard,en:soybeans,en:sulphur-dioxide-and-sulphites',
#  'traces_from_ingredients': '',
#  'traces_from_user': '(es) Crustáceos,Huevos,Pescado,Gluten,Mostaza,Soja,Dióxido de azufre y sulfitos',
#  'traces_hierarchy': ['en:crustaceans',
#   'en:eggs',
#   'en:fish',
#   'en:gluten',
#   'en:mustard',
#   'en:soybeans',
#   'en:sulphur-dioxide-and-sulphites'],
#  'traces_lc': 'es',
#  'traces_tags': ['en:crustaceans',
#   'en:eggs',
#   'en:fish',
#   'en:gluten',
#   'en:mustard',
#   'en:soybeans',
#   'en:sulphur-dioxide-and-sulphites'],
#  'unknown_ingredients_n': 0,
#  'unknown_nutrients_tags': [],
#  'update_key': 'main-countries',
#  'url': 'https://world.openfoodfacts.org/product/00726511300821001676/espinacas-a-la-crema-bonarea',
#  'vitamins_tags': []}

# %%
for product in products:
    print(product['product_name'])
# Out:
# Mini sticks nature auvernou
# Espinacas a la crema
# Nos œufs bio
# Haché de Jambon - à l'Emmental
# Filet de saumon & pâtes au basilic, sauce citron
# Le Moelleux
# Le Kebab de Poulet et sa Semoule à l'Orientale
# Le Moelleux
# Haché de Jambon - à Pôeler
# Le surimi râpé
# Penne complètes & légumes du soleil
# Le Gratin Butternut Pâtes & Poulet et sa sauce crème & emmental
# Le Couscous à la Marocaine et ses légumes
# Le Délice à la chair de crabe
# Le Moelleux
# Petites Gambas & tagliatelles au basilic
# Sopa De Pollo Y Fideos 70 GR
# Homesoy soya milk
# Nissin Lámen Galinha Caipira
# Panés au colin d'Alaska
# Tavoletta cioccolato rosa e melograno
# Tavoletta CIOCCOLATO FONDENTE 72%
# Cioccolato Fondente con frutti di bosco
# Boudins noirs aux Pommes

# %%
products[0].keys()
# Out:
# dict_keys(['_id', '_keywords', 'added_countries_tags', 'additives_debug_tags', 'additives_n', 'additives_old_n', 'additives_old_tags', 'additives_original_tags', 'additives_prev_original_tags', 'additives_tags', 'additives_tags_n', 'allergens', 'allergens_from_ingredients', 'allergens_from_user', 'allergens_hierarchy', 'allergens_lc', 'allergens_tags', 'amino_acids_prev_tags', 'amino_acids_tags', 'brands', 'brands_tags', 'categories', 'categories_hierarchy', 'categories_lc', 'categories_old', 'categories_properties', 'categories_properties_tags', 'categories_tags', 'category_properties', 'checkers_tags', 'ciqual_food_name_tags', 'cities_tags', 'code', 'codes_tags', 'compared_to_category', 'complete', 'completeness', 'correctors_tags', 'countries', 'countries_hierarchy', 'countries_lc', 'countries_tags', 'created_t', 'creator', 'data_quality_bugs_tags', 'data_quality_errors_tags', 'data_quality_info_tags', 'data_quality_tags', 'data_quality_warnings_tags', 'data_sources', 'data_sources_tags', 'debug_param_sorted_langs', 'ecoscore_data', 'ecoscore_grade', 'ecoscore_score', 'ecoscore_tags', 'editors', 'editors_tags', 'emb_codes', 'emb_codes_20141016', 'emb_codes_orig', 'emb_codes_tags', 'entry_dates_tags', 'environment_impact_level', 'environment_impact_level_tags', 'expiration_date', 'fruits-vegetables-nuts_100g_estimate', 'generic_name', 'generic_name_de', 'generic_name_en', 'generic_name_fr', 'generic_name_nl', 'id', 'image_front_small_url', 'image_front_thumb_url', 'image_front_url', 'image_ingredients_small_url', 'image_ingredients_thumb_url', 'image_ingredients_url', 'image_nutrition_small_url', 'image_nutrition_thumb_url', 'image_nutrition_url', 'image_small_url', 'image_thumb_url', 'image_url', 'images', 'informers_tags', 'ingredients', 'ingredients_analysis_tags', 'ingredients_debug', 'ingredients_from_or_that_may_be_from_palm_oil_n', 'ingredients_from_palm_oil_n', 'ingredients_from_palm_oil_tags', 'ingredients_hierarchy', 'ingredients_ids_debug', 'ingredients_n', 'ingredients_n_tags', 'ingredients_original_tags', 'ingredients_tags', 'ingredients_text', 'ingredients_text_de', 'ingredients_text_debug', 'ingredients_text_en', 'ingredients_text_fr', 'ingredients_text_nl', 'ingredients_text_with_allergens', 'ingredients_text_with_allergens_de', 'ingredients_text_with_allergens_en', 'ingredients_text_with_allergens_fr', 'ingredients_text_with_allergens_nl', 'ingredients_that_may_be_from_palm_oil_n', 'ingredients_that_may_be_from_palm_oil_tags', 'interface_version_created', 'interface_version_modified', 'known_ingredients_n', 'labels', 'labels_hierarchy', 'labels_lc', 'labels_tags', 'lang', 'languages', 'languages_codes', 'languages_hierarchy', 'languages_tags', 'last_edit_dates_tags', 'last_editor', 'last_image_dates_tags', 'last_image_t', 'last_modified_by', 'last_modified_t', 'lc', 'link', 'main_countries_tags', 'manufacturing_places', 'manufacturing_places_tags', 'max_imgid', 'minerals_prev_tags', 'minerals_tags', 'misc_tags', 'no_nutrition_data', 'nova_group', 'nova_group_debug', 'nova_groups', 'nova_groups_tags', 'nucleotides_prev_tags', 'nucleotides_tags', 'nutrient_levels', 'nutrient_levels_tags', 'nutriments', 'nutriscore_data', 'nutriscore_grade', 'nutriscore_score', 'nutriscore_score_opposite', 'nutrition_data', 'nutrition_data_per', 'nutrition_data_prepared', 'nutrition_data_prepared_per', 'nutrition_grade_fr', 'nutrition_grades', 'nutrition_grades_tags', 'nutrition_score_beverage', 'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients', 'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value', 'obsolete', 'obsolete_since_date', 'origins', 'origins_hierarchy', 'origins_lc', 'origins_old', 'origins_tags', 'other_nutritional_substances_tags', 'packaging', 'packaging_tags', 'packagings', 'photographers_tags', 'pnns_groups_1', 'pnns_groups_1_tags', 'pnns_groups_2', 'pnns_groups_2_tags', 'popularity_key', 'popularity_tags', 'product_name', 'product_name_de', 'product_name_en', ...

# %%
type(products)
# Out:
# list

# %% [markdown]
# ### Requête d'un produit en particulier via le barcode

# %%
barcode = '3036810201280'
product = openfoodfacts.products.get_product(barcode)
print(product['product']['product_name'])
print("keys du dictionnaire :", list(product.keys()))
product
# Out:
# Dijon Originale
# keys du dictionnaire : ['code', 'product', 'status', 'status_verbose']
# {'code': '3036810201280',
#  'product': {'_id': '3036810201280',
#   '_keywords': ['lebensmittel',
#    'gewurzmittel',
#    'dijon-senfe',
#    'unspecified',
#    'dijon-senf',
#    'saucen',
#    'originale',
#    'dijon',
#    'senfe',
#    'maille'],
#   'added_countries_tags': [],
#   'additives_debug_tags': [],
#   'additives_n': 2,
#   'additives_old_n': 1,
#   'additives_old_tags': ['en:e330'],
#   'additives_original_tags': ['en:e330', 'en:e224'],
#   'additives_prev_original_tags': ['en:e330', 'en:e224'],
#   'additives_tags': ['en:e224', 'en:e330'],
#   'allergens': 'en:mustard,de:Kaliummetabisulfit',
#   'allergens_from_ingredients': '',
#   'allergens_from_user': '(en) en:mustard,de:Kaliummetabisulfit',
#   'allergens_hierarchy': ['en:mustard', 'de:Kaliummetabisulfit'],
#   'allergens_lc': 'en',
#   'allergens_tags': ['en:mustard', 'de:kaliummetabisulfit'],
#   'amino_acids_prev_tags': [],
#   'amino_acids_tags': [],
#   'brands': 'Maille',
#   'brands_tags': ['maille'],
#   'categories': 'Lebensmittel, Gewürzmittel, Saucen, Senfe, Dijon-Senfe',
#   'categories_hierarchy': ['en:groceries',
#    'en:condiments',
#    'en:sauces',
#    'en:mustards',
#    'en:dijon-mustards'],
#   'categories_lc': 'de',
#   'categories_old': 'Groceries,Condiments,Sauces,Mustards,Dijon mustards',
#   'categories_properties': {'agribalyse_food_code:en': '11013',
#    'ciqual_food_code:en': '11013'},
#   'categories_properties_tags': ['all-products',
#    'categories-known',
#    'agribalyse-food-code-11013',
#    'agribalyse-food-code-known',
#    'agribalyse-proxy-food-code-unknown',
#    'ciqual-food-code-11013',
#    'ciqual-food-code-known',
#    'agribalyse-known',
#    'agribalyse-11013'],
#   'categories_tags': ['en:groceries',
#    'en:condiments',
#    'en:sauces',
#    'en:mustards',
#    'en:dijon-mustards'],
#   'category_properties': {'ciqual_food_name:en': 'Mustard',
#    'ciqual_food_name:fr': 'Moutarde'},
#   'checkers_tags': [],
#   'ciqual_food_name_tags': ['mustard'],
#   'cities_tags': [],
#   'code': '3036810201280',
#   'codes_tags': ['code-13',
#    '3036810201xxx',
#    '303681020xxxx',
#    '30368102xxxxx',
#    '3036810xxxxxx',
#    '303681xxxxxxx',
#    '30368xxxxxxxx',
#    '3036xxxxxxxxx',
#    '303xxxxxxxxxx',
#    '30xxxxxxxxxxx',
#    '3xxxxxxxxxxxx'],
#   'compared_to_category': 'en:dijon-mustards',
#   'complete': 0,
#   'completeness': 0.9625,
#   'correctors_tags': ['date-limite-app',
#    'teolemon',
#    'smias',
#    'tacite',
#    'kakao',
#    'yuka.WW9rUUYvNGt2TlVndE5zQW9UWDcrUEZ6eTRHZ0JXcnNDdk5LSUE9PQ',
#    'yukafix',
#    'tacite-mass-editor',
#    'jbarcelona',
#    'havtorn',
#    'yuka.VGFRRFM2a0krOTA2bmNNbDF5emUrTndybXBtR1VXcThOdEVvSVE9PQ',
#    'archanox',
#    'scanbot',
#    'thaialagata',
#    'kandy971',
#    'yuka.ZXA0a0Mvb0dnNkZhZzlvajF6RDBxOUlwM01hV1JHK3FCY1lUSVE9PQ',
#    'gourmet',
#    'yuka.YUswcEVMUU5uUGtFdnRnazVqT014Y2xWLzd5NFltT1JkTTRMSWc9PQ',
#    'yuka.Vi9FUklyNWRnOFFSd2NObThVbnAydlZUK3BDMVFrZVBLdXMwSVE9PQ',
#    'musarana',
#    'prepperapp',
#    'yuka.SHI4L1BwUSt1UFVBdzhNMy9Dai8rWWhleUkycmIwV1VKK2dSSWc9PQ',
#    'yuka.Zi9nRkcvOENnOXNyb3NjZzhFcklwSWg2M2FHcWRsKzdNdFk0SVE9PQ',
#    'kiliweb',
#    'yuka.RzVrNUVweGZ0OEZScHZZbHd5TEszZXhyNnNHWFZudVpJTXN0SVE9PQ',
#    'yuka.WkowQ0FZNE5wOTBnd3ZjNzd4cktvY3hIN1ptTUFFR1pDclE2SVE9PQ',
#    'yuka.K7FHG9yMGPd8RsXZ_Yge8WCePv7kBPFeFXkToQ',
#    'openfoodfacts-contributors',
#    'jordibrus',
#    'sebleouf',
#    'chevalstar',
#    'charlesnepote',
#    'inf'],
#   'countries': 'France,Germany,Italy,Portugal,Romania,Spain,Switzerland,Australia,Netherlands,Belgium,Sweden',
#   'countries_beforescanbot': 'Australie,Belgique,France,Allemagne,Italie,Pays-Bas,Portugal,Espagne,Suède,Suisse, en:romania',
#   'countries_hierarchy': ['en:australia',
#    'en:belgium',
#    'en:france',
#    'en:germany',
#    'en:italy',
#    'en:netherlands',
#    'en:portugal',
#    'en:romania',
#    'en:spain',
#    'en:sweden',
#    'en:switzerland'],
#   'countries_lc': 'en',
#   'countries_tags': ['en:australia',
#    'en:belgium',
#    'en:france',
#    'en:germany',
#    'en:italy',
#    'en:netherlands',
#    'en:portugal',
#    'en:romania',
#    'en:spain',
#    'en:sweden',
#    'en:switzerland'],
#   'created_t': 1415014704,
#   'creator': 'openfoodfacts-contributors',
#   'data_quality_bugs_tags': [],
#   'data_quality_errors_tags': [],
#   'data_quality_info_tags': ['en:packaging-data-incomplete',
#    'en:ingredients-percent-analysis-ok'],
#   'data_quality_tags': ['en:packaging-data-incomplete',
#    'en:ingredients-percent-analysis-ok',
#    'en:ingredients-en-ending-comma',
#    'en:ingredients-de-ending-comma',
#    'en:ecoscore-packaging-unspecified-shape',
#    'en:ecoscore-production-system-no-label'],
#   'data_quality_warnings_tags': ['en:ingredients-en-ending-comma',
#    'en:ingredients-de-ending-comma',
#    'en:ecoscore-packaging-unspecified-shape',
#    'en:ecoscore-production-system-no-label'],
#   'data_sources': 'App - yuka, Apps',
#   'data_sources_tags': ['app-yuka', 'apps'],
#   'debug_param_sorted_langs': ['de', 'es', 'fr'],
#   'ecoscore_data': {'adjustments': {'origins_of_ingredients': {'aggregated_origins': [{'origin': 'en:unspecified',
#        'percent': 100}],
#      'epi_score': 0,
#      'epi_value': -5,
#      'origins_from_origins_field': ['en:unspecified'],
#      'transportation_score_be': 0,
#      'transportation_score_ch': 0,
#      'transportation_score_de': 0,
#      'transportation_score_es': 0,
#      'transportation_score_fr': 0,
#      'transportation_score_ie': 0,
#      'transportation_score_it': 0,
#      'transportation_score_lu': 0,
#      'transportation_score_nl': 0,
#      'transportation_value_be': 0,
#      'transportation_value_ch': 0,
#      'transportation_value_de': 0,
#      'transportation_value_es': 0,
#      'transportation_value_fr': 0,
#      'transportation_value_ie': 0,
#      'transportation_value_it': 0,
#      'transportation_value_lu': 0,
#      'transportation_value_nl': 0,
#      'value_be': -5,
#      'value_ch': -5,
#      'value_de': -5,
#      'value_es': -5,
#      'value_fr': -5,
#      'value_ie': -5,
#      'value_it': -5,
#      'value_lu': -5,
#      'value_nl': -5},
#     'packaging': {'non_recyclable_and_non_biodegradable_materials': 0,
#      'packagings': [{'ecoscore_material_score': '76',
#        'ecoscore_shape_ratio': 1,
#        'material': 'en:steel',
#        'shape': 'en:unknown'}],
#      'score': 76,
#      'value': -2,
#      'warning': 'unspecified_shape'},
#     'production_system': {'warning': 'no_label'},
#     'threatened_species': {}},
#    'agribalyse': {'agribalyse_food_code': '11013',
#     'co2_agriculture': '0.61047871',
#     'co2_consumption': '0',
#     'co2_distribution': '0.016095913',
#     'co2_packaging': '0.64841333',
#     'co2_processing': '0.21859249',
#     'co2_total': '1.6820828',
#     'co2_transportation': '0.18845221',
#     'code': '11013',
#     'dqr': '2.47',
#     'ef_agriculture': '0.17746254',
#     'ef_consumption': '0',
#     'ef_distribution': '0.0047842479',
#     'ef_packaging': '0.067319121',
#     'ef_processing': '0.044880986',
#     'ef_total': '0.30922658999999997',
#     'ef_transportation': '0.014774955999999999',
#     'is_beverage': 0,
#     'name_en': 'Mustard',
#     'name_fr': 'Moutarde',
#     'score': 75},
#    'grade': 'b',
#    'grade_be': 'b',
#    'grade_ch': 'b',
#    'grade_de': 'b',
#    'grade_es': 'b',
#    'grade_fr': 'b',
#    'grade_ie': 'b',
#    'grade_it': 'b',
#    'grade_lu': 'b',
#    'grade_nl': 'b',
#    'missing': {'labels': 1, 'packagings': 1},
#    'missing_data_warning': 1,
#    'score': 73,
#    'score_be': 68,
#    'score_ch': 68,
#    'score_de': 68,
#    'score_es': 68,
#    'score_fr': 68,
#    'score_ie': 68,
#    'score_it': 68,
#    'score_lu': 68,
#    'score_nl': 68,
#    'status': 'known'},
#   'ecoscore_grade': 'b',
#   'ecoscore_score': 73,
#   'ecoscore_tags': ['b'],
#   'editors': [''],
#   'editors_tags': ['yuka.VGFRRFM2a0krOTA2bmNNbDF5emUrTndybXBtR1VXcThOdEVvSVE9PQ',
#    'yuka.Zi9nRkcvOENnOXNyb3NjZzhFcklwSWg2M2FHcWRsKzdNdFk0SVE9PQ',
#    'yuka.Vi9FUklyNWRnOFFSd2NObThVbnAydlZUK3BDMVFrZVBLdXMwSVE9PQ',
#    'kiliweb',
#    'yuka.WkowQ0FZNE5wOTBnd3ZjNzd4cktvY3hIN1ptTUFFR1pDclE2SVE9PQ',
#    'smias',
#    'yuka.RzVrNUVweGZ0OEZScHZZbHd5TEszZXhyNnNHWFZudVpJTXN0SVE9PQ',
#    'jbarcelona',
#    'archanox',
#    'scanbot',
#    'date-limite-app',
#    'tacite',
#    'teolemon',
#    'aleene',
#    'thaialagata',
#    'openfoodfacts-contributors',
#    'tacite-mass-editor',
#    'yuka.WW9rUUYvNGt2TlVndE5zQW9UWDcrUEZ6eTRHZ0JXcnNDdk5LSUE9PQ',
#    'havtorn',
#    'musarana',
#    'sebleouf',
#    'kandy971',
#    'gourmet',
#    'jordibrus',
#    'foodrepo',
#    'kakao',
#    'yuka.K7FHG9yMGPd8RsXZ_Yge8WCePv7kBPFeFXkToQ',
#    'yuka.SHI4L1BwUSt1UFVBdzhNMy9Dai8rWWhleUkycmIwV1VKK2dSSWc9PQ',
#    'inf',
#    'prepperapp',
#    'chevalstar',
#    'charlesnepote',
#    'yukafix',
#    'yuka.YUswcEVMUU5uUGtFdnRnazVqT014Y2xWLzd5NFltT1JkTTRMSWc9PQ',
#    'yuka.ZXA0a0Mvb0dnNkZhZzlvajF6RDBxOUlwM01hV1JHK3FCY1lUSVE9PQ'],
#   'emb_codes': '',
#   'emb_codes_20141016': '',
#   'emb_codes_orig': '',
#   'emb_codes_tags': [],
#   'entry_dates_tags': ['2014-11-03', '2014-11', '2014'],
#   'environment_impact_level': '',
#   'environment_impact_level_tags': [],
#   'expiration_date': '2018-06-02',
#   'fruits-vegetables-nuts_100g_estimate': 0,
#   'generic_name': 'Dijon-Senf',
#   'generic_name_de': 'Dijon-Senf',
#   'generic_name_es': '',
#   'generic_name_fr': '',
#   'generic_name_xx': '',
#   'generic_name_xx_debug_tags': [],
#   'id': '3036810201280',
#   'image_front_small_url': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front.3.200.jpg',
#   'image_front_thumb_url': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front.3.100.jpg',
#   'image_front_url': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front.3.400.jpg',
#   'image_small_url': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front.3.200.jpg',
#   'image_thumb_url': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front.3.100.jpg',
#   'image_url': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front.3.400.jpg',
#   'images': {'1': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 3264, 'w': 2448}},
#     'uploaded_t': 1415014705,
#     'uploader': 'openfoodfacts-contributors'},
#    '10': {'sizes': {'100': {'h': 100, 'w': 56},
#      '400': {'h': 400, 'w': 225},
#      'full': {'h': 1000, 'w': 563}},
#     'uploaded_t': 1554150317,
#     'uploader': 'foodrepo'},
#    '11': {'sizes': {'100': {'h': 100, 'w': 56},
#      '400': {'h': 400, 'w': 225},
#      'full': {'h': 1000, 'w': 563}},
#     'uploaded_t': 1554150317,
#     'uploader': 'foodrepo'},
#    '12': {'sizes': {'100': {'h': 100, 'w': 56},
#      '400': {'h': 400, 'w': 225},
#      'full': {'h': 1000, 'w': 563}},
#     'uploaded_t': 1554150318,
#     'uploader': 'foodrepo'},
#    '13': {'sizes': {'100': {'h': 100, 'w': 92},
#      '400': {'h': 400, 'w': 366},
#      'full': {'h': 1200, 'w': 1098}},
#     'uploaded_t': 1559670236,
#     'uploader': 'kiliweb'},
#    '14': {'sizes': {'100': {'h': 100, 'w': 62},
#      '400': {'h': 400, 'w': 247},
#      'full': {'h': 400, 'w': 247}},
#     'uploaded_t': 1570867470,
#     'uploader': 'date-limite-app'},
#    '15': {'sizes': {'100': {'h': 100, 'w': 100},
#      '400': {'h': 400, 'w': 400},
#      'full': {'h': 600, 'w': 600}},
#     'uploaded_t': 1571170181,
#     'uploader': 'thaialagata'},
#    '16': {'sizes': {'100': {'h': 100, 'w': 100},
#      '400': {'h': 400, 'w': 398},
#      'full': {'h': 1211, 'w': 1206}},
#     'uploaded_t': 1572094881,
#     'uploader': 'aleene'},
#    '17': {'sizes': {'100': {'h': 100, 'w': 89},
#      '400': {'h': 400, 'w': 358},
#      'full': {'h': 1333, 'w': 1193}},
#     'uploaded_t': 1572094882,
#     'uploader': 'aleene'},
#    '18': {'sizes': {'100': {'h': 100, 'w': 87},
#      '400': {'h': 400, 'w': 348},
#      'full': {'h': 1200, 'w': 1044}},
#     'uploaded_t': 1574708096,
#     'uploader': 'kiliweb'},
#    '19': {'sizes': {'100': {'h': 88, 'w': 100},
#      '400': {'h': 353, 'w': 400},
#      'full': {'h': 1200, 'w': 1360}},
#     'uploaded_t': 1577189639,
#     'uploader': 'kiliweb'},
#    '2': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 2666, 'w': 2000}},
#     'uploaded_t': 1421600785,
#     'uploader': 'openfoodfacts-contributors'},
#    '20': {'sizes': {'100': {'h': 100, 'w': 62},
#      '400': {'h': 400, 'w': 247},
#      'full': {'h': 1619, 'w': 1000}},
#     'uploaded_t': 1585664283,
#     'uploader': 'date-limite-app'},
#    '21': {'sizes': {'100': {'h': 96, 'w': 100},
#      '400': {'h': 384, 'w': 400},
#      'full': {'h': 1200, 'w': 1249}},
#     'uploaded_t': 1586888210,
#     'uploader': 'kiliweb'},
#    '22': {'sizes': {'100': {'h': 93, 'w': 100},
#      '400': {'h': 373, 'w': 400},
#      'full': {'h': 1194, 'w': 1280}},
#     'uploaded_t': 1588443070,
#     'uploader': 'kiliweb'},
#    '23': {'sizes': {'100': {'h': 100, 'w': 94},
#      '400': {'h': 400, 'w': 376},
#      'full': {'h': 1200, 'w': 1127}},
#     'uploaded_t': 1589027300,
#     'uploader': 'kiliweb'},
#    '24': {'sizes': {'100': {'h': 99, 'w': 100},
#      '400': {'h': 397, 'w': 400},
#      'full': {'h': 1200, 'w': 1209}},
#     'uploaded_t': 1589027417,
#     'uploader': 'kiliweb'},
#    '25': {'sizes': {'100': {'h': 75, 'w': 100},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 750, 'w': 1000}},
#     'uploaded_t': 1598715201,
#     'uploader': 'date-limite-app'},
#    '26': {'sizes': {'100': {'h': 24, 'w': 100},
#      '400': {'h': 95, 'w': 400},
#      'full': {'h': 628, 'w': 2636}},
#     'uploaded_t': 1601292671,
#     'uploader': 'jordibrus'},
#    '3': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 1333, 'w': 1000}},
#     'uploaded_t': '1484398582',
#     'uploader': 'date-limite-app'},
#    '4': {'sizes': {'100': {'h': 75, 'w': 100},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 1500, 'w': 2000}},
#     'uploaded_t': '1490446808',
#     'uploader': 'smias'},
#    '5': {'sizes': {'100': {'h': 100, 'w': 75},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 2666, 'w': 2000}},
#     'uploaded_t': '1490446822',
#     'uploader': 'smias'},
#    '6': {'sizes': {'100': {'h': 75, 'w': 100},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 1500, 'w': 2000}},
#     'uploaded_t': '1495878972',
#     'uploader': 'kakao'},
#    '7': {'sizes': {'100': {'h': 75, 'w': 100},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 1500, 'w': 2000}},
#     'uploaded_t': '1495878994',
#     'uploader': 'kakao'},
#    '8': {'sizes': {'100': {'h': 75, 'w': 100},
#      '400': {'h': 300, 'w': 400},
#      'full': {'h': 1500, 'w': 2000}},
#     'uploaded_t': '1495879013',
#     'uploader': 'kakao'},
#    '9': {'sizes': {'100': {'h': 81, 'w': 100},
#      '400': {'h': 324, 'w': 400},
#      'full': {'h': 1996, 'w': 2462}},
#     'uploaded_t': '1517143843',
#     'uploader': 'kiliweb'},
#    'front': {'geometry': '0x0--8--8',
#     'imgid': '1',
#     'normalize': None,
#     'rev': '3',
#     'sizes': {'100': {'h': 100, 'w': 75},
#      '200': {'h': 200, 'w': 150},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 3264, 'w': 2448}},
#     'white_magic': None},
#    'front_de': {'angle': '270',
#     'geometry': '720x1165-481-169',
#     'imgid': '6',
#     'normalize': 'false',
#     'rev': '25',
#     'sizes': {'100': {'h': 100, 'w': 62},
#      '200': {'h': 200, 'w': 124},
#      '400': {'h': 400, 'w': 247},
#      'full': {'h': 1165, 'w': 720}},
#     'white_magic': 'false',
#     'x1': '96.23333740234376',
#     'x2': '240.2333374023438',
#     'y1': '33.83331298828126',
#     'y2': '266.8333129882813'},
#    'front_es': {'angle': '0',
#     'geometry': '0x0-0-0',
#     'imgid': '15',
#     'normalize': 'false',
#     'rev': '62',
#     'sizes': {'100': {'h': 100, 'w': 68},
#      '200': {'h': 200, 'w': 137},
#      '400': {'h': 400, 'w': 273},
#      'full': {'h': 600, 'w': 410}},
#     'white_magic': 'true',
#     'x1': '0',
#     'x2': '0',
#     'y1': '0',
#     'y2': '0'},
#    'front_fr': {'geometry': '0x0--8--8',
#     'imgid': '1',
#     'normalize': None,
#     'rev': '3',
#     'sizes': {'100': {'h': 100, 'w': 75},
#      '200': {'h': 200, 'w': 150},
#      '400': {'h': 400, 'w': 300},
#      'full': {'h': 3264, 'w': 2448}},
#     'white_magic': None},
#    'ingredients_de': {'angle': '270',
#     'geometry': '935x185-76-955',
#     'imgid': '7',
#     'normalize': 'false',
#     'ocr': 1,
#     'orientation': '0',
#     'rev': '22',
#     'sizes': {'100': {'h': 20, 'w': 100},
#      '200': {'h': 40, 'w': 200},
#      '400': {'h': 79, 'w': 400},
#      'full': {'h': 185, 'w': 935}},
#     'white_magic': 'false',
#     'x1': '15.233337402343752',
#     'x2': '202.23333740234378',
#     'y1': '191.01666259765628',
#     'y2': '228.01666259765628'},
#    'ingredients_es': {'angle': None,
#     'geometry': '0x0-0-0',
#     'imgid': '26',
#     'normalize': None,
#     'rev': '133',
#     'sizes': {'100': {'h': 24, 'w': 100},
#      '200': {'h': 48, 'w': 200},
#      '400': {'h': 95, 'w': 400},
#      'full': {'h': 628, 'w': 2636}},
#     'white_magic': None,
#     'x1': None,
#     'x2': None,
#     'y1': None,
#     'y2': None},
#    'ingredients_fr': {'angle': None,
#     'geometry': '0x0-0-0',
#     'imgid': '9',
#     'normalize': '0',
#     'ocr': 1,
#     'orientation': '0',
#     'rev': '28',
#     'sizes': {'100': {'h': 81, 'w': 100},
#      '200': {'h': 162, 'w': 200},
#      '400': {'h': 324, 'w': 400},
#      'full': {'h': 1996, 'w': 2462}},
#     'white_magic': '0',
#     'x1': None,
#     'x2': None,
#     'y1': None,
#     'y2': None},
#    'nutrition_de': {'angle': '90',
#     'geometry': '912x815-201-666',
#     'imgid': '8',
#     'normalize': 'false',
#     'rev': '119',
#     'sizes': {'100': {'h': 89, 'w': 100},
#      '200': {'h': 179, 'w': 200},
#      '400': {'h': 357, 'w': 400},
#      'full': {'h': 815, 'w': 912}},
#     'white_magic': 'false',
#     'x1': '201.14636295056218',
#     'x2': '1113.8447756489747',
#     'y1': '666.5338586877893',
#     'y2': '1481.348673502604'},
#    'nutrition_fr': {'angle': '0',
#     'geometry': '893x693-633-985',
#     'imgid': '5',
#     'normalize': 'false',
#     'ocr': 1,
#     'orientation': '0',
#     'rev': '16',
#     'sizes': {'100': {'h': 78, 'w': 100},
#      '200': {'h': 155, 'w': 200},
#      '400': {'h': 310, 'w': 400},
#      'full': {'h': 693, 'w': 893}},
#     'white_magic': 'false',
#     'x1': '95',
#     'x2': '229',
#     'y1': '147.8125',
#     'y2': '251.8125'}},
#   'informers_tags': ['openfoodfacts-contributors',
#    'date-limite-app',
#    'teolemon',
#    'tacite',
#    'kakao',
#    'tacite-mass-editor',
#    'jbarcelona',
#    'thaialagata',
#    'gourmet',
#    'jordibrus',
#    'inf'],
#   'ingredients': [{'id': 'en:water',
#     'percent_estimate': 58.3333333333333,
#     'percent_max': 100,
#     'percent_min': 16.6666666666667,
#     'rank': 1,
#     'text': 'water',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:mustard grains',
#     'percent_estimate': 20.8333333333333,
#     'percent_max': 50,
#     'percent_min': 0,
#     'rank': 2,
#     'text': 'mustard grains'},
#    {'id': 'en:brandy vinegar',
#     'percent_estimate': 10.4166666666667,
#     'percent_max': 33.3333333333333,
#     'percent_min': 0,
#     'rank': 3,
#     'text': 'brandy vinegar'},
#    {'id': 'en:salt',
#     'percent_estimate': 5.20833333333333,
#     'percent_max': 25,
#     'percent_min': 0,
#     'rank': 4,
#     'text': 'salt',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'has_sub_ingredients': 'yes',
#     'id': 'en:acid',
#     'percent_estimate': 2.60416666666666,
#     'percent_max': 20,
#     'percent_min': 0,
#     'rank': 5,
#     'text': 'acidifier'},
#    {'has_sub_ingredients': 'yes',
#     'id': 'en:preservative',
#     'percent_estimate': 2.60416666666666,
#     'percent_max': 16.6666666666667,
#     'percent_min': 0,
#     'rank': 6,
#     'text': 'preservative'},
#    {'id': 'en:e330',
#     'percent_estimate': 2.60416666666666,
#     'percent_max': 20,
#     'percent_min': 0,
#     'text': 'citric acid',
#     'vegan': 'yes',
#     'vegetarian': 'yes'},
#    {'id': 'en:e224',
#     'percent_estimate': 2.60416666666666,
#     'percent_max': 16.6666666666667,
#     'percent_min': 0,
#     'text': 'potassium metabisulphite',
#     'vegan': 'yes',
#     'vegetarian': 'yes'}],
#   'ingredients_analysis_tags': ['en:palm-oil-content-unknown',
#    'en:vegan-status-unknown',
#    'en:vegetarian-status-unknown'],
#   'ingredients_debug': ['Wasser',
#    ',',
#    None,
#    None,
#    None,
#    ' _Senfkörner_',
#    ',',
#    None,
#    None,
#    None,
#    ' Branntweinessig',
#    ',',
#    None,
#    None,
#    None,
#    ' Salz',
#    ',',
#    None,
#    None,
#    None,
#    ' Säuerungsmittel',
#    ':',
#    ':',
#    None,
#    None,
#    ' Citronensäure',
#    ',',
#    None,
#    None,
#    None,
#    ' Konservierungsstoff',
#    ':',
#    ':',
#    None,
#    None,
#    ' _Kaliummetabisulfit_.'],
#   'ingredients_from_or_that_may_be_from_palm_oil_n': 0,
#   'ingredients_from_palm_oil_n': 0,
#   'ingredients_from_palm_oil_tags': [],
#   'ingredients_hierarchy': ['en:water',
#    'en:mustard grains',
#    'en:brandy vinegar',
#    'en:salt',
#    'en:acid',
#    'en:preservative',
#    'en:e330',
#    'en:e224'],
#   'ingredients_ids_debug': ['wasser',
#    'senfkorner',
#    'branntweinessig',
#    'salz',
#    'sauerungsmittel',
#    'citronensaure',
#    'konservierungsstoff',
#    'kaliummetabisulfit'],
#   'ingredients_n': 8,
#   'ingredients_n_tags': ['8', '1-10'],
#   'ingredients_original_tags': ['en:water',
#    'en:mustard grains',
#    'en:brandy vinegar',
#    'en:salt',
#    'en:acid',
#    'en:preservative',
#    'en:e330',
#    'en:e224'],
#   'ingredients_tags': ['en:water',
#    'en:mustard-grains',
#    'en:brandy-vinegar',
#    'en:salt',
#    'en:acid',
#    'en:preservative',
#    'en:e330',
#    'en:e224'],
#   'ingredients_text': 'water, mustard grains, brandy vinegar, salt, acidifier: citric acid, preservative: potassium metabisulphite ,',
#   'ingredients_text_de': 'Wasser, _Senfkörner_, Branntweinessig, Salz, Säuerungsmittel: Citronensäure, Konservierungsstoff: _Kaliummetabisulfit_,',
#   'ingredients_text_debug': 'Wasser, _Senfkörner_, Branntweinessig, Salz, Säuerungsmittel: Citronensäure, Konservierungsstoff: _Kaliummetabisulfit_.',
#   'ingredients_text_en': 'water, mustard grains, brandy vinegar, salt, acidifier: citric acid, preservative: potassium metabisulphite ,',
#   'ingredients_text_es': 'Agua, semillas de _mostaza_, vinagre de alcohol, sal, acidulante: ácido cítrico, conservador: _metabisulfito_ de potasio.',
#   'ingredients_text_fr': '',
#   'ingredients_text_with_allergens': 'water, mustard grains, brandy vinegar, salt, acidifier: citric acid, preservative: potassium metabisulphite ,',
#   'ingredients_text_with_allergens_de': 'Wasser, <span class="allergen">Senfkörner</span>, Branntweinessig, Salz, Säuerungsmittel: Citronensäure, Konservierungsstoff: <span class="allergen">Kaliummetabisulfit</span>,',
#   'ingredients_text_with_allergens_en': 'water, mustard grains, brandy vinegar, salt, acidifier: citric acid, preservative: potassium metabisulphite ,',
#   'ingredients_text_with_allergens_es': 'Agua, semillas de <span class="allergen">mostaza</span>, vinagre de alcohol, sal, acidulante: ácido cítrico, conservador: <span class="allergen">metabisulfito</span> de potasio.',
#   'ingredients_text_with_allergens_fr': '',
#   'ingredients_text_xx': '',
#   'ingredients_text_xx_debug_tags': [],
#   'ingredients_that_may_be_from_palm_oil_n': 0,
#   'ingredients_that_may_be_from_palm_oil_tags': [],
#   'interface_version_created': '20120622',
#   'interface_version_modified': '20150316.jqm2',
#   'known_ingredients_n': 6,
#   'labels': '',
#   'labels_hierarchy': [],
#   'labels_lc': 'en',
#   'labels_old': '',
#   'labels_tags': [],
#   'lang': 'en',
#   'languages': {'en:english': 1,
#    'en:french': 4,
#    'en:german': 6,
#    'en:spanish': 4},
#   'languages_codes': {'de': 6, 'en': 1, 'es': 4, 'fr': 4},
#   'languages_hierarchy': ['en:english',
#    'en:french',
#    'en:german',
#    'en:spanish'],
#   'languages_tags': ['en:english',
#    'en:french',
#    'en:german',
#    'en:spanish',
#    'en:4',
#    'en:multilingual'],
#   'last_edit_dates_tags': ['2021-05-04', '2021-05', '2021'],
#   'last_editor': 'inf',
#   'last_image_dates_tags': ['2020-09-28', '2020-09', '2020'],
#   'last_image_t': 1601292671,
#   'last_modified_by': 'inf',
#   'last_modified_t': 1620120454,
#   'lc': 'en',
#   'link': 'https://us.maille.com/collections/mustards/products/dijon-originale-mustard',
#   'main_countries_tags': [],
#   'manufacturing_places': 'Frankreich',
#   'manufacturing_places_tags': ['frankreich'],
#   'max_imgid': '26',
#   'minerals_prev_tags': [],
#   'minerals_tags': [],
#   'misc_tags': ['en:nutrition-no-fiber',
#    'en:nutrition-fruits-vegetables-nuts-estimate-from-ingredients',
#    'en:nutrition-no-fiber-or-fruits-vegetables-nuts',
#    'en:nutriscore-computed',
#    'en:ecoscore-missing-data-warning',
#    'en:ecoscore-computed',
#    'en:main-countries-au-unexpectedly-low-scans',
#    'en:main-countries-au-unexpectedly-low-scans-0-10-percent-of-expected',
#    'en:main-countries-au-unexpectedly-low-scans-and-only-1-field-in-country-language',
#    'en:main-countries-au-product-name-not-in-country-language',
#    'en:main-countries-au-only-1-field-in-country-language',
#    'en:main-countries-be-unexpectedly-low-scans',
#    'en:main-countries-be-unexpectedly-low-scans-0-10-percent-of-expected',
#    'en:main-countries-fr-unexpectedly-low-scans',
#    'en:main-countries-fr-unexpectedly-low-scans-0-10-percent-of-expected',
#    'en:main-countries-fr-unexpectedly-low-scans-and-only-1-field-in-country-language',
#    'en:main-countries-fr-ingredients-not-in-country-language',
#    'en:main-countries-fr-only-1-field-in-country-language',
#    'en:main-countries-it-product-name-not-in-country-language',
#    'en:main-countries-it-ingredients-not-in-country-language',
#    'en:main-countries-it-no-data-in-country-language',
#    'en:main-countries-nl-product-name-not-in-country-language',
#    'en:main-countries-nl-ingredients-not-in-country-language',
#    'en:main-countries-nl-no-data-in-country-language',
#    'en:main-countries-pt-product-name-not-in-country-language',
#    'en:main-countries-pt-ingredients-not-in-country-language',
#    'en:main-countries-pt-no-data-in-country-language',
#    'en:main-countries-ro-product-name-not-in-country-language',
#    'en:main-countries-ro-ingredients-not-in-country-language',
#    'en:main-countries-ro-no-data-in-country-language',
#    'en:main-countries-se-product-name-not-in-country-language',
#    'en:main-countries-se-ingredients-not-in-country-language',
#    'en:main-countries-se-no-data-in-country-language'],
#   'no_nutrition_data': '',
#   'nova_group': 3,
#   'nova_group_debug': ' -- ingredients/en:preservative : 3',
#   'nova_groups': '3',
#   'nova_groups_tags': ['en:3-processed-foods'],
#   'nucleotides_prev_tags': [],
#   'nucleotides_tags': [],
#   'nutrient_levels': {'fat': 'moderate',
#    'salt': 'high',
#    'saturated-fat': 'low',
#    'sugars': 'low'},
#   'nutrient_levels_tags': ['en:fat-in-moderate-quantity',
#    'en:saturated-fat-in-low-quantity',
#    'en:sugars-in-low-quantity',
#    'en:salt-in-high-quantity'],
#   'nutriments': {'carbohydrates': 3.5,
#    'carbohydrates_100g': 3.5,
#    'carbohydrates_serving': 0.35,
#    'carbohydrates_unit': 'g',
#    'carbohydrates_value': 3.5,
#    'energy': 620,
#    'energy-kcal': 150,
#    'energy-kcal_100g': 150,
#    'energy-kcal_serving': 15,
#    'energy-kcal_unit': 'kcal',
#    'energy-kcal_value': 150,
#    'energy-kj': 620,
#    'energy-kj_100g': 620,
#    'energy-kj_serving': 62,
#    'energy-kj_unit': 'kJ',
#    'energy-kj_value': 620,
#    'energy_100g': 620,
#    'energy_serving': 62,
#    'energy_unit': 'kJ',
#    'energy_value': 620,
#    'fat': 11,
#    'fat_100g': 11,
#    'fat_serving': 1.1,
#    'fat_unit': 'g',
#    'fat_value': 11,
#    'fruits-vegetables-nuts-estimate-from-ingredients_100g': 0,
#    'nova-group': 3,
#    'nova-group_100g': 3,
#    'nova-group_serving': 3,
#    'nutrition-score-fr': 11,
#    'nutrition-score-fr_100g': 11,
#    'proteins': 7,
#    'proteins_100g': 7,
#    'proteins_serving': 0.7,
#    'proteins_unit': 'g',
#    'proteins_value': 7,
#    'salt': 5.7,
#    'salt_100g': 5.7,
#    'salt_serving': 0.57,
#    'salt_unit': 'g',
#    'salt_value': 5.7,
#    'saturated-fat': 0.6,
#    'saturated-fat_100g': 0.6,
#    'saturated-fat_serving': 0.06,
#    'saturated-fat_unit': 'g',
#    'saturated-fat_value': 0.6,
#    'sodium': 2.28,
#    'sodium_100g': 2.28,
#    'sodium_serving': 0.228,
#    'sodium_unit': 'g',
#    'sodium_value': 2.28,
#    'sugars': 2,
#    'sugars_100g': 2,
#    'sugars_serving': 0.2,
#    'sugars_unit': 'g',
#    'sugars_value': 2},
#   'nutriscore_data': {'energy': 620,
#    'energy_points': 1,
#    'energy_value': 620,
#    'fiber': 0,
#    'fiber_points': 0,
#    'fiber_value': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#    'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 0,
#    'grade': 'd',
#    'is_beverage': 0,
#    'is_cheese': 0,
#    'is_fat': 0,
#    'is_water': 0,
#    'negative_points': 11,
#    'positive_points': 0,
#    'proteins': 7,
#    'proteins_points': 4,
#    'proteins_value': 7,
#    'saturated_fat': 0.6,
#    'saturated_fat_points': 0,
#    'saturated_fat_ratio': 5.45454545454545,
#    'saturated_fat_ratio_points': 0,
#    'saturated_fat_ratio_value': 5.5,
#    'saturated_fat_value': 0.6,
#    'score': 11,
#    'sodium': 2280,
#    'sodium_points': 10,
#    'sodium_value': 2280,
#    'sugars': 2,
#    'sugars_points': 0,
#    'sugars_value': 2},
#   'nutriscore_grade': 'd',
#   'nutriscore_score': 11,
#   'nutriscore_score_opposite': -11,
#   'nutrition_data': 'on',
#   'nutrition_data_per': '100g',
#   'nutrition_data_prepared': '',
#   'nutrition_data_prepared_per': '100g',
#   'nutrition_grade_fr': 'd',
#   'nutrition_grades': 'd',
#   'nutrition_grades_tags': ['d'],
#   'nutrition_score_beverage': 0,
#   'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients': 1,
#   'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value': 0,
#   'nutrition_score_warning_no_fiber': 1,
#   'obsolete': '',
#   'obsolete_since_date': '',
#   'origins': 'Unspecified',
#   'origins_hierarchy': ['en:unspecified'],
#   'origins_lc': 'en',
#   'origins_old': 'França',
#   'origins_tags': ['en:unspecified'],
#   'other_nutritional_substances_tags': [],
#   'packaging': 'Glas,70 GL,40 FE,Glas/Gläser',
#   'packaging_tags': ['glas', '70-gl', '40-fe', 'glas-glaser'],
#   'packaging_text': '',
#   'packaging_text_de': '',
#   'packaging_text_es': '',
#   'packaging_text_fr': '',
#   'packagings': [{'material': 'en:steel'}],
#   'photographers_tags': ['openfoodfacts-contributors',
#    'date-limite-app',
#    'smias',
#    'kakao',
#    'kiliweb',
#    'foodrepo',
#    'thaialagata',
#    'aleene',
#    'jordibrus'],
#   'pnns_groups_1': 'Fat and sauces',
#   'pnns_groups_1_tags': ['fat-and-sauces', 'known'],
#   'pnns_groups_2': 'Dressings and sauces',
#   'pnns_groups_2_tags': ['dressings-and-sauces', 'known'],
#   'popularity_key': 19995000144,
#   'popularity_tags': ['top-10000-scans-2019',
#    'top-50000-scans-2019',
#    'top-100000-scans-2019',
#    'at-least-5-scans-2019',
#    'at-least-10-scans-2019',
#    'top-75-percent-scans-2019',
#    'top-80-percent-scans-2019',
#    'top-85-percent-scans-2019',
#    'top-90-percent-scans-2019',
#    'top-500-de-scans-2019',
#    'top-1000-de-scans-2019',
#    'top-5000-de-scans-2019',
#    'top-10000-de-scans-2019',
#    'top-50000-de-scans-2019',
#    'top-100000-de-scans-2019',
#    'top-country-de-scans-2019',
#    'at-least-5-de-scans-2019',
#    'at-least-10-de-scans-2019',
#    'top-5000-es-scans-2019',
#    'top-10000-es-scans-2019',
#    'top-50000-es-scans-2019',
#    'top-100000-es-scans-2019',
#    'at-least-5-es-scans-2019',
#    'at-least-10-es-scans-2019',
#    'top-5000-ch-scans-2019',
#    'top-10000-ch-scans-2019',
#    'top-50000-ch-scans-2019',
#    'top-100000-ch-scans-2019',
#    'at-least-5-ch-scans-2019',
#    'top-500-pt-scans-2019',
#    'top-1000-pt-scans-2019',
#    'top-5000-pt-scans-2019',
#    'top-10000-pt-scans-2019',
#    'top-50000-pt-scans-2019',
#    'top-100000-pt-scans-2019',
#    'at-least-5-pt-scans-2019',
#    'top-100000-fr-scans-2019',
#    'at-least-5-fr-scans-2019',
#    'top-100-nl-scans-2019',
#    'top-500-nl-scans-2019',
#    'top-1000-nl-scans-2019',
#    'top-5000-nl-scans-2019',
#    'top-10000-nl-scans-2019',
#    'top-50000-nl-scans-2019',
#    'top-100000-nl-scans-2019',
#    'at-least-5-nl-scans-2019',
#    'top-500-mx-scans-2019',
#    'top-1000-mx-scans-2019',
#    'top-5000-mx-scans-2019',
#    'top-10000-mx-scans-2019',
#    'top-50000-mx-scans-2019',
#    'top-100000-mx-scans-2019',
#    'top-1000-it-scans-2019',
#    'top-5000-it-scans-2019',
#    'top-10000-it-scans-2019',
#    'top-50000-it-scans-2019',
#    'top-100000-it-scans-2019',
#    'top-100-hu-scans-2019',
#    'top-500-hu-scans-2019',
#    'top-1000-hu-scans-2019',
#    'top-5000-hu-scans-2019',
#    'top-10000-hu-scans-2019',
#    'top-50000-hu-scans-2019',
#    'top-100000-hu-scans-2019',
#    'top-500-at-scans-2019',
#    'top-1000-at-scans-2019',
#    'top-5000-at-scans-2019',
#    'top-10000-at-scans-2019',
#    'top-50000-at-scans-2019',
#    'top-100000-at-scans-2019',
#    'top-100-is-scans-2019',
#    'top-500-is-scans-2019',
#    'top-1000-is-scans-2019',
#    'top-5000-is-scans-2019',
#    'top-10000-is-scans-2019',
#    'top-50000-is-scans-2019',
#    'top-100000-is-scans-2019',
#    'top-5000-ro-scans-2019',
#    'top-10000-ro-scans-2019',
#    'top-50000-ro-scans-2019',
#    'top-100000-ro-scans-2019',
#    'top-500-tr-scans-2019',
#    'top-1000-tr-scans-2019',
#    'top-5000-tr-scans-2019',
#    'top-10000-tr-scans-2019',
#    'top-50000-tr-scans-2019',
#    'top-100000-tr-scans-2019',
#    'top-50-sk-scans-2019',
#    'top-100-sk-scans-2019',
#    'top-500-sk-scans-2019',
#    'top-1000-sk-scans-2019',
#    'top-5000-sk-scans-2019',
#    'top-10000-sk-scans-2019',
#    'top-50000-sk-scans-2019',
#    'top-100000-sk-scans-2019',
#    'top-50000-be-scans-2019',
#    'top-100000-be-scans-2019',
#    'top-1000-no-scans-2019',
#    'top-5000-no-scans-2019',
#    'top-10000-no-scans-2019',
#    'top-50000-no-scans-2019',
#    'top-100000-no-scans-2019',
#    'top-5000-scans-2020',
#    'top-10000-scans-2020',
#    'top-50000-scans-2020',
#    'top-100000-scans-2020',
#    'at-least-5-scans-2020',
#    'at-least-10-scans-2020',
#    'top-75-percent-scans-2020',
#    'top-80-percent-scans-2020',
#    'top-85-percent-scans-2020',
#    'top-90-percent-scans-2020',
#    'top-500-de-scans-2020',
#    'top-1000-de-scans-2020',
#    'top-5000-de-scans-2020',
#    'top-10000-de-scans-2020',
#    'top-50000-de-scans-2020',
#    'top-100000-de-scans-2020',
#    'top-country-de-scans-2020',
#    'at-least-5-de-scans-2020',
#    'at-least-10-de-scans-2020',
#    'top-1000-es-scans-2020',
#    'top-5000-es-scans-2020',
#    'top-10000-es-scans-2020',
#    'top-50000-es-scans-2020',
#    'top-100000-es-scans-2020',
#    'at-least-5-es-scans-2020',
#    'at-least-10-es-scans-2020',
#    'top-100-ro-scans-2020',
#    'top-500-ro-scans-2020',
#    'top-1000-ro-scans-2020',
#    'top-5000-ro-scans-2020',
#    'top-10000-ro-scans-2020',
#    'top-50000-ro-scans-2020',
#    'top-100000-ro-scans-2020',
#    'at-least-5-ro-scans-2020',
#    'top-1000-pt-scans-2020',
#    'top-5000-pt-scans-2020',
#    'top-10000-pt-scans-2020',
#    'top-50000-pt-scans-2020',
#    'top-100000-pt-scans-2020',
#    'at-least-5-pt-scans-2020',
#    'top-5000-it-scans-2020',
#    'top-10000-it-scans-2020',
#    'top-50000-it-scans-2020',
#    'top-100000-it-scans-2020',
#    'at-least-5-it-scans-2020',
#    'top-500-at-scans-2020',
#    'top-1000-at-scans-2020',
#    'top-5000-at-scans-2020',
#    'top-10000-at-scans-2020',
#    'top-50000-at-scans-2020',
#    'top-100000-at-scans-2020',
#    'top-500-nl-scans-2020',
#    'top-1000-nl-scans-2020',
#    'top-5000-nl-scans-2020',
#    'top-10000-nl-scans-2020',
#    'top-50000-nl-scans-2020',
#    'top-100000-nl-scans-2020',
#    'top-500-fi-scans-2020',
#    'top-1000-fi-scans-2020',
#    'top-5000-fi-scans-2020',
#    'top-10000-fi-scans-2020',
#    'top-50000-fi-scans-2020',
#    'top-100000-fi-scans-2020',
#    'top-500-se-scans-2020',
#    'top-1000-se-scans-2020',
#    'top-5000-se-scans-2020',
#    'top-10000-se-scans-2020',
#    'top-50000-se-scans-2020',
#    'top-100000-se-scans-2020',
#    'top-1000-ca-scans-2020',
#    'top-5000-ca-scans-2020',
#    'top-10000-ca-scans-2020',
#    'top-50000-ca-scans-2020',
#    'top-100000-ca-scans-2020',
#    'top-50000-ch-scans-2020',
#    'top-100000-ch-scans-2020',
#    'top-500-co-scans-2020',
#    'top-1000-co-scans-2020',
#    'top-5000-co-scans-2020',
#    'top-10000-co-scans-2020',
#    'top-50000-co-scans-2020',
#    'top-100000-co-scans-2020',
#    'top-5000-mx-scans-2020',
#    'top-10000-mx-scans-2020',
#    'top-50000-mx-scans-2020',
#    'top-100000-mx-scans-2020',
#    'top-500-tr-scans-2020',
#    'top-1000-tr-scans-2020',
#    'top-5000-tr-scans-2020',
#    'top-10000-tr-scans-2020',
#    'top-50000-tr-scans-2020',
#    'top-100000-tr-scans-2020',
#    'top-500-cz-scans-2020',
#    'top-1000-cz-scans-2020',
#    'top-5000-cz-scans-2020',
#    'top-10000-cz-scans-2020',
#    'top-50000-cz-scans-2020',
#    'top-100000-cz-scans-2020',
#    'top-500-uy-scans-2020',
#    'top-1000-uy-scans-2020',
#    'top-5000-uy-scans-2020',
#    'top-10000-uy-scans-2020',
#    'top-50000-uy-scans-2020',
#    'top-100000-uy-scans-2020',
#    'top-1000-no-scans-2020',
#    'top-5000-no-scans-2020',
#    'top-10000-no-scans-2020',
#    'top-50000-no-scans-2020',
#    'top-100000-no-scans-2020',
#    'top-5000-ad-scans-2020',
#    'top-10000-ad-scans-2020',
#    'top-50000-ad-scans-2020',
#    'top-100000-ad-scans-2020',
#    'top-1000-br-scans-2020',
#    'top-5000-br-scans-2020',
#    'top-10000-br-scans-2020',
#    'top-50000-br-scans-2020',
#    'top-100000-br-scans-2020',
#    'top-10000-lu-scans-2020',
#    'top-50000-lu-scans-2020',
#    'top-100000-lu-scans-2020'],
#   'product_name': 'Dijon Originale',
#   'product_name_de': 'Dijon Originale',
#   'product_name_es': 'Mostaza Dijón',
#   'product_name_fr': 'Dijon originale',
#   'product_name_xx': '',
#   'product_name_xx_debug_tags': [],
#   'product_quantity': '200',
#   'purchase_places': 'Deutschland,Espanya',
#   'purchase_places_tags': ['deutschland', 'espanya'],
#   'quantity': '200ml',
#   'removed_countries_tags': [],
#   'rev': 155,
#   'scans_n': 215,
#   'selected_images': {'front': {'display': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_de.25.400.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_es.62.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_fr.3.400.jpg'},
#     'small': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_de.25.200.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_es.62.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_fr.3.200.jpg'},
#     'thumb': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_de.25.100.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_es.62.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/front_fr.3.100.jpg'}},
#    'ingredients': {'display': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_de.22.400.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_es.133.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_fr.28.400.jpg'},
#     'small': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_de.22.200.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_es.133.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_fr.28.200.jpg'},
#     'thumb': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_de.22.100.jpg',
#      'es': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_es.133.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/ingredients_fr.28.100.jpg'}},
#    'nutrition': {'display': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/nutrition_de.119.400.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/nutrition_fr.16.400.jpg'},
#     'small': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/nutrition_de.119.200.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/nutrition_fr.16.200.jpg'},
#     'thumb': {'de': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/nutrition_de.119.100.jpg',
#      'fr': 'https://static.openfoodfacts.org/images/products/303/681/020/1280/nutrition_fr.16.100.jpg'}}},
#   'serving_quantity': '10',
#   'serving_size': '10g',
#   'sortkey': 1610790795,
#   'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-completed, en:packaging-code-to-be-completed, en:characteristics-completed, en:origins-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-to-be-selected, en:ingredients-photo-to-be-selected, en:front-photo-selected, en:photos-uploaded',
#   'states_hierarchy': ['en:to-be-completed',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-to-be-completed',
#    'en:characteristics-completed',
#    'en:origins-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-to-be-validated',
#    'en:packaging-photo-to-be-selected',
#    'en:nutrition-photo-to-be-selected',
#    'en:ingredients-photo-to-be-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'states_tags': ['en:to-be-completed',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-to-be-completed',
#    'en:characteristics-completed',
#    'en:origins-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-to-be-validated',
#    'en:packaging-photo-to-be-selected',
#    'en:nutrition-photo-to-be-selected',
#    'en:ingredients-photo-to-be-selected',
#    'en:front-photo-selected',
#    'en:photos-uploaded'],
#   'stores': 'Woolworths,REWE,HIT,Coles,BonPreu',
#   'stores_tags': ['woolworths', 'rewe', 'hit', 'coles', 'bonpreu'],
#   'teams': 'pain-au-chocolat,stakano,chocolatine',
#   'teams_tags': ['pain-au-chocolat', 'stakano', 'chocolatine'],
#   'traces': '',
#   'traces_from_ingredients': '',
#   'traces_from_user': '(en) ',
#   'traces_hierarchy': [],
#   'traces_lc': 'en',
#   'traces_tags': [],
#   'unique_scans_n': 139,
#   'unknown_ingredients_n': 2,
#   'unknown_nutrients_tags': [],
#   'update_key': 'main-countries',
#   'vitamins_prev_tags': [],
#   'vitamins_tags': []},
#  'status': 1,
#  'status_verbose': 'product found'}

# %% [markdown]
# ### Search

# %% [markdown]
# La méthode search_all() est préférable à search(). La seconde méthode retourne des méta-données en plus de l'itérable.

# %% [markdown]
# ##### Méthode search()

# %%
query = 'mustard maille'
search_result = openfoodfacts.products.search(query)
# search_result

# %% [markdown]
# ##### Méthode search_all()

# %%
query = 'mustard maille'
search_result = openfoodfacts.products.search_all(query)
for product in search_result:
    #     print (product['product_name'])
    #     display(product)
    pass

# %% [markdown]
# ### Download data

# %%
file_type = 'csv'
# openfoodfacts.utils.download_data(file_type)

# %% [markdown]
# L'instruction download_data() télécharge le data set dans le dossier ~/user.

# %% [markdown]
# ## Conclusion des tests de l'API

# %% [markdown]
# Les résultats sont décevants. Les requêtes retournent des données incomplètes.
# La fonction download_data() est utile car elle permet de récupérer le dataset.

# %% [markdown]
# # Téléchargement des données openfoodfacts

# %% [markdown]
# ## Téléchargement du fichier .csv contenant le jeu de données openfoodfatcs

# %%
download = False    # False pour utiliser le fichier déjà téléchargé    # si True : on relance un download complet
          
# si le fichier csv n'existe pas, un download est demandé
if not exists('en.openfoodfacts.org.products.csv') :
    download = True
          
if download :
    # téléchargement du .csv
    file_type = 'csv'
    openfoodfacts.utils.download_data(file_type)     # L'instruction download_data() télécharge le dataset dans le dossier ~/user.

# %% [markdown]
# ## Conversion du fichier .csv en dataframe pandas

# %%
# Chargement du dataframe df1 à partir du fichier csv ou à partir d'un pickle pour gagner du temps
create_pickle = False  # si False : appel du pickle existant    # si True : création du pickle

# si le fichier pickle n'existe pas, une création est demandée
if not exists('df_avant_nettoyage.pkl'):
    create_pickle = True

if create_pickle:
    # création du pickle
    df1 = pd.read_csv('en.openfoodfacts.org.products.csv',
                      sep='\t',
                      low_memory=False)
    df1.to_pickle('df_avant_nettoyage.pkl')
else:  # on charge le pickle
    df1 = pd.read_pickle('df_avant_nettoyage.pkl')

# %% [markdown]
# ## Affichage de quelques lignes du dataframe

# %%
with pd.option_context('display.max_rows', 400, 'display.max_colwidth', 1000):
    display(df1.tail())
#     display(df1.loc[[4]])
#     display(df1.loc[4:5000])
# Out:
#                     code  \
# 1802746    9999999910128
# 1802747        999999999
# 1802748    9999999990397
# 1802749    9999999999994
# 1802750  999999999999999
#
#                                                                                                     url  \
# 1802746  http://world-en.openfoodfacts.org/product/9999999910128/sandwich-club-rillette-poisson-combava
# 1802747               http://world-en.openfoodfacts.org/product/999999999/the-noir-bio-darjeeling-pages
# 1802748                                    http://world-en.openfoodfacts.org/product/9999999990397/fati
# 1802749                 http://world-en.openfoodfacts.org/product/9999999999994/light-free-skyr-a-boire
# 1802750                     http://world-en.openfoodfacts.org/product/999999999999999/signal-toothpaste
#
#                             creator   created_t      created_datetime  \
# 1802746                     kiliweb  1572513866  2019-10-31T09:24:26Z
# 1802747              nutrinet-sante  1608105503  2020-12-16T07:58:23Z
# 1802748                     kiliweb  1581171613  2020-02-08T14:20:13Z
# 1802749                     kiliweb  1613129728  2021-02-12T11:35:28Z
# 1802750  openfoodfacts-contributors  1587222660  2020-04-18T15:11:00Z
#
#          last_modified_t last_modified_datetime  \
# 1802746       1572513866   2019-10-31T09:24:26Z
# 1802747       1608105504   2020-12-16T07:58:24Z
# 1802748       1582644247   2020-02-25T15:24:07Z
# 1802749       1613129730   2021-02-12T11:35:30Z
# 1802750       1605558295   2020-11-16T20:24:55Z
#
#                                    product_name abbreviated_product_name  \
# 1802746  Sandwich club Rillette poisson combava                      NaN
# 1802747                 Thé noir BIO Darjeeling                      NaN
# 1802748                                    Fati                      NaN
# 1802749               Light & Free SKYR A BOIRE                      NaN
# 1802750                       Signal Toothpaste                      NaN
#
#         generic_name quantity packaging packaging_tags packaging_text brands  \
# 1802746          NaN      NaN       NaN            NaN            NaN    NaN
# 1802747          NaN      NaN       NaN            NaN            NaN  Pagès
# 1802748          NaN    440 g       NaN            NaN            NaN    NaN
# 1802749          NaN      NaN       NaN            NaN            NaN    NaN
# 1802750          NaN      NaN       NaN            NaN            NaN    NaN
#
#         brands_tags                                        categories  \
# 1802746         NaN                                               NaN
# 1802747       pages                                               NaN
# 1802748         NaN                                               NaN
# 1802749         NaN                                               NaN
# 1802750         NaN  Non food products, Open Beauty Facts, Toothpaste
#
#                                                  categories_tags  \
# 1802746                                                      NaN
# 1802747                                                      NaN
# 1802748                                                      NaN
# 1802749                                                      NaN
# 1802750  en:non-food-products,en:open-beauty-facts,en:toothpaste
#
#                                           categories_en origins origins_tags  \
# 1802746                                             NaN     NaN          NaN
# 1802747                                             NaN     NaN          NaN
# 1802748                                             NaN     NaN          NaN
# 1802749                                             NaN     NaN          NaN
# 1802750  Non food products,Open Beauty Facts,Toothpaste     NaN          NaN
#
#         origins_en manufacturing_places manufacturing_places_tags labels  \
# 1802746        NaN                  NaN                       NaN    NaN
# 1802747        NaN                  NaN                       NaN    NaN
# 1802748        NaN                  NaN                       NaN    NaN
# 1802749        NaN                  NaN                       NaN    NaN
# 1802750        NaN                  NaN                       NaN    NaN
#
#         labels_tags labels_en emb_codes emb_codes_tags  \
# 1802746         NaN       NaN       NaN            NaN
# 1802747         NaN       NaN       NaN            NaN
# 1802748         NaN       NaN       NaN            NaN
# 1802749         NaN       NaN       NaN            NaN
# 1802750         NaN       NaN       NaN            NaN
#
#         first_packaging_code_geo  cities cities_tags purchase_places stores  \
# 1802746                      NaN     NaN         NaN             NaN    NaN
# 1802747                      NaN     NaN         NaN             NaN    NaN
# 1802748                      NaN     NaN         NaN             NaN    NaN
# 1802749                      NaN     NaN         NaN             NaN    NaN
# 1802750                      NaN     NaN         NaN             NaN    NaN
#
#          countries countries_tags countries_en ingredients_text allergens  \
# 1802746      en:re     en:reunion      Réunion              NaN       NaN
# 1802747  en:france      en:france       France              NaN       NaN
# 1802748      en:be     en:belgium      Belgium              NaN       NaN
# 1802749  en:france      en:france       France              NaN       NaN
# 1802750     France      en:france       France              NaN       NaN
#
#          allergens_en traces traces_tags traces_en serving_size  \
# 1802746           NaN    NaN         NaN       NaN          NaN
# 1802747           NaN    NaN         NaN       NaN          NaN
# 1802748           NaN    NaN         NaN       NaN          NaN
# 1802749           NaN    NaN         NaN       NaN          NaN
# 1802750           NaN    NaN         NaN       NaN          NaN
#
#          serving_quantity  no_nutriments  additives_n additives  \
# 1802746               NaN            NaN          NaN       NaN
# 1802747               NaN            NaN          NaN       NaN
# 1802748               NaN            NaN          NaN       NaN
# 1802749               NaN            NaN          NaN       NaN
# 1802750               NaN            NaN          NaN       NaN
#
#         additives_tags additives_en  ingredients_from_palm_oil_n  \
# 1802746            NaN          NaN                          NaN
# 1802747            NaN          NaN                          NaN
# 1802748            NaN          NaN                          NaN
# 1802749            NaN          NaN                          NaN
# 1802750            NaN          NaN                          NaN
#
#          ingredients_from_palm_oil ingredients_from_palm_oil_tags  \
# 1802746                        NaN                            NaN
# 1802747                        NaN                            NaN
# 1802748                        NaN                            NaN
# 1802749                        NaN                            NaN
# 1802750                        NaN                            NaN
#
#          ingredients_that_may_be_from_palm_oil_n  \
# 1802746                                      NaN
# 1802747                                      NaN
# 1802748                                      NaN
# 1802749                                      NaN
# 1802750                                      NaN
#
#          ingredients_that_may_be_from_palm_oil  \
# 1802746                                    NaN
# 1802747                                    NaN
# 1802748                                    NaN
# 1802749                                    NaN
# 1802750                                    NaN
#
#         ingredients_that_may_be_from_palm_oil_tags  nutriscore_score  \
# 1802746                                        NaN               NaN
# 1802747                                        NaN               NaN
# 1802748                                        NaN               NaN
# 1802749                                        NaN               NaN
# 1802750                                        NaN               NaN
#
#         nutriscore_grade  nova_group pnns_groups_1 pnns_groups_2  \
# 1802746              NaN         NaN       unknown       unknown
# 1802747              NaN         NaN       unknown       unknown
# 1802748              NaN         NaN       unknown       unknown
# 1802749              NaN         NaN       unknown       unknown
# 1802750              NaN         NaN       unknown       unknown
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        states  \
# 1802746                                                                                                                                                      en:to-be-completed, en:nutrition-facts-to-be-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:categories-to-be-completed, en:brands-to-be-completed, en:packaging-to-be-completed, en:quantity-to-be-completed, en:product-name-completed, en:photos-to-be-validated, en:photos-uploaded
# 1802747                                                                                                                                                                                 en:to-be-completed, en:nutrition-facts-to-be-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:categories-to-be-completed, en:brands-completed, en:packaging-to-be-completed, en:quantity-to-be-completed, en:product-name-completed, en:photos-to-be-uploaded
# 1802748                                                                                                                                                                  en:to-be-completed, en:nutrition-facts-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:categories-to-be-completed, en:brands-to-be-completed, en:packaging-to-be-completed, en:quantity-completed, en:product-name-completed, en:photos-to-be-validated, en:photos-uploaded
# 1802749  en:to-be-completed, en:nutrition-facts-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:origins-to-be-completed, en:categories-to-be-completed, en:brands-to-be-completed, en:packaging-to-be-completed, en:quantity-to-be-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-selected, en:ingredients-photo-to-be-selected, en:front-photo-selected, en:photos-uploaded
# 1802750                        en:to-be-completed, en:nutrition-facts-to-be-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:categories-completed, en:brands-to-be-completed, en:packaging-to-be-completed, en:quantity-to-be-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-to-be-selected, en:ingredients-photo-to-be-selected, en:front-photo-selected, en:photos-uploaded
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  states_tags  \
# 1802746                                                                                                                                                 en:to-be-completed,en:nutrition-facts-to-be-completed,en:ingredients-to-be-completed,en:expiration-date-to-be-completed,en:packaging-code-to-be-completed,en:characteristics-to-be-completed,en:categories-to-be-completed,en:brands-to-be-completed,en:packaging-to-be-completed,en:quantity-to-be-completed,en:product-name-completed,en:photos-to-be-validated,en:photos-uploaded
# 1802747                                                                                                                                                                           en:to-be-completed,en:nutrition-facts-to-be-completed,en:ingredients-to-be-completed,en:expiration-date-to-be-completed,en:packaging-code-to-be-completed,en:characteristics-to-be-completed,en:categories-to-be-completed,en:brands-completed,en:packaging-to-be-completed,en:quantity-to-be-completed,en:product-name-completed,en:photos-to-be-uploaded
# 1802748                                                                                                                                                             en:to-be-completed,en:nutrition-facts-completed,en:ingredients-to-be-completed,en:expiration-date-to-be-completed,en:packaging-code-to-be-completed,en:characteristics-to-be-completed,en:categories-to-be-completed,en:brands-to-be-completed,en:packaging-to-be-completed,en:quantity-completed,en:product-name-completed,en:photos-to-be-validated,en:photos-uploaded
# 1802749  en:to-be-completed,en:nutrition-facts-completed,en:ingredients-to-be-completed,en:expiration-date-to-be-completed,en:packaging-code-to-be-completed,en:characteristics-to-be-completed,en:origins-to-be-completed,en:categories-to-be-completed,en:brands-to-be-completed,en:packaging-to-be-completed,en:quantity-to-be-completed,en:product-name-completed,en:photos-to-be-validated,en:packaging-photo-to-be-selected,en:nutrition-photo-selected,en:ingredients-photo-to-be-selected,en:front-photo-selected,en:photos-uploaded
# 1802750                       en:to-be-completed,en:nutrition-facts-to-be-completed,en:ingredients-to-be-completed,en:expiration-date-to-be-completed,en:packaging-code-to-be-completed,en:characteristics-to-be-completed,en:categories-completed,en:brands-to-be-completed,en:packaging-to-be-completed,en:quantity-to-be-completed,en:product-name-completed,en:photos-to-be-validated,en:packaging-photo-to-be-selected,en:nutrition-photo-to-be-selected,en:ingredients-photo-to-be-selected,en:front-photo-selected,en:photos-uploaded
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                              states_en  \
# 1802746                                                                                                                                  To be completed,Nutrition facts to be completed,Ingredients to be completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories to be completed,Brands to be completed,Packaging to be completed,Quantity to be completed,Product name completed,Photos to be validated,Photos uploaded
# 1802747                                                                                                                                                         To be completed,Nutrition facts to be completed,Ingredients to be completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories to be completed,Brands completed,Packaging to be completed,Quantity to be completed,Product name completed,Photos to be uploaded
# 1802748                                                                                                                                              To be completed,Nutrition facts completed,Ingredients to be completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories to be completed,Brands to be completed,Packaging to be completed,Quantity completed,Product name completed,Photos to be validated,Photos uploaded
# 1802749  To be completed,Nutrition facts completed,Ingredients to be completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Origins to be completed,Categories to be completed,Brands to be completed,Packaging to be completed,Quantity to be completed,Product name completed,Photos to be validated,Packaging photo to be selected,Nutrition photo selected,Ingredients photo to be selected,Front photo selected,Photos uploaded
# 1802750                    To be completed,Nutrition facts to be completed,Ingredients to be completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands to be completed,Packaging to be completed,Quantity to be completed,Product name completed,Photos to be validated,Packaging photo to be selected,Nutrition photo to be selected,Ingredients photo to be selected,Front photo selected,Photos uploaded
#
#         brand_owner  ecoscore_score_fr ecoscore_grade_fr  main_category  \
# 1802746         NaN                NaN               NaN            NaN
# 1802747         NaN                NaN               NaN            NaN
# 1802748         NaN                NaN               NaN            NaN
# 1802749         NaN                NaN               NaN            NaN
# 1802750         NaN                NaN               NaN  en:toothpaste
#
#         main_category_en  \
# 1802746              NaN
# 1802747              NaN
# 1802748              NaN
# 1802749              NaN
# 1802750       Toothpaste
#
#                                                                                       image_url  \
# 1802746    https://static.openfoodfacts.org/images/products/999/999/991/0128/front_fr.3.400.jpg
# 1802747                                                                                     NaN
# 1802748    https://static.openfoodfacts.org/images/products/999/999/999/0397/front_fr.3.400.jpg
# 1802749   https://static.openfoodfacts.org/images/products/999/999/999/9994/front_fr.12.400.jpg
# 1802750  https://static.openfoodfacts.org/images/products/999/999/999/999999/front_en.3.400.jpg
#
#                                                                                 image_small_url  \
# 1802746    https://static.openfoodfacts.org/images/products/999/999/991/0128/front_fr.3.200.jpg
# 1802747                                                                                     NaN
# 1802748    https://static.openfoodfacts.org/images/products/999/999/999/0397/front_fr.3.200.jpg
# 1802749   https://static.openfoodfacts.org/images/products/999/999/999/9994/front_fr.12.200.jpg
# 1802750  https://static.openfoodfacts.org/images/products/999/999/999/999999/front_en.3.200.jpg
#
#         image_ingredients_url image_ingredients_small_url  \
# 1802746                   NaN                         NaN
# 1802747                   NaN                         NaN
# 1802748                   NaN                         NaN
# 1802749                   NaN                         NaN
# 1802750                   NaN                         NaN
#
#                                                                                image_nutrition_url  \
# 1802746                                                                                        NaN
# 1802747                                                                                        NaN
# 1802748   https://static.openfoodfacts.org/images/products/999/999/999/0397/nutrition_fr.5.400.jpg
# 1802749  https://static.openfoodfacts.org/images/products/999/999/999/9994/nutrition_fr.14.400.jpg
# 1802750                                                                                        NaN
#
#                                                                          image_nutrition_small_url  \
# 1802746                                                                                        NaN
# 1802747                                                                                        NaN
# 1802748   https://static.openfoodfacts.org/images/products/999/999/999/0397/nutrition_fr.5.200.jpg
# 1802749  https://static.openfoodfacts.org/images/products/999/999/999/9994/nutrition_fr.14.200.jpg
# 1802750                                                                                        NaN
#
#          energy-kj_100g  energy-kcal_100g  energy_100g  energy-from-fat_100g  \
# 1802746             NaN               NaN          NaN                   NaN
# 1802747             NaN               NaN          NaN                   NaN
# 1802748             NaN              24.0        100.0                   NaN
# 1802749             NaN               0.0          0.0                   NaN
# 1802750             NaN               NaN          NaN                   NaN
#
#          fat_100g  saturated-fat_100g  -butyric-acid_100g  -caproic-acid_100g  \
# 1802746       NaN                 NaN                 NaN                 NaN
# 1802747       NaN                 NaN                 NaN                 NaN
# 1802748       0.3                 0.0                 NaN                 NaN
# 1802749       0.2                 0.1                 NaN                 NaN
# 1802750       NaN                 NaN                 NaN                 NaN
#
#          -caprylic-acid_100g  -capric-acid_100g  -lauric-acid_100g  \
# 1802746                  NaN                NaN                NaN
# 1802747                  NaN                NaN                NaN
# 1802748                  NaN                NaN                NaN
# 1802749                  NaN                NaN                NaN
# 1802750                  NaN                NaN                NaN
#
#          -myristic-acid_100g  -palmitic-acid_100g  -stearic-acid_100g  \
# 1802746                  NaN                  NaN                 NaN
# 1802747                  NaN                  NaN                 NaN
# 1802748                  NaN                  NaN                 NaN
# 1802749                  NaN                  NaN                 NaN
# 1802750                  NaN                  NaN                 NaN
#
#          -arachidic-acid_100g  -behenic-acid_100g  -lignoceric-acid_100g  \
# 1802746                   NaN                 NaN                    NaN
# 1802747                   NaN                 NaN                    NaN
# 1802748                   NaN                 NaN                    NaN
# 1802749                   NaN                 NaN                    NaN
# 1802750                   NaN                 NaN                    NaN
#
#          -cerotic-acid_100g  -montanic-acid_100g  -melissic-acid_100g  \
# 1802746                 NaN                  NaN                  NaN
# 1802747                 NaN                  NaN                  NaN
# 1802748                 NaN                  NaN                  NaN
# 1802749                 NaN                  NaN                  NaN
# 1802750                 NaN                  NaN                  NaN
#
#          monounsaturated-fat_100g  polyunsaturated-fat_100g  omega-3-fat_100g  \
# 1802746                       NaN                       NaN               NaN
# 1802747                       NaN                       NaN               NaN
# 1802748                       NaN                       NaN               NaN
# 1802749                       NaN                       NaN               NaN
# 1802750                       NaN                       NaN               NaN
#
#          -alpha-linolenic-acid_100g  -eicosapentaenoic-acid_100g  \
# 1802746                         NaN                          NaN
# 1802747                         NaN                          NaN
# 1802748                         NaN                          NaN
# 1802749                         NaN                          NaN
# 1802750                         NaN                          NaN
#
#          -docosahexaenoic-acid_100g  omega-6-fat_100g  -linoleic-acid_100g  \
# 1802746                         NaN               NaN                  NaN
# 1802747                         NaN               NaN                  NaN
# 1802748                         NaN               NaN                  NaN
# 1802749                         NaN               NaN                  NaN
# 1802750                         NaN               NaN                  NaN
#
#          -arachidonic-acid_100g  -gamma-linolenic-acid_100g  \
# 1802746                     NaN                         NaN
# 1802747                     NaN                         NaN
# 1802748                     NaN                         NaN
# 1802749                     NaN                         NaN
# 1802750                     NaN                         NaN
#
#          -dihomo-gamma-linolenic-acid_100g  omega-9-fat_100g  \
# 1802746                                NaN               NaN
# 1802747                                NaN               NaN
# 1802748                                NaN               NaN
# 1802749                                NaN               NaN
# 1802750                                NaN               NaN
#
#          -oleic-acid_100g  -elaidic-acid_100g  -gondoic-acid_100g  \
# 1802746               NaN                 NaN                 NaN
# 1802747               NaN                 NaN                 NaN
# 1802748               NaN                 NaN                 NaN
# 1802749               NaN                 NaN                 NaN
# 1802750               NaN                 NaN                 NaN
#
#          -mead-acid_100g  -erucic-acid_100g  -nervonic-acid_100g  \
# 1802746              NaN                NaN                  NaN
# 1802747              NaN                NaN                  NaN
# 1802748              NaN                NaN                  NaN
# 1802749              NaN                NaN                  NaN
# 1802750              NaN                NaN                  NaN
#
#          trans-fat_100g  cholesterol_100g  carbohydrates_100g  sugars_100g  \
# 1802746             NaN               NaN                 NaN          NaN
# 1802747             NaN               NaN                 NaN          NaN
# 1802748             NaN               NaN                 2.4          0.6
# 1802749             NaN               NaN                 8.0          7.8
# 1802750             NaN               NaN                 NaN          NaN
#
#          -sucrose_100g  -glucose_100g  -fructose_100g  -lactose_100g  \
# 1802746            NaN            NaN             NaN            NaN
# 1802747            NaN            NaN             NaN            NaN
# 1802748            NaN            NaN             NaN            NaN
# 1802749            NaN            NaN             NaN            NaN
# 1802750            NaN            NaN             NaN            NaN
#
#          -maltose_100g  -maltodextrins_100g  starch_100g  polyols_100g  \
# 1802746            NaN                  NaN          NaN           NaN
# 1802747            NaN                  NaN          NaN           NaN
# 1802748            NaN                  NaN          NaN           NaN
# 1802749            NaN                  NaN          NaN           NaN
# 1802750            NaN                  NaN          NaN           NaN
#
#          fiber_100g  -soluble-fiber_100g  -insoluble-fiber_100g  \
# 1802746         NaN                  NaN                    NaN
# 1802747         NaN                  NaN                    NaN
# 1802748         NaN                  NaN                    NaN
# 1802749         NaN                  NaN                    NaN
# 1802750         NaN                  NaN                    NaN
#
#          proteins_100g  casein_100g  serum-proteins_100g  nucleotides_100g  \
# 1802746            NaN          NaN                  NaN               NaN
# 1802747            NaN          NaN                  NaN               NaN
# 1802748            1.6          NaN                  NaN               NaN
# 1802749            5.5          NaN                  NaN               NaN
# 1802750            NaN          NaN                  NaN               NaN
#
#          salt_100g  sodium_100g  alcohol_100g  vitamin-a_100g  \
# 1802746        NaN          NaN           NaN             NaN
# 1802747        NaN          NaN           NaN             NaN
# 1802748       0.64        0.256           NaN             NaN
# 1802749       0.15        0.060           NaN             NaN
# 1802750        NaN          NaN           NaN             NaN
#
#          beta-carotene_100g  vitamin-d_100g  vitamin-e_100g  vitamin-k_100g  \
# 1802746                 NaN             NaN             NaN             NaN
# 1802747                 NaN             NaN             NaN             NaN
# 1802748                 NaN             NaN             NaN             NaN
# 1802749                 NaN             NaN             NaN             NaN
# 1802750                 NaN             NaN             NaN             NaN
#
#          vitamin-c_100g  vitamin-b1_100g  vitamin-b2_100g  vitamin-pp_100g  \
# 1802746             NaN              NaN              NaN              NaN
# 1802747             NaN              NaN              NaN              NaN
# 1802748             NaN              NaN              NaN              NaN
# 1802749             NaN              NaN              NaN              NaN
# 1802750             NaN              NaN              NaN              NaN
#
#          vitamin-b6_100g  vitamin-b9_100g  folates_100g  vitamin-b12_100g  \
# 1802746              NaN              NaN           NaN               NaN
# 1802747              NaN              NaN           NaN               NaN
# 1802748              NaN              NaN           NaN               NaN
# 1802749              NaN              NaN           NaN               NaN
# 1802750              NaN              NaN           NaN               NaN
#
#          biotin_100g  pantothenic-acid_100g  silica_100g  bicarbonate_100g  \
# 1802746          NaN                    NaN          NaN               NaN
# 1802747          NaN                    NaN          NaN               NaN
# 1802748          NaN                    NaN          NaN               NaN
# 1802749          NaN                    NaN          NaN               NaN
# 1802750          NaN                    NaN          NaN               NaN
#
#          potassium_100g  chloride_100g  calcium_100g  phosphorus_100g  \
# 1802746             NaN            NaN           NaN              NaN
# 1802747             NaN            NaN           NaN              NaN
# 1802748             NaN            NaN           NaN              NaN
# 1802749             NaN            NaN           NaN              NaN
# 1802750             NaN            NaN           NaN              NaN
#
#          iron_100g  magnesium_100g  zinc_100g  copper_100g  manganese_100g  \
# 1802746        NaN             NaN        NaN          NaN             NaN
# 1802747        NaN             NaN        NaN          NaN             NaN
# 1802748        NaN             NaN        NaN          NaN             NaN
# 1802749        NaN             NaN        NaN          NaN             NaN
# 1802750        NaN             NaN        NaN          NaN             NaN
#
#          fluoride_100g  selenium_100g  chromium_100g  molybdenum_100g  \
# 1802746            NaN            NaN            NaN              NaN
# 1802747            NaN            NaN            NaN              NaN
# 1802748            NaN            NaN            NaN              NaN
# 1802749            NaN            NaN            NaN              NaN
# 1802750            NaN            NaN            NaN              NaN
#
#          iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 1802746          NaN            NaN           NaN      NaN
# 1802747          NaN            NaN           NaN      NaN
# 1802748          NaN            NaN           NaN      NaN
# 1802749          NaN            NaN           NaN      NaN
# 1802750          NaN            NaN           NaN      NaN
#
#          fruits-vegetables-nuts_100g  fruits-vegetables-nuts-dried_100g  \
# 1802746                          NaN                                NaN
# 1802747                          NaN                                NaN
# 1802748                          NaN                                NaN
# 1802749                          NaN                                NaN
# 1802750                          NaN                                NaN
#
#          fruits-vegetables-nuts-estimate_100g  \
# 1802746                                   NaN
# 1802747                                   NaN
# 1802748                                   NaN
# 1802749                                   NaN
# 1802750                                   NaN
#
#          collagen-meat-protein-ratio_100g  cocoa_100g  chlorophyl_100g  \
# 1802746                               NaN         NaN              NaN
# 1802747                               NaN         NaN              NaN
# 1802748                               NaN         NaN              NaN
# 1802749                               NaN         NaN              NaN
# 1802750                               NaN         NaN              NaN
#
#          carbon-footprint_100g  carbon-footprint-from-meat-or-fish_100g  \
# 1802746                    NaN                                      NaN
# 1802747                    NaN                                      NaN
# 1802748                    NaN                                      NaN
# 1802749                    NaN                                      NaN
# 1802750                    NaN                                      NaN
#
#          nutrition-score-fr_100g  nutrition-score-uk_100g  \
# 1802746                      NaN                      NaN
# 1802747                      NaN                      NaN
# 1802748                      NaN                      NaN
# 1802749                      NaN                      NaN
# 1802750                      NaN                      NaN
#
#          glycemic-index_100g  water-hardness_100g  choline_100g  \
# 1802746                  NaN                  NaN           NaN
# 1802747                  NaN                  NaN           NaN
# 1802748                  NaN                  NaN           NaN
# 1802749                  NaN                  NaN           NaN
# 1802750                  NaN                  NaN           NaN
#
#          phylloquinone_100g  beta-glucan_100g  inositol_100g  carnitine_100g
# 1802746                 NaN               NaN            NaN             NaN
# 1802747                 NaN               NaN            NaN             NaN
# 1802748                 NaN               NaN            NaN             NaN
# 1802749                 NaN               NaN            NaN             NaN
# 1802750                 NaN               NaN            NaN             NaN

# %%
length = len(df1)
print("length =", length)
# Out:
# length = 1802751

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1802751 entries, 0 to 1802750
# Columns: 186 entries, code to carnitine_100g
# dtypes: float64(123), int64(2), object(61)
# memory usage: 2.5+ GB

# %% [markdown]
# # Nettoyage de données (suppression des valeurs aberrantes)

# %% [markdown]
# La liste suivante contient les variables que nous allons nettoyer, ainsi que les valeurs min/max des intervalles en dehors desquelles les valeurs sont aberrantes.
# Les valeurs aberrantes ont été remplacées par des NaN.

# %%
liste_variables_pour_nettoyage = [
                ['energy_100g', 0, 3800],     # 3800kJ correspondent à 100g de lipides
                ['sugars_100g', 0, 100],     # il y a au maximum 100g de sucre dans 100g d'aliment
                ['saturated-fat_100g', 0, 100],
                ['fat_100g', 0, 100],
                ['salt_100g', 0, 100],
                ['proteins_100g', 0, 100], 
                ['fiber_100g', 0, 100], 
                ['cholesterol_100g', 0, 5],     # une valeur supérieure à 5g/100g est aberrante
                ['-lactose_100g', 0, 100],    
                ['nutriscore_score', -15, 40],
                ['energy-kj_100g', 0, 3800],
                ['energy-kcal_100g', 0, 900],
                ['monounsaturated-fat_100g', 0, 100],    
                ['polyunsaturated-fat_100g', 0, 100],
                ['trans-fat_100g', 0, 100],    
                ['carbohydrates_100g', 0, 100],            
                ['alcohol_100g', 0, 100],    
                ['vitamin-a_100g', 0, 0.01],    
                ['vitamin-c_100g', 0, 1],    
                ['calcium_100g', 0, 100],    
                ['iron_100g', 0, 0.1],    
                ['sodium_100g', 0, 100],
]

# %% [markdown]
# Exécution du nettoyage

# %%
print('Variable'.center(26, ' '), 'Borne min'.center(11, ' '),
      'Borne max'.center(11,
                         ' '), 'Nb de valeurs avant nettoyage'.center(33, ' '),
      'Nb de remplacements NaN'.center(25, ' '), '%remplacés'.center(11, ' '))
print(''.center(123, '-'))

for var in range(len(liste_variables_pour_nettoyage)):
    nom = liste_variables_pour_nettoyage[var][0]
    min_x = liste_variables_pour_nettoyage[var][1]
    max_x = liste_variables_pour_nettoyage[var][2]
    count_avant = df1[nom].count()
    df1[nom] = df1[nom].apply(lambda x: np.nan
                              if (x < min_x or x > max_x) else x)
    count_apres = df1[nom].count()
    print(
        nom.center(26, ' '),
        str(min_x).center(11, ' '),
        str(max_x).center(11, ' '),
        str(count_avant).center(33, ' '),
        str(count_avant - count_apres).center(25, ' '), "{0:.2f}%".format(
            (count_avant - count_apres) / count_avant * 100).center(11, ' '))
# Out:
#          Variable           Borne min   Borne max    Nb de valeurs avant nettoyage    Nb de remplacements NaN   %remplacés
# ---------------------------------------------------------------------------------------------------------------------------
#        energy_100g              0          3800                 1431552                         5409              0.38%
#        sugars_100g              0          100                  1405976                          79               0.01%
#     saturated-fat_100g          0          100                  1380084                          45               0.00%
#          fat_100g               0          100                  1423426                         108               0.01%
#         salt_100g               0          100                  1368694                         877               0.06%
#       proteins_100g             0          100                  1424472                          76               0.01%
#         fiber_100g              0          100                   472216                          53               0.01%
#      cholesterol_100g           0           5                    268389                         179               0.07%
#       -lactose_100g             0          100                    839                            4                0.48%
#      nutriscore_score          -15          40                   670110                          0                0.00%
#       energy-kj_100g            0          3800                  131989                          51               0.04%
#      energy-kcal_100g           0          900                  1378429                         5735              0.42%
#  monounsaturated-fat_100g       0          100                   47498                           2                0.00%
#  polyunsaturated-fat_100g       0          100                   47490                           1                0.00%
#       trans-fat_100g            0          100                   264628                          12               0.00%
#     carbohydrates_100g          0          100                  1422974                         173               0.01%
#        alcohol_100g             0          100                   20883                           2                0.01%
#       vitamin-a_100g            0          0.01                  212298                         319               0.15%
#       vitamin-c_100g            0           1                    220001                         426               0.19%
#        calcium_100g             0          100                   270006                          68               0.03%
#         iron_100g               0          0.1                   264648                         294               0.11%
#        sodium_100g              0          100                  1368690                         571               0.04%

# %% [markdown]
# # Sauvegarde du df nettoyé

# %%
df1.to_pickle('df_après_nettoyage.pkl')
